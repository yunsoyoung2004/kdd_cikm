# %%
# ============================================================
# robust_multi_env_recurrent_ppo.py
# ------------------------------------------------------------
# 목표
# - CartPole / Acrobot / MountainCar 에서 안정적으로 학습되는 recurrent PPO
# - sparse reward 환경 대응
# - mild / medium / hard POMDP curriculum 지원
# - notebook / terminal 모두 안전
#
# 주요 개선
# - parse_known_args() : notebook 안전
# - recurrent PPO (LSTM)
# - orthogonal init + LayerNorm
# - observation normalization
# - PPO value clipping / KL early stopping
# - lr annealing / entropy annealing
# - env-specific shaping reward (train only)
# - raw reward / train reward 분리
# - scheduled POMDP severity
# - checkpoint / resume / graceful stop
# - optional notebook kernel safe shutdown
#
# 권장 실행
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --resume
# ============================================================

import os
import gc
import csv
import json
import math
import time
import signal
import random
import argparse
from dataclasses import dataclass, asdict
from typing import Dict, List, Optional, Tuple, Any

import numpy as np
import gymnasium as gym

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical


# ============================================================
# Global
# ============================================================

USE_AMP_DEFAULT = True
STOP_REQUESTED = False


def _signal_handler(signum, frame):
    global STOP_REQUESTED
    STOP_REQUESTED = True
    print(f"\n[signal] received signal={signum}. stopping at next safe point...")


signal.signal(signal.SIGINT, _signal_handler)
signal.signal(signal.SIGTERM, _signal_handler)


# ============================================================
# Utils
# ============================================================

def set_global_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)


def cleanup_torch(device: torch.device):
    try:
        gc.collect()
        if device.type == "cuda":
            torch.cuda.synchronize(device)
            torch.cuda.empty_cache()
            try:
                torch.cuda.ipc_collect()
            except Exception:
                pass
    except Exception as e:
        print("[warn] cleanup_torch failed:", repr(e))


def unwrap_model(model: nn.Module) -> nn.Module:
    return model._orig_mod if hasattr(model, "_orig_mod") else model


def model_state_dict(model: nn.Module) -> Dict[str, torch.Tensor]:
    return unwrap_model(model).state_dict()


def load_model_state_dict(model: nn.Module, state_dict: Dict[str, torch.Tensor], strict: bool = True):
    unwrap_model(model).load_state_dict(state_dict, strict=strict)


def maybe_compile(model: nn.Module, enabled: bool) -> nn.Module:
    if not enabled:
        return model
    try:
        return torch.compile(model)
    except Exception as e:
        print("[warn] torch.compile failed, fallback:", repr(e))
        return model


def linear_interp(a: float, b: float, t01: float) -> float:
    t01 = max(0.0, min(1.0, float(t01)))
    return a + (b - a) * t01


def safe_float(x, default=0.0):
    try:
        return float(x)
    except Exception:
        return float(default)


def maybe_shutdown_kernel(enabled: bool):
    if not enabled:
        return
    try:
        from IPython import get_ipython
        ip = get_ipython()
        if ip is not None and hasattr(ip, "kernel"):
            print("[shutdown] notebook kernel will be shut down safely.")
            ip.kernel.do_shutdown(restart=False)
    except Exception as e:
        print("[warn] kernel shutdown skipped:", repr(e))


# ============================================================
# Running mean/std
# ============================================================

class RunningMeanStd:
    def __init__(self, shape):
        self.mean = np.zeros(shape, dtype=np.float64)
        self.var = np.ones(shape, dtype=np.float64)
        self.count = 1e-4

    def update(self, x: np.ndarray):
        x = np.asarray(x, dtype=np.float64)
        if x.ndim == 1:
            x = x[None, :]
        batch_mean = np.mean(x, axis=0)
        batch_var = np.var(x, axis=0)
        batch_count = x.shape[0]
        self._update_from_moments(batch_mean, batch_var, batch_count)

    def _update_from_moments(self, batch_mean, batch_var, batch_count):
        delta = batch_mean - self.mean
        total_count = self.count + batch_count

        new_mean = self.mean + delta * batch_count / total_count

        m_a = self.var * self.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + (delta ** 2) * self.count * batch_count / total_count
        new_var = M2 / total_count

        self.mean = new_mean
        self.var = np.maximum(new_var, 1e-12)
        self.count = total_count

    def normalize(self, x: np.ndarray) -> np.ndarray:
        x = np.asarray(x, dtype=np.float32)
        z = (x - self.mean) / np.sqrt(self.var + 1e-8)
        return np.clip(z, -10.0, 10.0).astype(np.float32)

    def state_dict(self) -> Dict[str, Any]:
        return {
            "mean": self.mean.tolist(),
            "var": self.var.tolist(),
            "count": float(self.count),
        }

    def load_state_dict(self, sd: Dict[str, Any]):
        self.mean = np.asarray(sd["mean"], dtype=np.float64)
        self.var = np.asarray(sd["var"], dtype=np.float64)
        self.count = float(sd["count"])


# ============================================================
# POMDP wrapper with curriculum
# ============================================================

class ScheduledPartialObsWrapper(gym.ObservationWrapper):
    """
    partial_indices: 일부 차원만 관측
    flicker/noise는 progress에 따라 start -> end
    """
    def __init__(
        self,
        env: gym.Env,
        partial_indices: Optional[List[int]],
        flicker_prob_start: float,
        flicker_prob_end: float,
        noise_std_start: float,
        noise_std_end: float,
    ):
        super().__init__(env)
        self.partial_indices = partial_indices
        self.flicker_prob_start = float(flicker_prob_start)
        self.flicker_prob_end = float(flicker_prob_end)
        self.noise_std_start = float(noise_std_start)
        self.noise_std_end = float(noise_std_end)
        self.progress = 0.0

        assert isinstance(env.observation_space, gym.spaces.Box), "Only Box observation supported"
        low = env.observation_space.low
        high = env.observation_space.high

        if self.partial_indices is None:
            self.partial_indices = list(range(int(np.prod(low.shape))))

        low2 = low[self.partial_indices].astype(np.float32)
        high2 = high[self.partial_indices].astype(np.float32)

        self.observation_space = gym.spaces.Box(
            low=low2,
            high=high2,
            shape=(len(self.partial_indices),),
            dtype=np.float32,
        )

    def set_progress(self, progress01: float):
        self.progress = max(0.0, min(1.0, float(progress01)))

    def get_current_params(self):
        flicker_prob = linear_interp(self.flicker_prob_start, self.flicker_prob_end, self.progress)
        noise_std = linear_interp(self.noise_std_start, self.noise_std_end, self.progress)
        return flicker_prob, noise_std

    def observation(self, obs):
        obs = np.asarray(obs, dtype=np.float32)
        obs = obs[self.partial_indices].astype(np.float32)

        flicker_prob, noise_std = self.get_current_params()

        if flicker_prob > 0.0 and np.random.rand() < flicker_prob:
            obs = np.zeros_like(obs, dtype=np.float32)

        if noise_std > 0.0:
            obs = obs + np.random.normal(0.0, noise_std, size=obs.shape).astype(np.float32)

        return obs.astype(np.float32)


# ============================================================
# Reward shaping
# ============================================================

class RewardShaper:
    def reset(self, obs: np.ndarray):
        pass

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        return float(raw_reward)


class IdentityShaper(RewardShaper):
    pass


class CartPoleShaper(RewardShaper):
    """
    CartPole은 원래 dense reward라 shaping 거의 안 함.
    너무 과한 shaping은 오히려 망가질 수 있으니 작은 안정화만.
    """
    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        # obs: [x, x_dot, theta, theta_dot]
        theta = abs(float(next_obs[2])) if len(next_obs) >= 3 else 0.0
        x = abs(float(next_obs[0])) if len(next_obs) >= 1 else 0.0

        # 작은 penalty만 추가
        bonus = 0.05 * max(0.0, 0.2 - theta) - 0.01 * x
        return float(raw_reward + bonus)


class MountainCarShaper(RewardShaper):
    """
    potential-based shaping:
    높이 + 진행 방향 + 정상 종료 bonus
    """
    def potential(self, obs):
        pos = float(obs[0])
        vel = float(obs[1])
        # position, forward motion
        return 5.0 * pos + 1.0 * vel

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        gamma = 0.99
        shaped = float(raw_reward) + gamma * self.potential(next_obs) - self.potential(obs)

        # goal reached bonus
        if terminated and float(next_obs[0]) >= 0.5:
            shaped += 10.0
        return shaped


class AcrobotShaper(RewardShaper):
    """
    potential-based shaping:
    end-effector 높이 기반
    """
    def tip_height(self, obs):
        c1, s1, c2, s2 = float(obs[0]), float(obs[1]), float(obs[2]), float(obs[3])
        theta1 = math.atan2(s1, c1)
        theta2 = math.atan2(s2, c2)
        # link length = 1,1
        y = -math.cos(theta1) - math.cos(theta1 + theta2)
        return y

    def potential(self, obs):
        # tip 높이가 위로 갈수록 좋음
        return 4.0 * self.tip_height(obs)

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        gamma = 0.99
        shaped = float(raw_reward) + gamma * self.potential(next_obs) - self.potential(obs)
        if terminated:
            shaped += 10.0
        return shaped


# ============================================================
# Presets
# ============================================================

@dataclass
class EnvPreset:
    name: str
    env_id: str
    partial_indices: Optional[List[int]]

    flicker_prob_start: float
    flicker_prob_end: float
    noise_std_start: float
    noise_std_end: float

    max_steps: int
    solve_score: Optional[float]
    recommended_episodes: int

    lr: float
    lr_end_scale: float
    gamma: float
    gae_lambda: float
    ppo_clip: float
    value_clip: float
    ppo_epochs: int
    minibatch_tokens: int
    steps_per_update: int
    value_coef: float
    max_grad_norm: float
    target_kl: float

    ent_start: float
    ent_end: float

    mlp_hidden: int
    lstm_hidden: int

    shaper: str


def get_presets() -> Dict[str, EnvPreset]:
    presets = {
        # ----------------------------------------------------
        # RELIABLE
        # ----------------------------------------------------
        "cartpole_reliable": EnvPreset(
            name="cartpole_reliable",
            env_id="CartPole-v1",
            partial_indices=[0, 1, 2, 3],
            flicker_prob_start=0.00,
            flicker_prob_end=0.03,
            noise_std_start=0.0,
            noise_std_end=0.003,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=4000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=4,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.03,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),

        "acrobot_reliable": EnvPreset(
            name="acrobot_reliable",
            env_id="Acrobot-v1",
            partial_indices=[0, 1, 2, 3, 4, 5],
            flicker_prob_start=0.00,
            flicker_prob_end=0.03,
            noise_std_start=0.0,
            noise_std_end=0.001,
            max_steps=500,
            solve_score=-100.0,
            recommended_episodes=16000,
            lr=2.5e-4,
            lr_end_scale=0.15,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=8,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.6,
            max_grad_norm=0.7,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.002,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="acrobot",
        ),

        "mountaincar_reliable": EnvPreset(
            name="mountaincar_reliable",
            env_id="MountainCar-v0",
            partial_indices=[0, 1],
            flicker_prob_start=0.00,
            flicker_prob_end=0.02,
            noise_std_start=0.0,
            noise_std_end=0.0005,
            max_steps=200,
            solve_score=-110.0,
            recommended_episodes=18000,
            lr=2e-4,
            lr_end_scale=0.10,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=10,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.7,
            max_grad_norm=0.7,
            target_kl=0.02,
            ent_start=0.03,
            ent_end=0.003,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="mountaincar",
        ),

        # ----------------------------------------------------
        # MEDIUM POMDP
        # ----------------------------------------------------
        "cartpole_medium": EnvPreset(
            name="cartpole_medium",
            env_id="CartPole-v1",
            partial_indices=[0, 2, 3],
            flicker_prob_start=0.01,
            flicker_prob_end=0.06,
            noise_std_start=0.001,
            noise_std_end=0.01,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=6000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=5,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.03,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),

        "acrobot_medium": EnvPreset(
            name="acrobot_medium",
            env_id="Acrobot-v1",
            partial_indices=[0, 1, 2, 3, 5],
            flicker_prob_start=0.01,
            flicker_prob_end=0.05,
            noise_std_start=0.0,
            noise_std_end=0.003,
            max_steps=500,
            solve_score=-100.0,
            recommended_episodes=22000,
            lr=2.5e-4,
            lr_end_scale=0.15,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=8,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.6,
            max_grad_norm=0.7,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.002,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="acrobot",
        ),

        "mountaincar_medium": EnvPreset(
            name="mountaincar_medium",
            env_id="MountainCar-v0",
            partial_indices=[0, 1],
            flicker_prob_start=0.01,
            flicker_prob_end=0.05,
            noise_std_start=0.0002,
            noise_std_end=0.003,
            max_steps=200,
            solve_score=-110.0,
            recommended_episodes=24000,
            lr=2e-4,
            lr_end_scale=0.10,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=10,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.7,
            max_grad_norm=0.7,
            target_kl=0.02,
            ent_start=0.03,
            ent_end=0.003,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="mountaincar",
        ),

        # ----------------------------------------------------
        # HARD
        # ----------------------------------------------------
        "cartpole_partial_hard": EnvPreset(
            name="cartpole_partial_hard",
            env_id="CartPole-v1",
            partial_indices=[0, 2],
            flicker_prob_start=0.02,
            flicker_prob_end=0.10,
            noise_std_start=0.001,
            noise_std_end=0.02,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=9000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=6,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),
    }
    return presets


def get_shaper(name: str) -> RewardShaper:
    name = str(name).lower()
    if name == "cartpole":
        return CartPoleShaper()
    if name == "acrobot":
        return AcrobotShaper()
    if name == "mountaincar":
        return MountainCarShaper()
    return IdentityShaper()


def build_env(preset: EnvPreset, seed: Optional[int] = None):
    env = gym.make(preset.env_id)
    env = ScheduledPartialObsWrapper(
        env=env,
        partial_indices=preset.partial_indices,
        flicker_prob_start=preset.flicker_prob_start,
        flicker_prob_end=preset.flicker_prob_end,
        noise_std_start=preset.noise_std_start,
        noise_std_end=preset.noise_std_end,
    )
    if seed is not None:
        env.reset(seed=seed)
        env.action_space.seed(seed)
    return env


# ============================================================
# Model
# ============================================================

class RecurrentActorCritic(nn.Module):
    def __init__(self, obs_dim: int, action_dim: int, mlp_hidden: int, lstm_hidden: int):
        super().__init__()

        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.mlp_hidden = mlp_hidden
        self.lstm_hidden = lstm_hidden

        self.encoder = nn.Sequential(
            nn.Linear(obs_dim, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
            nn.Linear(mlp_hidden, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
        )

        self.lstm = nn.LSTM(
            input_size=mlp_hidden,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
        )

        self.actor = nn.Linear(lstm_hidden, action_dim)
        self.critic = nn.Linear(lstm_hidden, 1)

        self.apply(self._init_weights)

        nn.init.orthogonal_(self.actor.weight, gain=0.01)
        nn.init.zeros_(self.actor.bias)
        nn.init.orthogonal_(self.critic.weight, gain=1.0)
        nn.init.zeros_(self.critic.bias)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.orthogonal_(m.weight, gain=math.sqrt(2))
            nn.init.zeros_(m.bias)

    def initial_state(self, batch_size: int, device: torch.device):
        h = torch.zeros((1, batch_size, self.lstm_hidden), device=device)
        c = torch.zeros((1, batch_size, self.lstm_hidden), device=device)
        return (h, c)

    def forward(self, obs_seq: torch.Tensor, hidden=None):
        # obs_seq: (B,T,D)
        x = self.encoder(obs_seq)
        x, hidden = self.lstm(x, hidden)
        logits = self.actor(x)
        values = self.critic(x)
        return logits, values, hidden

    @torch.no_grad()
    def act(self, obs_t: torch.Tensor, hidden):
        logits, value, hidden = self.forward(obs_t, hidden)
        logits = logits[:, -1, :]
        value = value[:, -1, :]
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        entropy = dist.entropy()
        return (
            int(action.item()),
            float(log_prob.item()),
            float(value.item()),
            float(entropy.item()),
            hidden,
        )


# ============================================================
# Rollout buffer
# ============================================================

class RolloutBuffer:
    def __init__(self):
        self.obs = []
        self.actions = []
        self.train_rewards = []
        self.raw_rewards = []
        self.dones = []
        self.log_probs = []
        self.values = []
        self.episode_ids = []
        self.bootstrap_values = []

    def clear(self):
        self.__init__()

    def add(self, obs, action, train_reward, raw_reward, done, log_prob, value, episode_id):
        self.obs.append(np.asarray(obs, dtype=np.float32))
        self.actions.append(int(action))
        self.train_rewards.append(float(train_reward))
        self.raw_rewards.append(float(raw_reward))
        self.dones.append(bool(done))
        self.log_probs.append(float(log_prob))
        self.values.append(float(value))
        self.episode_ids.append(int(episode_id))

    def __len__(self):
        return len(self.obs)


# ============================================================
# Metrics / GAE / segments
# ============================================================

def compute_train_metrics(raw_rewards: List[float], solve_score: Optional[float]):
    r = np.asarray(raw_rewards, dtype=np.float32)
    if len(r) == 0:
        return {
            "auc_mean": 0.0,
            "last100_mean": 0.0,
            "last100_std": 0.0,
            "best_reward": 0.0,
            "first_solve_ep": -1,
        }

    tail = r[-100:] if len(r) >= 100 else r
    last100_mean = float(tail.mean())
    last100_std = float(tail.std(ddof=0))
    best_reward = float(r.max())
    auc_mean = float(r.mean())

    first_solve_ep = -1
    if solve_score is not None and len(r) >= 100:
        win = np.convolve(r, np.ones(100, dtype=np.float32) / 100.0, mode="valid")
        idx = np.where(win >= solve_score)[0]
        if len(idx) > 0:
            first_solve_ep = int(idx[0] + 100)

    return {
        "auc_mean": auc_mean,
        "last100_mean": last100_mean,
        "last100_std": last100_std,
        "best_reward": best_reward,
        "first_solve_ep": int(first_solve_ep),
    }


def compute_gae(
    rewards: np.ndarray,
    values: np.ndarray,
    dones: np.ndarray,
    next_value: float,
    gamma: float,
    gae_lambda: float,
):
    n = len(rewards)
    advantages = np.zeros(n, dtype=np.float32)
    last_gae = 0.0
    for t in reversed(range(n)):
        if t == n - 1:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = next_value
        else:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = values[t + 1]

        delta = rewards[t] + gamma * next_values * next_nonterminal - values[t]
        last_gae = delta + gamma * gae_lambda * next_nonterminal * last_gae
        advantages[t] = last_gae

    returns = advantages + values
    return advantages, returns


def split_into_segments_preview(buffer: RolloutBuffer):
    if len(buffer) == 0:
        return []

    segments = []
    start = 0
    n = len(buffer)

    for i in range(n - 1):
        if buffer.dones[i] or buffer.episode_ids[i + 1] != buffer.episode_ids[i]:
            segments.append(slice(start, i + 1))
            start = i + 1

    if start < n:
        segments.append(slice(start, n))

    return segments


def split_into_segments(buffer: RolloutBuffer):
    previews = split_into_segments_preview(buffer)
    out = []
    for idx, sl in enumerate(previews):
        out.append((sl, buffer.bootstrap_values[idx]))
    return out


def pad_sequences(arrays: List[np.ndarray], pad_value: float = 0.0):
    max_len = max(a.shape[0] for a in arrays)

    padded = []
    masks = []
    for a in arrays:
        T = a.shape[0]
        pad_shape = (max_len - T,) + a.shape[1:]
        if len(pad_shape) == 1:
            pad_arr = np.full((max_len - T,), pad_value, dtype=a.dtype)
        else:
            pad_arr = np.full(pad_shape, pad_value, dtype=a.dtype)

        padded_arr = np.concatenate([a, pad_arr], axis=0)
        mask = np.concatenate(
            [np.ones(T, dtype=np.float32), np.zeros(max_len - T, dtype=np.float32)],
            axis=0,
        )
        padded.append(padded_arr)
        masks.append(mask)

    return np.stack(padded), np.stack(masks)


# ============================================================
# Evaluation
# ============================================================

@torch.no_grad()
def evaluate_policy(
    model: nn.Module,
    preset: EnvPreset,
    device: torch.device,
    obs_rms: RunningMeanStd,
    n_episodes: int = 10,
    greedy: bool = True,
):
    env = build_env(preset, seed=12345)
    env.set_progress(1.0)  # hardest scheduled test
    scores = []

    try:
        for ep in range(n_episodes):
            obs, _ = env.reset(seed=12345 + ep)
            hidden = unwrap_model(model).initial_state(batch_size=1, device=device)
            done = False
            ep_reward = 0.0
            steps = 0

            while not done and steps < preset.max_steps:
                obs_n = obs_rms.normalize(obs)
                obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                logits, _, hidden = model(obs_t, hidden)
                logits = logits[:, -1, :]
                dist = Categorical(logits=logits)
                action = torch.argmax(dist.probs, dim=-1) if greedy else dist.sample()

                obs, reward, terminated, truncated, _ = env.step(int(action.item()))
                done = terminated or truncated
                ep_reward += float(reward)
                steps += 1

            scores.append(ep_reward)
    finally:
        env.close()

    arr = np.asarray(scores, dtype=np.float32)
    return {
        "eval_mean": float(arr.mean()) if len(arr) else 0.0,
        "eval_std": float(arr.std(ddof=0)) if len(arr) else 0.0,
        "eval_min": float(arr.min()) if len(arr) else 0.0,
        "eval_max": float(arr.max()) if len(arr) else 0.0,
    }


# ============================================================
# PPO update
# ============================================================

def ppo_update(
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    buffer: RolloutBuffer,
    preset: EnvPreset,
    device: torch.device,
    use_amp: bool,
    progress01: float,
):
    segments = split_into_segments(buffer)
    if not segments:
        return {
            "loss_total": 0.0,
            "loss_policy": 0.0,
            "loss_value": 0.0,
            "entropy": 0.0,
            "approx_kl": 0.0,
            "early_stop_kl": 0,
        }

    obs_list = []
    act_list = []
    old_logp_list = []
    adv_list = []
    ret_list = []
    old_value_list = []

    for sl, bootstrap_value in segments:
        rewards = np.asarray(buffer.train_rewards[sl], dtype=np.float32)
        values = np.asarray(buffer.values[sl], dtype=np.float32)
        dones = np.asarray(buffer.dones[sl], dtype=np.float32)

        adv, ret = compute_gae(
            rewards=rewards,
            values=values,
            dones=dones,
            next_value=float(bootstrap_value),
            gamma=preset.gamma,
            gae_lambda=preset.gae_lambda,
        )

        obs_arr = np.asarray(buffer.obs[sl], dtype=np.float32)
        act_arr = np.asarray(buffer.actions[sl], dtype=np.int64)
        logp_arr = np.asarray(buffer.log_probs[sl], dtype=np.float32)
        val_arr = np.asarray(buffer.values[sl], dtype=np.float32)

        obs_list.append(obs_arr)
        act_list.append(act_arr)
        old_logp_list.append(logp_arr)
        adv_list.append(adv.astype(np.float32))
        ret_list.append(ret.astype(np.float32))
        old_value_list.append(val_arr.astype(np.float32))

    # advantage normalization
    all_adv = np.concatenate(adv_list, axis=0)
    adv_mean = all_adv.mean()
    adv_std = all_adv.std() + 1e-8
    adv_list = [((a - adv_mean) / adv_std).astype(np.float32) for a in adv_list]

    obs_pad, mask = pad_sequences(obs_list, pad_value=0.0)
    act_pad, _ = pad_sequences([a[:, None] for a in act_list], pad_value=0)
    old_logp_pad, _ = pad_sequences([a[:, None] for a in old_logp_list], pad_value=0.0)
    adv_pad, _ = pad_sequences([a[:, None] for a in adv_list], pad_value=0.0)
    ret_pad, _ = pad_sequences([a[:, None] for a in ret_list], pad_value=0.0)
    old_val_pad, _ = pad_sequences([a[:, None] for a in old_value_list], pad_value=0.0)

    obs_t = torch.as_tensor(obs_pad, dtype=torch.float32, device=device)
    act_t = torch.as_tensor(act_pad.squeeze(-1), dtype=torch.long, device=device)
    old_logp_t = torch.as_tensor(old_logp_pad.squeeze(-1), dtype=torch.float32, device=device)
    adv_t = torch.as_tensor(adv_pad.squeeze(-1), dtype=torch.float32, device=device)
    ret_t = torch.as_tensor(ret_pad.squeeze(-1), dtype=torch.float32, device=device)
    old_val_t = torch.as_tensor(old_val_pad.squeeze(-1), dtype=torch.float32, device=device)
    mask_t = torch.as_tensor(mask, dtype=torch.float32, device=device)

    n_seq = obs_t.shape[0]
    idxs = np.arange(n_seq)

    ent_coef = linear_interp(preset.ent_start, preset.ent_end, progress01)

    total_loss_v = []
    policy_loss_v = []
    value_loss_v = []
    entropy_v = []
    approx_kl_v = []
    early_stop_kl = 0

    seqs_per_batch = max(1, preset.minibatch_tokens // max(1, obs_t.shape[1]))

    for _ in range(preset.ppo_epochs):
        np.random.shuffle(idxs)
        stop_this_epoch = False

        for start in range(0, n_seq, seqs_per_batch):
            batch_idx = idxs[start:start + seqs_per_batch]

            b_obs = obs_t[batch_idx]
            b_act = act_t[batch_idx]
            b_old_logp = old_logp_t[batch_idx]
            b_adv = adv_t[batch_idx]
            b_ret = ret_t[batch_idx]
            b_old_val = old_val_t[batch_idx]
            b_mask = mask_t[batch_idx]

            hidden = unwrap_model(model).initial_state(batch_size=b_obs.shape[0], device=device)

            with torch.amp.autocast("cuda", enabled=use_amp):
                logits, values, _ = model(b_obs, hidden)
                values = values.squeeze(-1)

                dist = Categorical(logits=logits)
                new_logp = dist.log_prob(b_act)
                entropy = dist.entropy()

                ratio = torch.exp(new_logp - b_old_logp)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - preset.ppo_clip, 1.0 + preset.ppo_clip) * b_adv
                policy_loss = -torch.sum(torch.min(surr1, surr2) * b_mask) / (torch.sum(b_mask) + 1e-8)

                # value clipping
                value_pred_clipped = b_old_val + torch.clamp(values - b_old_val, -preset.value_clip, preset.value_clip)
                value_loss_unclipped = (values - b_ret) ** 2
                value_loss_clipped = (value_pred_clipped - b_ret) ** 2
                value_loss_all = 0.5 * torch.max(value_loss_unclipped, value_loss_clipped)
                value_loss = torch.sum(value_loss_all * b_mask) / (torch.sum(b_mask) + 1e-8)

                entropy_mean = torch.sum(entropy * b_mask) / (torch.sum(b_mask) + 1e-8)
                loss = policy_loss + preset.value_coef * value_loss - ent_coef * entropy_mean

            optimizer.zero_grad(set_to_none=True)
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(unwrap_model(model).parameters(), preset.max_grad_norm)
            scaler.step(optimizer)
            scaler.update()

            with torch.no_grad():
                approx_kl = torch.sum((b_old_logp - new_logp) * b_mask) / (torch.sum(b_mask) + 1e-8)

            total_loss_v.append(float(loss.item()))
            policy_loss_v.append(float(policy_loss.item()))
            value_loss_v.append(float(value_loss.item()))
            entropy_v.append(float(entropy_mean.item()))
            approx_kl_v.append(float(approx_kl.item()))

            if float(approx_kl.item()) > float(preset.target_kl):
                early_stop_kl += 1
                stop_this_epoch = True
                break

        if stop_this_epoch:
            break

    return {
        "loss_total": float(np.mean(total_loss_v)) if total_loss_v else 0.0,
        "loss_policy": float(np.mean(policy_loss_v)) if policy_loss_v else 0.0,
        "loss_value": float(np.mean(value_loss_v)) if value_loss_v else 0.0,
        "entropy": float(np.mean(entropy_v)) if entropy_v else 0.0,
        "approx_kl": float(np.mean(approx_kl_v)) if approx_kl_v else 0.0,
        "early_stop_kl": int(early_stop_kl),
    }


# ============================================================
# Checkpoint
# ============================================================

def ckpt_path(ckpt_dir: str, preset_name: str, seed: int):
    ensure_dir(ckpt_dir)
    return os.path.join(ckpt_dir, f"{preset_name}_seed{seed}_latest.pt")


def meta_path(ckpt_dir: str, preset_name: str, seed: int):
    ensure_dir(ckpt_dir)
    return os.path.join(ckpt_dir, f"{preset_name}_seed{seed}_meta.json")


def save_json(path: str, data: Dict[str, Any]):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)


def save_checkpoint(
    path: str,
    episode: int,
    global_step: int,
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    obs_rms: RunningMeanStd,
    raw_train_rewards: List[float],
    train_reward_history: List[float],
    eval_history: List[Dict[str, Any]],
    config: Dict[str, Any],
):
    payload = {
        "episode": int(episode),
        "global_step": int(global_step),
        "model": model_state_dict(model),
        "optimizer": optimizer.state_dict(),
        "scaler": scaler.state_dict(),
        "obs_rms": obs_rms.state_dict(),
        "raw_train_rewards": list(raw_train_rewards),
        "train_reward_history": list(train_reward_history),
        "eval_history": list(eval_history),
        "config": config,
    }
    torch.save(payload, path)


def load_checkpoint(
    path: str,
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    obs_rms: RunningMeanStd,
    device: torch.device,
):
    payload = torch.load(path, map_location=device)

    load_model_state_dict(model, payload["model"], strict=True)
    optimizer.load_state_dict(payload["optimizer"])

    try:
        scaler.load_state_dict(payload["scaler"])
    except Exception:
        pass

    if "obs_rms" in payload:
        obs_rms.load_state_dict(payload["obs_rms"])

    return {
        "episode": int(payload.get("episode", -1)),
        "global_step": int(payload.get("global_step", 0)),
        "raw_train_rewards": list(payload.get("raw_train_rewards", [])),
        "train_reward_history": list(payload.get("train_reward_history", [])),
        "eval_history": list(payload.get("eval_history", [])),
        "config": payload.get("config", {}),
    }


# ============================================================
# One experiment
# ============================================================

def run_experiment(
    preset: EnvPreset,
    seed: int,
    total_episodes_override: Optional[int],
    eval_every: int,
    eval_episodes: int,
    save_every: int,
    log_every: int,
    device: torch.device,
    ckpt_dir: str,
    compile_models: bool,
    resume: bool,
    amp: bool,
):
    set_global_seed(seed)

    env = build_env(preset, seed=seed)
    shaper = get_shaper(preset.shaper)

    obs_dim = int(np.prod(env.observation_space.shape))
    assert isinstance(env.action_space, gym.spaces.Discrete), "Only discrete action spaces supported"
    action_dim = int(env.action_space.n)

    model = RecurrentActorCritic(
        obs_dim=obs_dim,
        action_dim=action_dim,
        mlp_hidden=preset.mlp_hidden,
        lstm_hidden=preset.lstm_hidden,
    ).to(device)

    if compile_models:
        model = maybe_compile(model, True)

    optimizer = torch.optim.Adam(unwrap_model(model).parameters(), lr=preset.lr, eps=1e-5)
    use_amp = bool(amp) and (device.type == "cuda")
    scaler = torch.amp.GradScaler("cuda", enabled=use_amp)

    obs_rms = RunningMeanStd(shape=(obs_dim,))

    episodes_target = int(total_episodes_override) if total_episodes_override is not None else int(preset.recommended_episodes)

    start_episode = 0
    global_step = 0
    raw_train_rewards: List[float] = []
    train_reward_history: List[float] = []
    eval_history: List[Dict[str, Any]] = []

    cpath = ckpt_path(ckpt_dir, preset.name, seed)
    mpath = meta_path(ckpt_dir, preset.name, seed)

    if resume and os.path.exists(cpath):
        print(f"[resume] loading {cpath}")
        state = load_checkpoint(cpath, model, optimizer, scaler, obs_rms, device)
        start_episode = int(state["episode"]) + 1
        global_step = int(state["global_step"])
        raw_train_rewards = state["raw_train_rewards"]
        train_reward_history = state["train_reward_history"]
        eval_history = state["eval_history"]
        print(f"[resume] preset={preset.name} seed={seed} start_episode={start_episode}")

    buffer = RolloutBuffer()

    try:
        if start_episode >= episodes_target:
            print(f"[skip] already finished: {preset.name} seed={seed}")
            result = {
                "preset": preset.name,
                "env_id": preset.env_id,
                "seed": seed,
                "episodes_completed": len(raw_train_rewards),
                **compute_train_metrics(raw_train_rewards, preset.solve_score),
            }
            if eval_history:
                result.update(eval_history[-1])
            return result

        obs, _ = env.reset(seed=seed + 123)
        shaper.reset(obs)
        hidden = unwrap_model(model).initial_state(batch_size=1, device=device)

        episode_idx = start_episode
        ep_raw_reward = 0.0
        ep_train_reward = 0.0
        ep_steps = 0

        while episode_idx < episodes_target:
            progress01 = episode_idx / max(1, episodes_target - 1)
            env.set_progress(progress01)

            # lr annealing
            lr_now = linear_interp(preset.lr, preset.lr * preset.lr_end_scale, progress01)
            for g in optimizer.param_groups:
                g["lr"] = lr_now

            obs_rms.update(np.asarray(obs, dtype=np.float32)[None, :])
            obs_n = obs_rms.normalize(obs)

            obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
            action, log_prob, value, _entropy, hidden = unwrap_model(model).act(obs_t, hidden)

            next_obs, raw_reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            train_reward = shaper.train_reward(
                obs=obs,
                action=action,
                next_obs=next_obs,
                raw_reward=raw_reward,
                terminated=terminated,
                truncated=truncated,
            )

            buffer.add(
                obs=obs_n,
                action=action,
                train_reward=train_reward,
                raw_reward=raw_reward,
                done=done,
                log_prob=log_prob,
                value=value,
                episode_id=episode_idx,
            )

            obs = next_obs
            ep_raw_reward += float(raw_reward)
            ep_train_reward += float(train_reward)
            ep_steps += 1
            global_step += 1

            if done or ep_steps >= preset.max_steps:
                buffer.bootstrap_values.append(0.0)
                raw_train_rewards.append(float(ep_raw_reward))
                train_reward_history.append(float(ep_train_reward))

                if (episode_idx % log_every) == 0:
                    recent = raw_train_rewards[-20:] if len(raw_train_rewards) >= 20 else raw_train_rewards
                    recent_mean = float(np.mean(recent)) if recent else 0.0
                    flicker_now, noise_now = env.get_current_params()
                    print(
                        f"[{preset.name} seed={seed}] "
                        f"ep={episode_idx:05d} "
                        f"rawR={ep_raw_reward:8.3f} "
                        f"trainR={ep_train_reward:8.3f} "
                        f"recent20={recent_mean:8.3f} "
                        f"flicker={flicker_now:.3f} "
                        f"noise={noise_now:.4f} "
                        f"lr={lr_now:.6f} "
                        f"global_step={global_step}"
                    )

                if ((episode_idx + 1) % eval_every) == 0 or (episode_idx + 1) == episodes_target:
                    eval_result = evaluate_policy(
                        model=model,
                        preset=preset,
                        device=device,
                        obs_rms=obs_rms,
                        n_episodes=eval_episodes,
                        greedy=True,
                    )
                    eval_result["eval_at_episode"] = int(episode_idx + 1)
                    eval_history.append(eval_result)

                    print(
                        f"[eval] {preset.name} seed={seed} "
                        f"ep={episode_idx+1} "
                        f"mean={eval_result['eval_mean']:.3f} "
                        f"std={eval_result['eval_std']:.3f}"
                    )

                if ((episode_idx + 1) % save_every) == 0 or STOP_REQUESTED:
                    save_checkpoint(
                        path=cpath,
                        episode=episode_idx,
                        global_step=global_step,
                        model=model,
                        optimizer=optimizer,
                        scaler=scaler,
                        obs_rms=obs_rms,
                        raw_train_rewards=raw_train_rewards,
                        train_reward_history=train_reward_history,
                        eval_history=eval_history,
                        config={
                            "preset": asdict(preset),
                            "seed": seed,
                            "episodes_target": episodes_target,
                        },
                    )
                    save_json(mpath, {
                        "preset": preset.name,
                        "env_id": preset.env_id,
                        "seed": seed,
                        "last_saved_episode": episode_idx,
                        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
                        "global_step": global_step,
                        "status": "running_or_interrupted",
                    })
                    print(f"[ckpt] saved {cpath}")

                episode_idx += 1

                if STOP_REQUESTED:
                    print("[stop] graceful stop requested.")
                    break

                obs, _ = env.reset(seed=seed * 100000 + episode_idx)
                shaper.reset(obs)
                hidden = unwrap_model(model).initial_state(batch_size=1, device=device)
                ep_raw_reward = 0.0
                ep_train_reward = 0.0
                ep_steps = 0

            # update
            if len(buffer) >= preset.steps_per_update or (STOP_REQUESTED and len(buffer) > 0):
                needed_segments = len(split_into_segments_preview(buffer))
                if len(buffer.bootstrap_values) < needed_segments:
                    with torch.no_grad():
                        obs_n = obs_rms.normalize(obs)
                        obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                        _, value_t, _ = model(obs_t, hidden)
                        bootstrap_value = float(value_t[:, -1, :].item()) if not done else 0.0
                    buffer.bootstrap_values.append(bootstrap_value)

                update_stats = ppo_update(
                    model=model,
                    optimizer=optimizer,
                    scaler=scaler,
                    buffer=buffer,
                    preset=preset,
                    device=device,
                    use_amp=use_amp,
                    progress01=progress01,
                )

                print(
                    f"[update] {preset.name} seed={seed} "
                    f"loss={update_stats['loss_total']:.4f} "
                    f"policy={update_stats['loss_policy']:.4f} "
                    f"value={update_stats['loss_value']:.4f} "
                    f"entropy={update_stats['entropy']:.4f} "
                    f"kl={update_stats['approx_kl']:.4f} "
                    f"early_stop_kl={update_stats['early_stop_kl']}"
                )

                buffer.clear()

                if STOP_REQUESTED:
                    break

        final_episode = min(max(start_episode, len(raw_train_rewards)) - 1, episodes_target - 1)
        if final_episode >= 0:
            save_checkpoint(
                path=cpath,
                episode=final_episode,
                global_step=global_step,
                model=model,
                optimizer=optimizer,
                scaler=scaler,
                obs_rms=obs_rms,
                raw_train_rewards=raw_train_rewards,
                train_reward_history=train_reward_history,
                eval_history=eval_history,
                config={
                    "preset": asdict(preset),
                    "seed": seed,
                    "episodes_target": episodes_target,
                },
            )
            save_json(mpath, {
                "preset": preset.name,
                "env_id": preset.env_id,
                "seed": seed,
                "last_saved_episode": final_episode,
                "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
                "global_step": global_step,
                "status": "finished_or_stopped",
            })
            print(f"[ckpt] final saved {cpath}")

        result = {
            "preset": preset.name,
            "env_id": preset.env_id,
            "seed": seed,
            "episodes_completed": len(raw_train_rewards),
            **compute_train_metrics(raw_train_rewards, preset.solve_score),
        }
        if eval_history:
            result.update(eval_history[-1])

        return result

    finally:
        try:
            env.close()
        except Exception:
            pass
        cleanup_torch(device)


# ============================================================
# Aggregation / save
# ============================================================

def aggregate_results(results: List[Dict[str, Any]]):
    grouped: Dict[str, List[Dict[str, Any]]] = {}
    for r in results:
        grouped.setdefault(str(r["preset"]), []).append(r)

    keys = [
        "auc_mean",
        "last100_mean",
        "last100_std",
        "best_reward",
        "first_solve_ep",
        "eval_mean",
        "eval_std",
        "episodes_completed",
    ]

    out = []
    for preset_name, rows in grouped.items():
        item = {
            "preset": preset_name,
            "n_seeds": len(rows),
        }
        for k in keys:
            vals = [float(x[k]) for x in rows if k in x]
            item[k] = float(np.mean(vals)) if vals else 0.0
        out.append(item)

    out.sort(key=lambda x: x["last100_mean"], reverse=True)
    return out


def save_csv(path: str, rows: List[Dict[str, Any]]):
    ensure_dir(os.path.dirname(path) or ".")
    if not rows:
        with open(path, "w", newline="", encoding="utf-8") as f:
            f.write("")
        return

    cols = sorted({k for r in rows for k in r.keys()})
    with open(path, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.DictWriter(f, fieldnames=cols)
        writer.writeheader()
        writer.writerows(rows)


def save_json_rows(path: str, rows: List[Dict[str, Any]]):
    ensure_dir(os.path.dirname(path) or ".")
    with open(path, "w", encoding="utf-8") as f:
        json.dump(rows, f, ensure_ascii=False, indent=2)


# ============================================================
# Args
# ============================================================

def parse_args():
    p = argparse.ArgumentParser(add_help=True)

    p.add_argument("--device", type=str, default=None, help="cuda:0 / cpu / auto(None)")
    p.add_argument("--amp", action="store_true", help="use amp on cuda")
    p.add_argument("--no-amp", dest="amp", action="store_false")
    p.set_defaults(amp=USE_AMP_DEFAULT)

    p.add_argument("--compile", action="store_true")
    p.add_argument("--resume", action="store_true")

    p.add_argument(
        "--presets",
        type=str,
        default="cartpole_reliable,acrobot_reliable,mountaincar_reliable",
        help="comma-separated preset names",
    )
    p.add_argument("--seeds", type=str, default="0,1,2")
    p.add_argument("--total-episodes", type=int, default=None)

    p.add_argument("--eval-every", type=int, default=250)
    p.add_argument("--eval-episodes", type=int, default=10)
    p.add_argument("--save-every", type=int, default=250)
    p.add_argument("--log-every", type=int, default=20)

    p.add_argument("--ckpt-dir", type=str, default="./checkpoints_robust_recurrent_ppo")
    p.add_argument("--raw-csv", type=str, default="./robust_recurrent_ppo_raw.csv")
    p.add_argument("--summary-csv", type=str, default="./robust_recurrent_ppo_summary.csv")
    p.add_argument("--raw-json", type=str, default="./robust_recurrent_ppo_raw.json")
    p.add_argument("--summary-json", type=str, default="./robust_recurrent_ppo_summary.json")

    # 노트북 끝나면 안전 종료
    p.add_argument("--shutdown-kernel-on-finish", action="store_true")

    # notebook 안전
    args, _unknown = p.parse_known_args()
    return args


# ============================================================
# Main
# ============================================================

def main():
    args = parse_args()
    presets_map = get_presets()

    if args.device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    else:
        device = torch.device(args.device)

    if device.type == "cuda":
        torch.backends.cudnn.benchmark = True
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True

    preset_names = [x.strip() for x in args.presets.split(",") if x.strip()]
    seeds = [int(x.strip()) for x in args.seeds.split(",") if x.strip()]

    selected_presets = []
    for name in preset_names:
        if name not in presets_map:
            raise ValueError(f"unknown preset: {name}. available={list(presets_map.keys())}")
        selected_presets.append(presets_map[name])

    print("============================================================")
    print("device       =", device)
    print("amp          =", bool(args.amp and device.type == "cuda"))
    print("compile      =", args.compile)
    print("presets      =", [p.name for p in selected_presets])
    print("seeds        =", seeds)
    print("episodes     =", args.total_episodes, "(None이면 preset recommended_episodes)")
    print("============================================================")

    raw_results = []
    started = time.time()

    try:
        for preset in selected_presets:
            for seed in seeds:
                if STOP_REQUESTED:
                    break

                print(f"\n===== RUN preset={preset.name} seed={seed} =====")
                result = run_experiment(
                    preset=preset,
                    seed=seed,
                    total_episodes_override=args.total_episodes,
                    eval_every=int(args.eval_every),
                    eval_episodes=int(args.eval_episodes),
                    save_every=int(args.save_every),
                    log_every=int(args.log_every),
                    device=device,
                    ckpt_dir=args.ckpt_dir,
                    compile_models=args.compile,
                    resume=args.resume,
                    amp=args.amp,
                )
                raw_results.append(result)

            if STOP_REQUESTED:
                break

    finally:
        summary = aggregate_results(raw_results)

        save_csv(args.raw_csv, raw_results)
        save_csv(args.summary_csv, summary)
        save_json_rows(args.raw_json, raw_results)
        save_json_rows(args.summary_json, summary)

        elapsed = time.time() - started

        print("\n================ FINAL SUMMARY ================")
        if summary:
            cols = [
                "preset", "n_seeds", "episodes_completed",
                "auc_mean", "last100_mean", "best_reward",
                "first_solve_ep", "eval_mean", "eval_std"
            ]
            widths = {c: max(len(c), max(len(str(r.get(c, ""))) for r in summary)) for c in cols}
            header = " | ".join(c.ljust(widths[c]) for c in cols)
            sep = "-+-".join("-" * widths[c] for c in cols)
            print(header)
            print(sep)

            for r in summary:
                pr = dict(r)
                for k in ["episodes_completed", "n_seeds", "first_solve_ep"]:
                    if k in pr:
                        pr[k] = int(float(pr[k]))
                for k in ["auc_mean", "last100_mean", "best_reward", "eval_mean", "eval_std"]:
                    if k in pr:
                        pr[k] = f"{float(pr[k]):.3f}"
                print(" | ".join(str(pr.get(c, "")).ljust(widths[c]) for c in cols))
        else:
            print("(no results)")

        print("\nraw csv     :", args.raw_csv)
        print("summary csv :", args.summary_csv)
        print("raw json    :", args.raw_json)
        print("summary json:", args.summary_json)
        print(f"elapsed_sec : {elapsed:.2f}")

        print("\n[recommended run]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_reliable,acrobot_reliable,mountaincar_reliable "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[more POMDP]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_medium,acrobot_medium,mountaincar_medium "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[hard partial test]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_partial_hard "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[important note]")
        print(
            "이 코드는 학습 안정성을 위해 reward shaping(train only)과 "
            "POMDP severity curriculum을 사용한다. "
            "평가/summary는 raw reward 기준으로 기록된다."
        )

        cleanup_torch(device)
        maybe_shutdown_kernel(bool(args.shutdown_kernel_on_finish))


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# device       = cuda:0
# amp          = True
# compile      = False
# presets      = ['cartpole_reliable', 'acrobot_reliable', 'mountaincar_reliable']
# seeds        = [0, 1, 2]
# episodes     = None (None이면 preset recommended_episodes)
# ============================================================
#
# ===== RUN preset=cartpole_reliable seed=0 =====
# [cartpole_reliable seed=0] ep=00000 rawR=  47.000 trainR=  47.279 recent20=  47.000 flicker=0.000 noise=0.0000 lr=0.000300 global_step=47
# [cartpole_reliable seed=0] ep=00020 rawR=  13.000 trainR=  13.045 recent20=  20.150 flicker=0.000 noise=0.0000 lr=0.000299 global_step=450
# [cartpole_reliable seed=0] ep=00040 rawR=  26.000 trainR=  26.131 recent20=  21.750 flicker=0.000 noise=0.0000 lr=0.000298 global_step=885
# [update] cartpole_reliable seed=0 loss=21.7917 policy=0.0292 value=43.5524 entropy=0.6931 kl=0.0002 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00060 rawR=  20.000 trainR=  20.109 recent20=  23.050 flicker=0.000 noise=0.0000 lr=0.000296 global_step=1346
# [cartpole_reliable seed=0] ep=00080 rawR=  15.000 trainR=  15.077 recent20=  21.550 flicker=0.001 noise=0.0001 lr=0.000295 global_step=1777
# [update] cartpole_reliable seed=0 loss=19.6600 policy=0.0021 value=39.3428 entropy=0.6919 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00100 rawR=  49.000 trainR=  49.181 recent20=  22.700 flicker=0.001 noise=0.0001 lr=0.000294 global_step=2231
# [cartpole_reliable seed=0] ep=00120 rawR=  15.000 trainR=  15.074 recent20=  23.900 flicker=0.001 noise=0.0001 lr=0.000293 global_step=2709
# [update] cartpole_reliable seed=0 loss=24.3612 policy=0.0214 value=48.7062 entropy=0.6859 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00140 rawR=  36.000 trainR=  36.200 recent20=  38.100 flicker=0.001 noise=0.0001 lr=0.000292 global_step=3471
# [cartpole_reliable seed=0] ep=00160 rawR=  42.000 trainR=  42.223 recent20=  31.100 flicker=0.001 noise=0.0001 lr=0.000290 global_step=4093
# [update] cartpole_reliable seed=0 loss=29.8284 policy=0.0021 value=59.6784 entropy=0.6703 kl=0.0016 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00180 rawR=  17.000 trainR=  17.104 recent20=  38.400 flicker=0.001 noise=0.0001 lr=0.000289 global_step=4861
# [update] cartpole_reliable seed=0 loss=30.2236 policy=0.0223 value=60.4270 entropy=0.6400 kl=0.0035 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00200 rawR=  37.000 trainR=  37.162 recent20=  38.400 flicker=0.002 noise=0.0002 lr=0.000288 global_step=5629
# [update] cartpole_reliable seed=0 loss=31.5194 policy=0.0056 value=63.0516 entropy=0.6352 kl=0.0000 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00220 rawR=  30.000 trainR=  30.196 recent20=  49.350 flicker=0.002 noise=0.0002 lr=0.000287 global_step=6616
# [update] cartpole_reliable seed=0 loss=40.2616 policy=0.0074 value=80.5323 entropy=0.6319 kl=0.0002 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00240 rawR=  49.000 trainR=  49.313 recent20=  64.350 flicker=0.002 noise=0.0002 lr=0.000286 global_step=7903
# [update] cartpole_reliable seed=0 loss=34.2608 policy=0.0473 value=68.4505 entropy=0.6235 kl=-0.0011 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=250 mean=89.100 std=25.782
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=00260 rawR=  63.000 trainR=  63.377 recent20=  64.650 flicker=0.002 noise=0.0002 lr=0.000284 global_step=9196
# [update] cartpole_reliable seed=0 loss=34.9190 policy=0.1224 value=69.6165 entropy=0.6205 kl=-0.0008 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=36.6668 policy=0.0441 value=73.2688 entropy=0.6266 kl=0.0015 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00280 rawR= 105.000 trainR= 105.515 recent20=  70.550 flicker=0.002 noise=0.0002 lr=0.000283 global_step=10607
# [update] cartpole_reliable seed=0 loss=37.3049 policy=0.0173 value=74.5985 entropy=0.6276 kl=-0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00300 rawR=  71.000 trainR=  71.254 recent20=  63.000 flicker=0.002 noise=0.0002 lr=0.000282 global_step=11867
# [update] cartpole_reliable seed=0 loss=34.8357 policy=0.0098 value=69.6751 entropy=0.6285 kl=0.0002 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=33.7837 policy=0.0740 value=67.4424 entropy=0.6258 kl=-0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00320 rawR= 129.000 trainR= 129.529 recent20=  76.700 flicker=0.002 noise=0.0002 lr=0.000281 global_step=13401
# [update] cartpole_reliable seed=0 loss=40.2635 policy=0.0135 value=80.5232 entropy=0.6314 kl=0.0006 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=44.8575 policy=-0.0043 value=89.7471 entropy=0.6381 kl=-0.0007 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00340 rawR=  53.000 trainR=  53.284 recent20= 109.850 flicker=0.003 noise=0.0003 lr=0.000280 global_step=15598
# [update] cartpole_reliable seed=0 loss=33.5144 policy=0.0876 value=66.8768 entropy=0.6306 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00360 rawR=  77.000 trainR=  77.320 recent20=  74.650 flicker=0.003 noise=0.0003 lr=0.000278 global_step=17091
# [update] cartpole_reliable seed=0 loss=35.0739 policy=0.0330 value=70.1047 entropy=0.6261 kl=-0.0002 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=36.4197 policy=0.0647 value=72.7330 entropy=0.6284 kl=-0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00380 rawR= 203.000 trainR= 203.413 recent20=  94.100 flicker=0.003 noise=0.0003 lr=0.000277 global_step=18973
# [update] cartpole_reliable seed=0 loss=34.9671 policy=0.0307 value=69.8950 entropy=0.6133 kl=0.0014 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=32.7281 policy=0.1011 value=65.2762 entropy=0.6133 kl=0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00400 rawR= 212.000 trainR= 211.729 recent20=  86.600 flicker=0.003 noise=0.0003 lr=0.000276 global_step=20705
# [update] cartpole_reliable seed=0 loss=41.3984 policy=0.0214 value=82.7776 entropy=0.6554 kl=0.0062 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00420 rawR=  55.000 trainR=  55.346 recent20=  81.900 flicker=0.003 noise=0.0003 lr=0.000275 global_step=22343
# [update] cartpole_reliable seed=0 loss=27.7446 policy=0.0774 value=55.3573 entropy=0.6389 kl=-0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00440 rawR=  44.000 trainR=  44.246 recent20=  59.400 flicker=0.003 noise=0.0003 lr=0.000274 global_step=23531
# [update] cartpole_reliable seed=0 loss=26.7483 policy=0.0402 value=53.4389 entropy=0.6364 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00460 rawR=  34.000 trainR=  34.167 recent20=  47.900 flicker=0.003 noise=0.0003 lr=0.000272 global_step=24489
# [update] cartpole_reliable seed=0 loss=24.5240 policy=0.0476 value=48.9752 entropy=0.6286 kl=0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00480 rawR=  43.000 trainR=  43.209 recent20=  46.850 flicker=0.004 noise=0.0004 lr=0.000271 global_step=25426
# [update] cartpole_reliable seed=0 loss=24.2882 policy=0.0513 value=48.4961 entropy=0.6294 kl=-0.0003 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=28.9428 policy=0.3894 value=57.1276 entropy=0.5924 kl=0.0106 early_stop_kl=1
# [eval] cartpole_reliable seed=0 ep=500 mean=218.300 std=11.073
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=00500 rawR=  14.000 trainR=  14.081 recent20=  71.900 flicker=0.004 noise=0.0004 lr=0.000270 global_step=26864
# [update] cartpole_reliable seed=0 loss=34.6942 policy=0.0677 value=69.2749 entropy=0.6223 kl=0.0033 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00520 rawR=  30.000 trainR=  30.125 recent20=  75.950 flicker=0.004 noise=0.0004 lr=0.000269 global_step=28383
# [update] cartpole_reliable seed=0 loss=23.7375 policy=0.0144 value=47.4680 entropy=0.6228 kl=0.0026 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00540 rawR=  25.000 trainR=  25.067 recent20=  54.000 flicker=0.004 noise=0.0004 lr=0.000268 global_step=29463
# [update] cartpole_reliable seed=0 loss=25.4292 policy=0.1355 value=50.6097 entropy=0.6422 kl=0.0041 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00560 rawR=  49.000 trainR=  49.192 recent20=  47.600 flicker=0.004 noise=0.0004 lr=0.000266 global_step=30415
# [update] cartpole_reliable seed=0 loss=21.3086 policy=0.0737 value=42.4919 entropy=0.6358 kl=-0.0012 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00580 rawR=  35.000 trainR=  35.127 recent20=  48.500 flicker=0.004 noise=0.0004 lr=0.000265 global_step=31385
# [update] cartpole_reliable seed=0 loss=24.1152 policy=0.1375 value=47.9765 entropy=0.6116 kl=0.0001 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00600 rawR=  73.000 trainR=  73.033 recent20=  66.400 flicker=0.005 noise=0.0005 lr=0.000264 global_step=32713
# [update] cartpole_reliable seed=0 loss=28.0333 policy=0.0317 value=56.0248 entropy=0.6319 kl=0.0029 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00620 rawR= 113.000 trainR= 112.966 recent20=  52.350 flicker=0.005 noise=0.0005 lr=0.000263 global_step=33760
# [update] cartpole_reliable seed=0 loss=23.3532 policy=0.0583 value=46.6106 entropy=0.6082 kl=0.0034 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=25.3495 policy=0.0553 value=50.6096 entropy=0.6233 kl=0.0085 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00640 rawR=  74.000 trainR=  74.109 recent20=  64.800 flicker=0.005 noise=0.0005 lr=0.000262 global_step=35056
# [update] cartpole_reliable seed=0 loss=24.8198 policy=0.0848 value=49.4915 entropy=0.6337 kl=0.0021 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00660 rawR= 107.000 trainR= 106.959 recent20=  61.200 flicker=0.005 noise=0.0005 lr=0.000260 global_step=36280
# [update] cartpole_reliable seed=0 loss=23.2729 policy=0.1097 value=46.3474 entropy=0.6214 kl=-0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00680 rawR=  95.000 trainR=  95.532 recent20=  55.950 flicker=0.005 noise=0.0005 lr=0.000259 global_step=37399
# [update] cartpole_reliable seed=0 loss=22.8986 policy=0.3443 value=45.1293 entropy=0.6152 kl=0.0041 early_stop_kl=1
# [cartpole_reliable seed=0] ep=00700 rawR=  30.000 trainR=  30.156 recent20=  48.100 flicker=0.005 noise=0.0005 lr=0.000258 global_step=38361
# [update] cartpole_reliable seed=0 loss=25.7941 policy=0.2084 value=51.1919 entropy=0.6166 kl=0.0053 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=28.8196 policy=0.0720 value=57.5163 entropy=0.6319 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00720 rawR=  21.000 trainR=  21.115 recent20=  78.800 flicker=0.005 noise=0.0005 lr=0.000257 global_step=39937
# [update] cartpole_reliable seed=0 loss=27.7119 policy=0.0449 value=55.3548 entropy=0.6297 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00740 rawR=  23.000 trainR=  23.079 recent20=  66.900 flicker=0.006 noise=0.0006 lr=0.000256 global_step=41275
# [eval] cartpole_reliable seed=0 ep=750 mean=158.500 std=8.176
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [update] cartpole_reliable seed=0 loss=24.2509 policy=0.0931 value=48.3362 entropy=0.6277 kl=-0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00760 rawR=  39.000 trainR=  39.136 recent20=  49.800 flicker=0.006 noise=0.0006 lr=0.000254 global_step=42271
# [update] cartpole_reliable seed=0 loss=21.7366 policy=0.0931 value=43.3064 entropy=0.5942 kl=0.0036 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00780 rawR= 112.000 trainR= 111.976 recent20=  56.400 flicker=0.006 noise=0.0006 lr=0.000253 global_step=43399
# [update] cartpole_reliable seed=0 loss=24.7118 policy=0.3309 value=48.7817 entropy=0.6107 kl=0.0028 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00800 rawR=  54.000 trainR=  54.250 recent20=  81.500 flicker=0.006 noise=0.0006 lr=0.000252 global_step=45029
# [update] cartpole_reliable seed=0 loss=31.8255 policy=0.0728 value=63.5258 entropy=0.6300 kl=0.0026 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.0379 policy=0.0380 value=52.0196 entropy=0.6176 kl=0.0025 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00820 rawR= 151.000 trainR= 151.572 recent20=  78.500 flicker=0.006 noise=0.0006 lr=0.000251 global_step=46599
# [update] cartpole_reliable seed=0 loss=28.0028 policy=0.1996 value=55.6263 entropy=0.6196 kl=0.0028 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00840 rawR=  87.000 trainR=  87.118 recent20=  69.950 flicker=0.006 noise=0.0006 lr=0.000250 global_step=47998
# [update] cartpole_reliable seed=0 loss=24.0295 policy=0.0669 value=47.9448 entropy=0.6191 kl=-0.0001 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.5323 policy=0.0195 value=55.0451 entropy=0.6146 kl=0.0016 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00860 rawR=  59.000 trainR=  59.088 recent20=  59.950 flicker=0.006 noise=0.0006 lr=0.000248 global_step=49197
# [update] cartpole_reliable seed=0 loss=25.8778 policy=0.0943 value=51.5865 entropy=0.6121 kl=0.0030 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00880 rawR=  18.000 trainR=  18.093 recent20=  66.950 flicker=0.007 noise=0.0007 lr=0.000247 global_step=50536
# [update] cartpole_reliable seed=0 loss=23.8177 policy=0.0261 value=47.6020 entropy=0.5996 kl=-0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00900 rawR=  28.000 trainR=  28.196 recent20=  62.400 flicker=0.007 noise=0.0007 lr=0.000246 global_step=51784
# [update] cartpole_reliable seed=0 loss=26.1428 policy=0.1921 value=51.9198 entropy=0.5902 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00920 rawR=  59.000 trainR=  59.167 recent20=  58.200 flicker=0.007 noise=0.0007 lr=0.000245 global_step=52948
# [update] cartpole_reliable seed=0 loss=24.5947 policy=-0.0118 value=49.2322 entropy=0.6136 kl=0.0027 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00940 rawR=  25.000 trainR=  25.100 recent20=  60.000 flicker=0.007 noise=0.0007 lr=0.000244 global_step=54148
# [update] cartpole_reliable seed=0 loss=25.1077 policy=0.1056 value=50.0234 entropy=0.6146 kl=0.0012 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00960 rawR= 104.000 trainR= 103.730 recent20=  46.450 flicker=0.007 noise=0.0007 lr=0.000242 global_step=55077
# [update] cartpole_reliable seed=0 loss=20.0003 policy=0.0463 value=39.9259 entropy=0.5809 kl=0.0023 early_stop_kl=0
# [cartpole_reliable seed=0] ep=00980 rawR= 153.000 trainR= 152.978 recent20=  60.450 flicker=0.007 noise=0.0007 lr=0.000241 global_step=56286
# [update] cartpole_reliable seed=0 loss=26.5160 policy=0.0618 value=52.9272 entropy=0.6147 kl=0.0051 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=1000 mean=103.300 std=1.269
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=01000 rawR=  48.000 trainR=  48.174 recent20=  37.000 flicker=0.008 noise=0.0008 lr=0.000240 global_step=57026
# [update] cartpole_reliable seed=0 loss=22.3130 policy=0.0746 value=44.4949 entropy=0.5945 kl=0.0038 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01020 rawR=  35.000 trainR=  35.179 recent20=  62.750 flicker=0.008 noise=0.0008 lr=0.000239 global_step=58281
# [update] cartpole_reliable seed=0 loss=27.2421 policy=0.4034 value=53.6953 entropy=0.5936 kl=0.0048 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01040 rawR=  57.000 trainR=  57.220 recent20=  46.250 flicker=0.008 noise=0.0008 lr=0.000238 global_step=59206
# [update] cartpole_reliable seed=0 loss=22.9542 policy=0.0813 value=45.7636 entropy=0.5941 kl=0.0020 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01060 rawR=  11.000 trainR=  11.036 recent20=  42.300 flicker=0.008 noise=0.0008 lr=0.000236 global_step=60052
# [update] cartpole_reliable seed=0 loss=23.5747 policy=0.0375 value=47.0922 entropy=0.6015 kl=0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01080 rawR=  24.000 trainR=  24.110 recent20=  49.200 flicker=0.008 noise=0.0008 lr=0.000235 global_step=61036
# [update] cartpole_reliable seed=0 loss=24.1797 policy=0.1713 value=48.0345 entropy=0.5935 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01100 rawR=  17.000 trainR=  17.065 recent20=  56.200 flicker=0.008 noise=0.0008 lr=0.000234 global_step=62160
# [update] cartpole_reliable seed=0 loss=23.2958 policy=0.1554 value=46.2978 entropy=0.5766 kl=0.0089 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01120 rawR=  68.000 trainR=  68.359 recent20=  57.900 flicker=0.008 noise=0.0008 lr=0.000233 global_step=63318
# [update] cartpole_reliable seed=0 loss=26.3089 policy=0.0061 value=52.6228 entropy=0.5865 kl=-0.0001 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=25.5949 policy=0.2794 value=50.6484 entropy=0.5955 kl=-0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01140 rawR=  47.000 trainR=  47.116 recent20=  82.450 flicker=0.009 noise=0.0009 lr=0.000232 global_step=64967
# [update] cartpole_reliable seed=0 loss=27.3864 policy=0.1035 value=54.5839 entropy=0.6225 kl=0.0070 early_stop_kl=1
# [cartpole_reliable seed=0] ep=01160 rawR=  31.000 trainR=  31.120 recent20=  74.200 flicker=0.009 noise=0.0009 lr=0.000230 global_step=66451
# [update] cartpole_reliable seed=0 loss=25.5960 policy=0.0544 value=51.1015 entropy=0.6281 kl=0.0020 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.2097 policy=0.1135 value=52.2101 entropy=0.6103 kl=-0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01180 rawR= 142.000 trainR= 141.857 recent20=  75.000 flicker=0.009 noise=0.0009 lr=0.000229 global_step=67951
# [update] cartpole_reliable seed=0 loss=28.0186 policy=0.2070 value=55.6405 entropy=0.6006 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01200 rawR=  21.000 trainR=  21.100 recent20=  74.700 flicker=0.009 noise=0.0009 lr=0.000228 global_step=69445
# [update] cartpole_reliable seed=0 loss=27.0794 policy=0.0656 value=54.0449 entropy=0.6043 kl=0.0031 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01220 rawR=  15.000 trainR=  15.067 recent20=  58.550 flicker=0.009 noise=0.0009 lr=0.000227 global_step=70616
# [update] cartpole_reliable seed=0 loss=26.0565 policy=-0.0121 value=52.1546 entropy=0.6098 kl=0.0042 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01240 rawR=  22.000 trainR=  22.104 recent20=  50.700 flicker=0.009 noise=0.0009 lr=0.000226 global_step=71630
# [update] cartpole_reliable seed=0 loss=24.7648 policy=0.2572 value=49.0316 entropy=0.5823 kl=0.0036 early_stop_kl=1
# [eval] cartpole_reliable seed=0 ep=1250 mean=107.800 std=3.124
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=01260 rawR=  33.000 trainR=  33.206 recent20=  53.050 flicker=0.009 noise=0.0009 lr=0.000224 global_step=72691
# [update] cartpole_reliable seed=0 loss=25.7936 policy=0.0380 value=51.5283 entropy=0.6142 kl=0.0024 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.7776 policy=0.0085 value=53.5556 entropy=0.6234 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01280 rawR= 113.000 trainR= 112.594 recent20=  69.950 flicker=0.010 noise=0.0010 lr=0.000223 global_step=74090
# [update] cartpole_reliable seed=0 loss=24.4932 policy=0.0858 value=48.8318 entropy=0.6125 kl=0.0007 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01300 rawR=  10.000 trainR=  10.046 recent20=  51.800 flicker=0.010 noise=0.0010 lr=0.000222 global_step=75126
# [update] cartpole_reliable seed=0 loss=27.3503 policy=0.0679 value=54.5815 entropy=0.6084 kl=0.0021 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01320 rawR=  18.000 trainR=  18.088 recent20=  50.000 flicker=0.010 noise=0.0010 lr=0.000221 global_step=76126
# [update] cartpole_reliable seed=0 loss=24.4477 policy=0.0291 value=48.8537 entropy=0.5998 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01340 rawR=  72.000 trainR=  72.341 recent20=  59.550 flicker=0.010 noise=0.0010 lr=0.000220 global_step=77317
# [update] cartpole_reliable seed=0 loss=24.9739 policy=0.2311 value=49.5016 entropy=0.5894 kl=0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01360 rawR=  18.000 trainR=  18.085 recent20=  67.150 flicker=0.010 noise=0.0010 lr=0.000218 global_step=78660
# [update] cartpole_reliable seed=0 loss=26.0980 policy=0.0583 value=52.0956 entropy=0.5982 kl=0.0003 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=23.4557 policy=0.0725 value=46.7822 entropy=0.5876 kl=0.0020 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01380 rawR=  14.000 trainR=  14.073 recent20=  62.550 flicker=0.010 noise=0.0010 lr=0.000217 global_step=79911
# [update] cartpole_reliable seed=0 loss=24.3480 policy=0.0140 value=48.6846 entropy=0.6211 kl=0.0017 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01400 rawR=  32.000 trainR=  32.228 recent20=  68.900 flicker=0.011 noise=0.0011 lr=0.000216 global_step=81289
# [update] cartpole_reliable seed=0 loss=24.9516 policy=0.1422 value=49.6345 entropy=0.5858 kl=0.0055 early_stop_kl=1
# [cartpole_reliable seed=0] ep=01420 rawR=  49.000 trainR=  49.222 recent20=  69.200 flicker=0.011 noise=0.0011 lr=0.000215 global_step=82673
# [update] cartpole_reliable seed=0 loss=26.2938 policy=0.0285 value=52.5465 entropy=0.6000 kl=0.0035 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.2057 policy=0.0417 value=52.3442 entropy=0.6184 kl=0.0036 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01440 rawR= 135.000 trainR= 134.420 recent20=  97.100 flicker=0.011 noise=0.0011 lr=0.000214 global_step=84615
# [update] cartpole_reliable seed=0 loss=27.1338 policy=0.1775 value=53.9283 entropy=0.5940 kl=-0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01460 rawR= 104.000 trainR= 103.607 recent20=  61.000 flicker=0.011 noise=0.0011 lr=0.000212 global_step=85835
# [update] cartpole_reliable seed=0 loss=25.2902 policy=0.0184 value=50.5591 entropy=0.5935 kl=0.0015 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.3633 policy=0.0952 value=54.5514 entropy=0.5873 kl=0.0069 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01480 rawR=  77.000 trainR=  77.278 recent20=  64.900 flicker=0.011 noise=0.0011 lr=0.000211 global_step=87133
# [update] cartpole_reliable seed=0 loss=25.1391 policy=0.0228 value=50.2481 entropy=0.5954 kl=0.0026 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=1500 mean=113.400 std=2.498
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=01500 rawR=  14.000 trainR=  14.065 recent20=  62.700 flicker=0.011 noise=0.0011 lr=0.000210 global_step=88387
# [update] cartpole_reliable seed=0 loss=27.2335 policy=0.1624 value=54.1574 entropy=0.5878 kl=-0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01520 rawR=  20.000 trainR=  20.085 recent20=  51.900 flicker=0.011 noise=0.0011 lr=0.000209 global_step=89425
# [update] cartpole_reliable seed=0 loss=24.5483 policy=0.0486 value=49.0146 entropy=0.5980 kl=0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01540 rawR=  19.000 trainR=  19.093 recent20=  62.350 flicker=0.012 noise=0.0012 lr=0.000208 global_step=90672
# [update] cartpole_reliable seed=0 loss=24.2033 policy=0.0720 value=48.2777 entropy=0.5937 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01560 rawR=  18.000 trainR=  18.097 recent20=  44.500 flicker=0.012 noise=0.0012 lr=0.000206 global_step=91562
# [update] cartpole_reliable seed=0 loss=26.6426 policy=0.1399 value=53.0203 entropy=0.5917 kl=0.0034 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01580 rawR= 128.000 trainR= 127.427 recent20=  64.950 flicker=0.012 noise=0.0012 lr=0.000205 global_step=92861
# [update] cartpole_reliable seed=0 loss=23.8093 policy=0.0575 value=47.5189 entropy=0.6174 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01600 rawR=  51.000 trainR=  51.269 recent20=  58.800 flicker=0.012 noise=0.0012 lr=0.000204 global_step=94037
# [update] cartpole_reliable seed=0 loss=26.0107 policy=0.2278 value=51.5804 entropy=0.5864 kl=0.0024 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=24.2772 policy=0.0161 value=48.5372 entropy=0.6084 kl=0.0038 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01620 rawR= 105.000 trainR= 105.255 recent20=  69.350 flicker=0.012 noise=0.0012 lr=0.000203 global_step=95424
# [update] cartpole_reliable seed=0 loss=28.4826 policy=0.0593 value=56.8615 entropy=0.6099 kl=0.0016 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01640 rawR= 113.000 trainR= 113.039 recent20=  55.650 flicker=0.012 noise=0.0012 lr=0.000202 global_step=96537
# [update] cartpole_reliable seed=0 loss=26.4740 policy=0.0115 value=52.9394 entropy=0.5993 kl=0.0024 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01660 rawR=  28.000 trainR=  28.086 recent20=  65.700 flicker=0.012 noise=0.0012 lr=0.000200 global_step=97851
# [update] cartpole_reliable seed=0 loss=27.2790 policy=0.0384 value=54.4958 entropy=0.6047 kl=0.0007 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=30.2805 policy=0.1653 value=60.2447 entropy=0.5934 kl=0.0027 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01680 rawR= 143.000 trainR= 142.923 recent20=  93.300 flicker=0.013 noise=0.0013 lr=0.000199 global_step=99717
# [update] cartpole_reliable seed=0 loss=28.2656 policy=0.0132 value=56.5189 entropy=0.5838 kl=0.0015 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01700 rawR=  13.000 trainR=  13.055 recent20=  51.250 flicker=0.013 noise=0.0013 lr=0.000198 global_step=100742
# [update] cartpole_reliable seed=0 loss=26.8356 policy=0.0404 value=53.6041 entropy=0.5745 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01720 rawR=  99.000 trainR=  99.288 recent20=  74.900 flicker=0.013 noise=0.0013 lr=0.000197 global_step=102240
# [update] cartpole_reliable seed=0 loss=28.3031 policy=0.1038 value=56.4131 entropy=0.6107 kl=0.0005 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.3100 policy=0.0817 value=54.4707 entropy=0.5971 kl=0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01740 rawR=  84.000 trainR=  84.021 recent20=  83.850 flicker=0.013 noise=0.0013 lr=0.000196 global_step=103917
# [update] cartpole_reliable seed=0 loss=25.7299 policy=0.0373 value=51.3994 entropy=0.6064 kl=0.0020 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=1750 mean=124.700 std=4.076
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=01760 rawR=  86.000 trainR=  86.098 recent20=  63.800 flicker=0.013 noise=0.0013 lr=0.000194 global_step=105193
# [update] cartpole_reliable seed=0 loss=31.4648 policy=0.2002 value=62.5425 entropy=0.5731 kl=0.0041 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01780 rawR=  66.000 trainR=  66.089 recent20=  60.400 flicker=0.013 noise=0.0013 lr=0.000193 global_step=106401
# [update] cartpole_reliable seed=0 loss=29.8345 policy=0.3914 value=58.8997 entropy=0.5920 kl=0.0013 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.4061 policy=0.1273 value=54.5710 entropy=0.5875 kl=0.0002 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01800 rawR=  15.000 trainR=  15.079 recent20=  57.900 flicker=0.014 noise=0.0014 lr=0.000192 global_step=107559
# [cartpole_reliable seed=0] ep=01820 rawR= 161.000 trainR= 160.089 recent20=  43.500 flicker=0.014 noise=0.0014 lr=0.000191 global_step=108429
# [update] cartpole_reliable seed=0 loss=32.0266 policy=0.2678 value=63.5301 entropy=0.5568 kl=0.0047 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.8063 policy=0.0440 value=53.5383 entropy=0.6032 kl=0.0010 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01840 rawR= 161.000 trainR= 160.372 recent20=  85.900 flicker=0.014 noise=0.0014 lr=0.000190 global_step=110147
# [update] cartpole_reliable seed=0 loss=26.4631 policy=0.0692 value=52.8010 entropy=0.5872 kl=0.0018 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=29.7763 policy=0.3578 value=58.8495 entropy=0.5616 kl=-0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01860 rawR= 123.000 trainR= 122.482 recent20=  77.200 flicker=0.014 noise=0.0014 lr=0.000188 global_step=111691
# [update] cartpole_reliable seed=0 loss=24.6468 policy=0.0338 value=49.2391 entropy=0.5942 kl=0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01880 rawR=  10.000 trainR=  10.031 recent20=  59.900 flicker=0.014 noise=0.0014 lr=0.000187 global_step=112889
# [update] cartpole_reliable seed=0 loss=25.2456 policy=0.0271 value=50.4504 entropy=0.6020 kl=0.0003 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=25.0245 policy=0.0382 value=49.9858 entropy=0.6020 kl=-0.0000 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01900 rawR= 111.000 trainR= 110.744 recent20=  93.100 flicker=0.014 noise=0.0014 lr=0.000186 global_step=114751
# [update] cartpole_reliable seed=0 loss=26.4758 policy=0.1854 value=52.5942 entropy=0.6094 kl=0.0012 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01920 rawR=  58.000 trainR=  58.215 recent20=  67.200 flicker=0.014 noise=0.0014 lr=0.000185 global_step=116095
# [update] cartpole_reliable seed=0 loss=28.8811 policy=0.0814 value=57.6122 entropy=0.5956 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01940 rawR= 119.000 trainR= 118.724 recent20=  71.800 flicker=0.015 noise=0.0015 lr=0.000184 global_step=117531
# [update] cartpole_reliable seed=0 loss=24.8070 policy=0.0960 value=49.4351 entropy=0.6093 kl=0.0010 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01960 rawR=  34.000 trainR=  34.199 recent20=  53.900 flicker=0.015 noise=0.0015 lr=0.000182 global_step=118609
# [update] cartpole_reliable seed=0 loss=29.2359 policy=0.1700 value=58.1445 entropy=0.5881 kl=0.0013 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=29.8630 policy=0.1872 value=59.3644 entropy=0.5970 kl=0.0012 early_stop_kl=0
# [cartpole_reliable seed=0] ep=01980 rawR= 106.000 trainR= 105.649 recent20=  93.000 flicker=0.015 noise=0.0015 lr=0.000181 global_step=120469
# [update] cartpole_reliable seed=0 loss=24.8903 policy=0.1303 value=49.5330 entropy=0.6081 kl=-0.0014 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=21.0912 policy=0.0059 value=42.1833 entropy=0.6102 kl=0.0011 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=2000 mean=135.300 std=3.822
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=02000 rawR=  36.000 trainR=  36.188 recent20=  72.650 flicker=0.015 noise=0.0015 lr=0.000180 global_step=121922
# [cartpole_reliable seed=0] ep=02020 rawR=  19.000 trainR=  19.105 recent20=  44.400 flicker=0.015 noise=0.0015 lr=0.000179 global_step=122810
# [update] cartpole_reliable seed=0 loss=30.9452 policy=0.0302 value=61.8422 entropy=0.5879 kl=0.0021 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=32.0670 policy=0.1253 value=63.8956 entropy=0.5899 kl=0.0015 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02040 rawR= 103.000 trainR= 102.750 recent20=  67.350 flicker=0.015 noise=0.0015 lr=0.000178 global_step=124157
# [update] cartpole_reliable seed=0 loss=27.5837 policy=0.1379 value=54.9035 entropy=0.5830 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02060 rawR=  36.000 trainR=  36.190 recent20=  51.650 flicker=0.015 noise=0.0015 lr=0.000176 global_step=125190
# [update] cartpole_reliable seed=0 loss=33.6013 policy=0.0210 value=67.1725 entropy=0.5877 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02080 rawR=  58.000 trainR=  58.174 recent20=  41.000 flicker=0.016 noise=0.0016 lr=0.000175 global_step=126010
# [update] cartpole_reliable seed=0 loss=30.4580 policy=-0.0008 value=60.9298 entropy=0.5984 kl=0.0007 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02100 rawR=  95.000 trainR=  94.760 recent20=  52.100 flicker=0.016 noise=0.0016 lr=0.000174 global_step=127052
# [update] cartpole_reliable seed=0 loss=25.4495 policy=0.0222 value=50.8664 entropy=0.6036 kl=0.0001 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02120 rawR=  18.000 trainR=  18.065 recent20=  59.400 flicker=0.016 noise=0.0016 lr=0.000173 global_step=128240
# [update] cartpole_reliable seed=0 loss=29.6046 policy=0.1446 value=58.9316 entropy=0.5898 kl=-0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02140 rawR=  28.000 trainR=  28.170 recent20=  62.800 flicker=0.016 noise=0.0016 lr=0.000172 global_step=129496
# [update] cartpole_reliable seed=0 loss=26.9815 policy=0.1330 value=53.7091 entropy=0.6110 kl=0.0018 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02160 rawR=  15.000 trainR=  15.069 recent20=  72.150 flicker=0.016 noise=0.0016 lr=0.000170 global_step=130939
# [update] cartpole_reliable seed=0 loss=28.7757 policy=0.0345 value=57.4939 entropy=0.5912 kl=0.0004 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02180 rawR=  14.000 trainR=  14.076 recent20=  52.650 flicker=0.016 noise=0.0016 lr=0.000169 global_step=131992
# [update] cartpole_reliable seed=0 loss=27.1614 policy=0.0267 value=54.2807 entropy=0.5954 kl=0.0006 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.4889 policy=0.0252 value=54.9389 entropy=0.6052 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02200 rawR=  81.000 trainR=  81.099 recent20=  58.500 flicker=0.017 noise=0.0017 lr=0.000168 global_step=133162
# [update] cartpole_reliable seed=0 loss=28.2279 policy=0.1508 value=56.1652 entropy=0.5873 kl=0.0013 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02220 rawR=  35.000 trainR=  35.099 recent20=  58.900 flicker=0.017 noise=0.0017 lr=0.000167 global_step=134340
# [update] cartpole_reliable seed=0 loss=29.7971 policy=0.3082 value=58.9890 entropy=0.5982 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02240 rawR=  80.000 trainR=  80.394 recent20=  77.400 flicker=0.017 noise=0.0017 lr=0.000166 global_step=135888
# [update] cartpole_reliable seed=0 loss=30.3389 policy=0.1081 value=60.4728 entropy=0.5988 kl=0.0017 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=2250 mean=104.300 std=3.257
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [update] cartpole_reliable seed=0 loss=31.8583 policy=0.2634 value=63.2005 entropy=0.5750 kl=0.0043 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02260 rawR=  64.000 trainR=  64.260 recent20=  67.100 flicker=0.017 noise=0.0017 lr=0.000164 global_step=137230
# [update] cartpole_reliable seed=0 loss=27.3226 policy=0.0316 value=54.5929 entropy=0.5914 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02280 rawR=  13.000 trainR=  13.050 recent20=  58.600 flicker=0.017 noise=0.0017 lr=0.000163 global_step=138402
# [update] cartpole_reliable seed=0 loss=36.2988 policy=0.3317 value=71.9448 entropy=0.5804 kl=0.0012 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02300 rawR= 130.000 trainR= 129.327 recent20=  83.700 flicker=0.017 noise=0.0017 lr=0.000162 global_step=140076
# [update] cartpole_reliable seed=0 loss=29.7649 policy=0.3024 value=58.9357 entropy=0.5918 kl=0.0018 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02320 rawR=  56.000 trainR=  56.152 recent20=  61.300 flicker=0.017 noise=0.0017 lr=0.000161 global_step=141302
# [update] cartpole_reliable seed=0 loss=30.0718 policy=0.0737 value=60.0066 entropy=0.5866 kl=0.0012 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=25.8777 policy=0.0529 value=51.6600 entropy=0.5909 kl=0.0028 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02340 rawR=  52.000 trainR=  52.092 recent20=  76.900 flicker=0.018 noise=0.0018 lr=0.000160 global_step=142840
# [update] cartpole_reliable seed=0 loss=29.0171 policy=0.0218 value=58.0011 entropy=0.5955 kl=0.0002 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02360 rawR= 111.000 trainR= 111.008 recent20=  63.850 flicker=0.018 noise=0.0018 lr=0.000158 global_step=144117
# [update] cartpole_reliable seed=0 loss=27.7395 policy=0.0263 value=55.4369 entropy=0.5902 kl=0.0042 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02380 rawR=  16.000 trainR=  16.070 recent20=  57.200 flicker=0.018 noise=0.0018 lr=0.000157 global_step=145261
# [update] cartpole_reliable seed=0 loss=28.1978 policy=0.0512 value=56.3033 entropy=0.5883 kl=0.0008 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=29.4646 policy=0.1163 value=58.7066 entropy=0.5819 kl=0.0010 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02400 rawR= 112.000 trainR= 112.472 recent20=  68.000 flicker=0.018 noise=0.0018 lr=0.000156 global_step=146621
# [update] cartpole_reliable seed=0 loss=31.4022 policy=0.1074 value=62.5995 entropy=0.5840 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02420 rawR= 105.000 trainR= 104.750 recent20=  71.350 flicker=0.018 noise=0.0018 lr=0.000155 global_step=148048
# [update] cartpole_reliable seed=0 loss=27.5203 policy=0.1261 value=54.7984 entropy=0.5924 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02440 rawR=  76.000 trainR=  76.043 recent20=  64.450 flicker=0.018 noise=0.0018 lr=0.000154 global_step=149337
# [update] cartpole_reliable seed=0 loss=29.8745 policy=0.1397 value=59.4794 entropy=0.5900 kl=0.0001 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02460 rawR=  47.000 trainR=  47.194 recent20=  56.150 flicker=0.018 noise=0.0018 lr=0.000152 global_step=150460
# [update] cartpole_reliable seed=0 loss=31.6144 policy=0.1833 value=62.8717 entropy=0.5757 kl=0.0007 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.4591 policy=0.0166 value=52.8948 entropy=0.5866 kl=0.0013 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02480 rawR=  18.000 trainR=  18.102 recent20=  54.800 flicker=0.019 noise=0.0019 lr=0.000151 global_step=151556
# [update] cartpole_reliable seed=0 loss=32.1522 policy=0.1956 value=63.9231 entropy=0.6009 kl=0.0010 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=2500 mean=500.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=02500 rawR=  69.000 trainR=  69.192 recent20=  81.500 flicker=0.019 noise=0.0019 lr=0.000150 global_step=153186
# [update] cartpole_reliable seed=0 loss=26.0193 policy=0.0809 value=51.8863 entropy=0.5827 kl=0.0009 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02520 rawR=  28.000 trainR=  28.145 recent20=  56.900 flicker=0.019 noise=0.0019 lr=0.000149 global_step=154324
# [update] cartpole_reliable seed=0 loss=29.6901 policy=0.0037 value=59.3821 entropy=0.5829 kl=0.0019 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02540 rawR=  97.000 trainR=  97.057 recent20=  52.800 flicker=0.019 noise=0.0019 lr=0.000148 global_step=155380
# [update] cartpole_reliable seed=0 loss=27.8699 policy=0.0067 value=55.7356 entropy=0.5743 kl=0.0003 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=24.5258 policy=0.0113 value=49.0381 entropy=0.5764 kl=0.0023 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02560 rawR= 100.000 trainR=  99.569 recent20=  76.050 flicker=0.019 noise=0.0019 lr=0.000146 global_step=156901
# [update] cartpole_reliable seed=0 loss=29.4735 policy=0.1864 value=58.5832 entropy=0.5846 kl=-0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02580 rawR=  85.000 trainR=  85.098 recent20=  72.850 flicker=0.019 noise=0.0019 lr=0.000145 global_step=158358
# [update] cartpole_reliable seed=0 loss=28.5032 policy=0.0055 value=57.0045 entropy=0.5963 kl=0.0020 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02600 rawR=  50.000 trainR=  50.072 recent20=  44.000 flicker=0.020 noise=0.0020 lr=0.000144 global_step=159238
# [update] cartpole_reliable seed=0 loss=37.2725 policy=0.2482 value=74.0572 entropy=0.5631 kl=0.0043 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02620 rawR= 108.000 trainR= 108.319 recent20=  74.850 flicker=0.020 noise=0.0020 lr=0.000143 global_step=160735
# [update] cartpole_reliable seed=0 loss=33.3117 policy=0.1276 value=66.3771 entropy=0.5939 kl=0.0081 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02640 rawR=  30.000 trainR=  30.151 recent20=  42.850 flicker=0.020 noise=0.0020 lr=0.000142 global_step=161592
# [update] cartpole_reliable seed=0 loss=32.4095 policy=0.0304 value=64.7666 entropy=0.5686 kl=0.0017 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02660 rawR=  45.000 trainR=  45.175 recent20=  60.150 flicker=0.020 noise=0.0020 lr=0.000140 global_step=162795
# [update] cartpole_reliable seed=0 loss=33.5835 policy=0.1551 value=66.8653 entropy=0.5845 kl=0.0039 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=23.8198 policy=0.1704 value=47.3073 entropy=0.5912 kl=0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02680 rawR=  23.000 trainR=  23.143 recent20=  72.350 flicker=0.020 noise=0.0020 lr=0.000139 global_step=164242
# [update] cartpole_reliable seed=0 loss=26.3019 policy=0.0089 value=52.5945 entropy=0.5983 kl=0.0022 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02700 rawR=  32.000 trainR=  32.169 recent20=  49.900 flicker=0.020 noise=0.0020 lr=0.000138 global_step=165240
# [update] cartpole_reliable seed=0 loss=36.2049 policy=0.0317 value=72.3545 entropy=0.5706 kl=0.0026 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02720 rawR=  75.000 trainR=  75.201 recent20=  58.400 flicker=0.020 noise=0.0020 lr=0.000137 global_step=166408
# [update] cartpole_reliable seed=0 loss=36.2530 policy=0.2038 value=72.1066 entropy=0.5811 kl=0.0044 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02740 rawR= 177.000 trainR= 176.629 recent20=  48.650 flicker=0.021 noise=0.0021 lr=0.000136 global_step=167381
# [eval] cartpole_reliable seed=0 ep=2750 mean=457.700 std=126.900
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [update] cartpole_reliable seed=0 loss=33.9196 policy=0.0948 value=67.6579 entropy=0.5983 kl=0.0005 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=29.1518 policy=0.2736 value=57.7646 entropy=0.5882 kl=-0.0016 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02760 rawR=  74.000 trainR=  74.082 recent20=  89.650 flicker=0.021 noise=0.0021 lr=0.000134 global_step=169174
# [update] cartpole_reliable seed=0 loss=29.9714 policy=0.1748 value=59.6014 entropy=0.5995 kl=0.0048 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02780 rawR=  18.000 trainR=  18.058 recent20=  70.550 flicker=0.021 noise=0.0021 lr=0.000133 global_step=170585
# [update] cartpole_reliable seed=0 loss=41.1551 policy=0.1264 value=82.0651 entropy=0.5751 kl=0.0048 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02800 rawR=  93.000 trainR=  93.056 recent20=  72.000 flicker=0.021 noise=0.0021 lr=0.000132 global_step=172025
# [update] cartpole_reliable seed=0 loss=30.0055 policy=0.2914 value=59.4362 entropy=0.6014 kl=-0.0003 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=35.9597 policy=0.2896 value=71.3480 entropy=0.5878 kl=0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02820 rawR= 160.000 trainR= 159.921 recent20=  68.200 flicker=0.021 noise=0.0021 lr=0.000131 global_step=173389
# [update] cartpole_reliable seed=0 loss=30.9038 policy=0.0289 value=61.7577 entropy=0.6014 kl=0.0064 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02840 rawR=  34.000 trainR=  34.116 recent20=  48.300 flicker=0.021 noise=0.0021 lr=0.000130 global_step=174355
# [update] cartpole_reliable seed=0 loss=34.8381 policy=0.0310 value=69.6216 entropy=0.5723 kl=0.0010 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02860 rawR=  68.000 trainR=  68.158 recent20=  64.300 flicker=0.021 noise=0.0021 lr=0.000128 global_step=175641
# [update] cartpole_reliable seed=0 loss=36.1979 policy=0.1168 value=72.1698 entropy=0.5851 kl=0.0038 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02880 rawR=  32.000 trainR=  32.066 recent20=  57.750 flicker=0.022 noise=0.0022 lr=0.000127 global_step=176796
# [update] cartpole_reliable seed=0 loss=27.0844 policy=0.0025 value=54.1709 entropy=0.5707 kl=0.0006 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.7125 policy=0.1533 value=55.1258 entropy=0.5898 kl=0.0022 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02900 rawR=  22.000 trainR=  22.140 recent20=  81.700 flicker=0.022 noise=0.0022 lr=0.000126 global_step=178430
# [update] cartpole_reliable seed=0 loss=29.7775 policy=0.0350 value=59.4924 entropy=0.6035 kl=0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02920 rawR=  52.000 trainR=  52.125 recent20=  88.050 flicker=0.022 noise=0.0022 lr=0.000125 global_step=180191
# [update] cartpole_reliable seed=0 loss=29.7123 policy=0.0790 value=59.2740 entropy=0.6040 kl=0.0001 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=29.2774 policy=0.0768 value=58.4085 entropy=0.6039 kl=0.0024 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02940 rawR=  60.000 trainR=  60.119 recent20=  71.050 flicker=0.022 noise=0.0022 lr=0.000124 global_step=181612
# [update] cartpole_reliable seed=0 loss=29.0538 policy=0.1109 value=57.8928 entropy=0.5774 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02960 rawR=  69.000 trainR=  69.151 recent20=  77.950 flicker=0.022 noise=0.0022 lr=0.000122 global_step=183171
# [update] cartpole_reliable seed=0 loss=28.5158 policy=0.1199 value=56.7985 entropy=0.5600 kl=0.0014 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=28.1373 policy=0.0718 value=56.1378 entropy=0.5859 kl=0.0007 early_stop_kl=0
# [cartpole_reliable seed=0] ep=02980 rawR= 161.000 trainR= 161.484 recent20=  87.450 flicker=0.022 noise=0.0022 lr=0.000121 global_step=184920
# [update] cartpole_reliable seed=0 loss=27.2970 policy=0.2591 value=54.0830 entropy=0.6109 kl=-0.0004 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=26.4584 policy=0.1281 value=52.6676 entropy=0.6010 kl=0.0019 early_stop_kl=0
# [eval] cartpole_reliable seed=0 ep=3000 mean=500.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/cartpole_reliable_seed0_latest.pt
# [cartpole_reliable seed=0] ep=03000 rawR=  76.000 trainR=  76.248 recent20= 109.350 flicker=0.023 noise=0.0023 lr=0.000120 global_step=187107
# [update] cartpole_reliable seed=0 loss=26.1539 policy=0.0092 value=52.2962 entropy=0.5921 kl=-0.0004 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=25.6004 policy=0.1632 value=50.8811 entropy=0.5830 kl=0.0010 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03020 rawR= 114.000 trainR= 114.370 recent20=  88.900 flicker=0.023 noise=0.0023 lr=0.000119 global_step=188885
# [update] cartpole_reliable seed=0 loss=30.2715 policy=0.0997 value=60.3500 entropy=0.5809 kl=0.0006 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03040 rawR=  42.000 trainR=  42.184 recent20=  70.800 flicker=0.023 noise=0.0023 lr=0.000118 global_step=190301
# [update] cartpole_reliable seed=0 loss=30.9198 policy=0.1768 value=61.4925 entropy=0.5904 kl=0.0014 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=27.3677 policy=0.2242 value=54.2931 entropy=0.5700 kl=0.0011 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03060 rawR=  68.000 trainR=  68.140 recent20=  93.000 flicker=0.023 noise=0.0023 lr=0.000116 global_step=192161
# [update] cartpole_reliable seed=0 loss=30.1209 policy=0.0350 value=60.1781 entropy=0.5760 kl=0.0008 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03080 rawR= 132.000 trainR= 131.532 recent20=  66.450 flicker=0.023 noise=0.0023 lr=0.000115 global_step=193490
# [update] cartpole_reliable seed=0 loss=35.1487 policy=0.1665 value=69.9705 entropy=0.5714 kl=0.0010 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=31.0751 policy=0.0189 value=62.1182 entropy=0.5626 kl=0.0003 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03100 rawR= 219.000 trainR= 218.771 recent20=  64.300 flicker=0.023 noise=0.0023 lr=0.000114 global_step=194776
# [update] cartpole_reliable seed=0 loss=30.0049 policy=0.3814 value=59.2531 entropy=0.5739 kl=0.0012 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=34.7876 policy=0.2954 value=68.9904 entropy=0.5887 kl=0.0025 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03120 rawR= 134.000 trainR= 133.617 recent20= 115.100 flicker=0.023 noise=0.0023 lr=0.000113 global_step=197078
# [update] cartpole_reliable seed=0 loss=29.4545 policy=0.0398 value=58.8354 entropy=0.5750 kl=0.0022 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=30.6869 policy=0.1067 value=61.1666 entropy=0.5981 kl=0.0014 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03140 rawR=  88.000 trainR=  87.954 recent20= 101.600 flicker=0.024 noise=0.0024 lr=0.000112 global_step=199110
# [update] cartpole_reliable seed=0 loss=34.4109 policy=0.1025 value=68.6230 entropy=0.5996 kl=0.0035 early_stop_kl=0
# [update] cartpole_reliable seed=0 loss=31.0001 policy=0.0404 value=61.9250 entropy=0.5763 kl=0.0005 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03160 rawR=  91.000 trainR=  91.277 recent20=  88.050 flicker=0.024 noise=0.0024 lr=0.000110 global_step=200871
# [update] cartpole_reliable seed=0 loss=31.8823 policy=0.1735 value=63.4236 entropy=0.6028 kl=0.0007 early_stop_kl=0
# [cartpole_reliable seed=0] ep=03180 rawR=  59.000 trainR=  59.085 recent20=  86.650 flicker=0.024 noise=0.0024 lr=0.000109 global_step=202604
# [update] cartpole_reliable seed=0 loss=35.7261 policy=0.1916 value=71.0745 entropy=0.5545 kl=0.0063 early_stop_kl=1
# [cartpole_reliable seed=0] ep=03200 rawR=  25.000 trainR=  25.165 recent20=  56.950 flicker=0.024 noise=0.0024 lr=0.000108 global_step=203743
# ...
# [update] acrobot_reliable seed=0 loss=56.2329 policy=-0.0263 value=93.8001 entropy=1.0962 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=55.0350 policy=0.0033 value=91.7540 entropy=1.0936 kl=0.0012 early_stop_kl=0
# [acrobot_reliable seed=0] ep=00920 rawR=-500.000 trainR=-460.206 recent20=-497.500 flicker=0.002 noise=0.0001 lr=0.000238 global_step=451061
# [update] acrobot_reliable seed=0 loss=54.1644 policy=-0.0007 value=90.3095 entropy=1.0843 kl=0.0011 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=53.6893 policy=0.0076 value=89.5035 entropy=1.0782 kl=0.0007 early_stop_kl=0
# [acrobot_reliable seed=0] ep=00940 rawR=-500.000 trainR=-469.236 recent20=-500.000 flicker=0.002 noise=0.0001 lr=0.000238 global_step=461061
# [update] acrobot_reliable seed=0 loss=53.5612 policy=0.0119 value=89.2825 entropy=1.0661 kl=0.0015 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=54.7916 policy=0.0001 value=91.3525 entropy=1.0580 kl=0.0001 early_stop_kl=0
# [acrobot_reliable seed=0] ep=00960 rawR=-500.000 trainR=-470.294 recent20=-484.450 flicker=0.002 noise=0.0001 lr=0.000237 global_step=470753
# [update] acrobot_reliable seed=0 loss=54.7017 policy=-0.0074 value=91.2151 entropy=1.0544 kl=-0.0000 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=54.9489 policy=-0.0109 value=91.6328 entropy=1.0523 kl=-0.0001 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=51.2121 policy=-0.0025 value=85.3909 entropy=1.0565 kl=0.0007 early_stop_kl=0
# [acrobot_reliable seed=0] ep=00980 rawR=-500.000 trainR=-463.273 recent20=-492.250 flicker=0.002 noise=0.0001 lr=0.000237 global_step=480599
# [update] acrobot_reliable seed=0 loss=53.0243 policy=0.0015 value=88.4050 entropy=1.0657 kl=0.0031 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=52.6299 policy=-0.0109 value=87.7672 entropy=1.0331 kl=0.0019 early_stop_kl=0
# [eval] acrobot_reliable seed=0 ep=1000 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [acrobot_reliable seed=0] ep=01000 rawR=-500.000 trainR=-460.706 recent20=-497.600 flicker=0.002 noise=0.0001 lr=0.000237 global_step=490553
# [update] acrobot_reliable seed=0 loss=51.1128 policy=-0.0222 value=85.2578 entropy=1.0445 kl=0.0023 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=51.2102 policy=-0.0056 value=85.3925 entropy=1.0435 kl=0.0016 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=51.9889 policy=0.0021 value=86.6759 entropy=0.9950 kl=0.0048 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01020 rawR=-500.000 trainR=-463.469 recent20=-495.350 flicker=0.002 noise=0.0001 lr=0.000236 global_step=500462
# [update] acrobot_reliable seed=0 loss=51.0804 policy=0.0061 value=85.1535 entropy=0.9448 kl=0.0034 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=48.9828 policy=-0.0031 value=81.6688 entropy=0.8189 kl=0.0048 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01040 rawR=-500.000 trainR=-462.208 recent20=-491.450 flicker=0.002 noise=0.0001 lr=0.000236 global_step=510293
# [update] acrobot_reliable seed=0 loss=49.1428 policy=0.0002 value=81.9298 entropy=0.8105 kl=0.0001 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.7752 policy=0.0023 value=79.6470 entropy=0.8164 kl=0.0002 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01060 rawR=-500.000 trainR=-470.480 recent20=-483.700 flicker=0.002 noise=0.0001 lr=0.000236 global_step=519969
# [update] acrobot_reliable seed=0 loss=47.2355 policy=-0.0114 value=78.7701 entropy=0.8107 kl=0.0003 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.0233 policy=-0.0009 value=78.3989 entropy=0.8078 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.4555 policy=0.0008 value=79.1157 entropy=0.7857 kl=0.0004 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01080 rawR=-500.000 trainR=-467.575 recent20=-493.000 flicker=0.002 noise=0.0001 lr=0.000236 global_step=529832
# [update] acrobot_reliable seed=0 loss=45.6985 policy=0.0027 value=76.1835 entropy=0.7588 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.6257 policy=-0.0037 value=79.4075 entropy=0.8031 kl=0.0008 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01100 rawR=-500.000 trainR=-461.841 recent20=-500.000 flicker=0.002 noise=0.0001 lr=0.000235 global_step=539832
# [update] acrobot_reliable seed=0 loss=46.1312 policy=-0.0158 value=76.9383 entropy=0.8482 kl=0.0008 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.2557 policy=-0.0263 value=78.8306 entropy=0.8734 kl=-0.0000 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=47.0904 policy=-0.0638 value=78.6177 entropy=0.8757 kl=0.0007 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01120 rawR=-500.000 trainR=-462.965 recent20=-500.000 flicker=0.002 noise=0.0001 lr=0.000235 global_step=549832
# [update] acrobot_reliable seed=0 loss=46.1635 policy=0.0054 value=76.9576 entropy=0.8775 kl=0.0007 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=44.7965 policy=-0.0074 value=74.7020 entropy=0.9211 kl=0.0012 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01140 rawR=-500.000 trainR=-462.977 recent20=-463.950 flicker=0.002 noise=0.0001 lr=0.000235 global_step=559117
# [update] acrobot_reliable seed=0 loss=47.4876 policy=-0.0155 value=79.2002 entropy=0.9109 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=44.3094 policy=0.0074 value=73.8642 entropy=0.8827 kl=0.0015 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01160 rawR=-500.000 trainR=-464.223 recent20=-488.100 flicker=0.002 noise=0.0001 lr=0.000235 global_step=568881
# [update] acrobot_reliable seed=0 loss=45.5096 policy=-0.0310 value=75.9289 entropy=0.8957 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=46.6825 policy=-0.0158 value=77.8575 entropy=0.8715 kl=-0.0005 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=42.3422 policy=0.0090 value=70.5834 entropy=0.9034 kl=0.0011 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01180 rawR=-500.000 trainR=-464.231 recent20=-497.300 flicker=0.002 noise=0.0001 lr=0.000234 global_step=578828
# [update] acrobot_reliable seed=0 loss=43.3482 policy=0.0103 value=72.2603 entropy=0.9783 kl=0.0045 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=46.1745 policy=-0.0033 value=76.9939 entropy=0.9927 kl=0.0004 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01200 rawR=-500.000 trainR=-466.613 recent20=-492.450 flicker=0.002 noise=0.0001 lr=0.000234 global_step=588679
# [update] acrobot_reliable seed=0 loss=42.1178 policy=0.0033 value=70.2226 entropy=1.0215 kl=0.0009 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=45.2222 policy=0.0008 value=75.4009 entropy=1.0319 kl=0.0010 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=43.3412 policy=0.0012 value=72.2657 entropy=1.0418 kl=0.0016 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01220 rawR=-500.000 trainR=-460.867 recent20=-498.300 flicker=0.002 noise=0.0001 lr=0.000234 global_step=598646
# [update] acrobot_reliable seed=0 loss=44.6323 policy=-0.0245 value=74.4602 entropy=1.0376 kl=0.0009 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=43.8025 policy=-0.0072 value=73.0482 entropy=1.0374 kl=0.0026 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01240 rawR=-500.000 trainR=-462.489 recent20=-499.250 flicker=0.002 noise=0.0001 lr=0.000234 global_step=608632
# [update] acrobot_reliable seed=0 loss=42.1128 policy=0.0074 value=70.2078 entropy=1.0367 kl=0.0026 early_stop_kl=0
# [eval] acrobot_reliable seed=0 ep=1250 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [update] acrobot_reliable seed=0 loss=41.5211 policy=-0.0008 value=69.2352 entropy=1.0339 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=41.0914 policy=-0.0270 value=68.5633 entropy=1.0530 kl=0.0016 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01260 rawR=-500.000 trainR=-458.131 recent20=-500.000 flicker=0.002 noise=0.0001 lr=0.000233 global_step=618632
# [update] acrobot_reliable seed=0 loss=42.4018 policy=0.0040 value=70.6961 entropy=1.0681 kl=0.0022 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=43.1516 policy=-0.0052 value=71.9607 entropy=1.0613 kl=0.0084 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01280 rawR=-500.000 trainR=-469.086 recent20=-499.750 flicker=0.002 noise=0.0001 lr=0.000233 global_step=628628
# [update] acrobot_reliable seed=0 loss=43.1887 policy=-0.0084 value=72.0282 entropy=1.0650 kl=0.0005 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=42.1933 policy=0.0028 value=70.3506 entropy=1.0718 kl=0.0026 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01300 rawR=-500.000 trainR=-461.275 recent20=-496.950 flicker=0.002 noise=0.0001 lr=0.000233 global_step=638568
# [update] acrobot_reliable seed=0 loss=41.1602 policy=0.0055 value=68.6244 entropy=1.0742 kl=0.0005 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=43.0923 policy=-0.0112 value=71.8725 entropy=1.0774 kl=0.0003 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=41.0940 policy=0.0034 value=68.5174 entropy=1.0738 kl=0.0033 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01320 rawR=-500.000 trainR=-462.394 recent20=-493.450 flicker=0.002 noise=0.0001 lr=0.000232 global_step=648438
# [update] acrobot_reliable seed=0 loss=42.4725 policy=-0.0216 value=70.8564 entropy=1.0647 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=41.2676 policy=-0.0268 value=68.8568 entropy=1.0660 kl=0.0006 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01340 rawR=-500.000 trainR=-465.780 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000232 global_step=658438
# [update] acrobot_reliable seed=0 loss=40.4116 policy=-0.0003 value=67.3863 entropy=1.0754 kl=0.0003 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=40.0147 policy=-0.0024 value=66.7285 entropy=1.0825 kl=0.0003 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=39.4085 policy=-0.0041 value=65.7209 entropy=1.0825 kl=0.0000 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01360 rawR=-500.000 trainR=-461.578 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000232 global_step=668438
# [update] acrobot_reliable seed=0 loss=42.0439 policy=0.0007 value=70.1055 entropy=1.0871 kl=0.0020 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=38.6463 policy=0.0133 value=64.4219 entropy=1.0915 kl=0.0003 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01380 rawR=-500.000 trainR=-461.776 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000232 global_step=678438
# [update] acrobot_reliable seed=0 loss=39.1395 policy=0.0111 value=65.2476 entropy=1.0965 kl=0.0006 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=40.1844 policy=0.0012 value=67.0057 entropy=1.0920 kl=0.0028 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=39.3742 policy=-0.0025 value=65.6613 entropy=1.0948 kl=0.0024 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01400 rawR=-500.000 trainR=-463.290 recent20=-498.400 flicker=0.003 noise=0.0001 lr=0.000231 global_step=688407
# [update] acrobot_reliable seed=0 loss=41.0822 policy=-0.0091 value=68.5188 entropy=1.0856 kl=0.0017 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=40.4156 policy=-0.0456 value=67.4678 entropy=1.0604 kl=0.0010 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01420 rawR=-500.000 trainR=-461.564 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000231 global_step=698407
# [update] acrobot_reliable seed=0 loss=40.5079 policy=-0.0051 value=67.5531 entropy=1.0271 kl=0.0011 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=38.1768 policy=-0.0047 value=63.6675 entropy=1.0308 kl=0.0030 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01440 rawR=-500.000 trainR=-463.402 recent20=-491.000 flicker=0.003 noise=0.0001 lr=0.000231 global_step=708230
# [update] acrobot_reliable seed=0 loss=39.4161 policy=-0.0067 value=65.7358 entropy=1.0132 kl=0.0023 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.6901 policy=-0.0291 value=62.8965 entropy=1.0193 kl=0.0006 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.6679 policy=-0.0011 value=62.8125 entropy=1.0084 kl=0.0012 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01460 rawR=-500.000 trainR=-462.201 recent20=-488.950 flicker=0.003 noise=0.0001 lr=0.000231 global_step=718012
# [update] acrobot_reliable seed=0 loss=40.1556 policy=-0.0043 value=66.9627 entropy=0.9663 kl=0.0019 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=40.7899 policy=-0.0882 value=68.1603 entropy=0.9874 kl=0.0016 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01480 rawR=-500.000 trainR=-464.850 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000230 global_step=728012
# [update] acrobot_reliable seed=0 loss=41.1938 policy=-0.0113 value=68.7060 entropy=1.0135 kl=0.0006 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.6877 policy=0.0019 value=62.8403 entropy=1.0051 kl=0.0024 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.4940 policy=-0.0089 value=62.5358 entropy=1.0153 kl=0.0078 early_stop_kl=0
# [eval] acrobot_reliable seed=0 ep=1500 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [acrobot_reliable seed=0] ep=01500 rawR=-500.000 trainR=-461.605 recent20=-489.650 flicker=0.003 noise=0.0001 lr=0.000230 global_step=737807
# [update] acrobot_reliable seed=0 loss=40.0070 policy=-0.0163 value=66.7372 entropy=1.0393 kl=0.0017 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.2167 policy=-0.0019 value=62.0633 entropy=1.0573 kl=0.0010 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01520 rawR=-500.000 trainR=-460.222 recent20=-497.850 flicker=0.003 noise=0.0001 lr=0.000230 global_step=747765
# [update] acrobot_reliable seed=0 loss=35.8114 policy=0.0174 value=59.6884 entropy=1.0407 kl=-0.0005 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=36.9484 policy=0.0114 value=61.5938 entropy=1.0511 kl=0.0026 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=37.9298 policy=-0.0530 value=63.3371 entropy=1.0658 kl=0.0016 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01540 rawR=-500.000 trainR=-461.463 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000230 global_step=757765
# [update] acrobot_reliable seed=0 loss=36.8818 policy=0.0031 value=61.4953 entropy=1.0135 kl=0.0048 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=34.7144 policy=-0.0012 value=57.8902 entropy=1.0179 kl=0.0008 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01560 rawR=-500.000 trainR=-462.248 recent20=-495.300 flicker=0.003 noise=0.0001 lr=0.000229 global_step=767673
# [update] acrobot_reliable seed=0 loss=38.1157 policy=-0.0081 value=63.5709 entropy=1.0296 kl=0.0008 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=38.7264 policy=-0.0233 value=64.6150 entropy=1.0534 kl=-0.0003 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01580 rawR=-500.000 trainR=-464.126 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000229 global_step=777673
# [update] acrobot_reliable seed=0 loss=39.2432 policy=-0.0147 value=65.4625 entropy=1.0792 kl=0.0002 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=32.2987 policy=0.0105 value=53.8463 entropy=1.0763 kl=0.0007 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=38.4318 policy=-0.0074 value=64.0963 entropy=1.0208 kl=0.0040 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01600 rawR=-500.000 trainR=-460.891 recent20=-497.700 flicker=0.003 noise=0.0001 lr=0.000229 global_step=787628
# [update] acrobot_reliable seed=0 loss=36.1048 policy=0.0179 value=60.1760 entropy=1.0289 kl=0.0004 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=36.4266 policy=0.0125 value=60.7217 entropy=1.0395 kl=0.0013 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01620 rawR=-500.000 trainR=-462.439 recent20=-500.000 flicker=0.003 noise=0.0001 lr=0.000228 global_step=797628
# [update] acrobot_reliable seed=0 loss=39.5382 policy=-0.0148 value=65.9540 entropy=1.0676 kl=-0.0004 early_stop_kl=0
# [update] acrobot_reliable seed=0 loss=35.8708 policy=0.0171 value=59.7893 entropy=1.0944 kl=0.0092 early_stop_kl=1
# [update] acrobot_reliable seed=0 loss=36.6671 policy=0.0051 value=61.1363 entropy=1.0874 kl=0.0032 early_stop_kl=0
# [acrobot_reliable seed=0] ep=01640 rawR=-500.000 trainR=-462.725 recent20=-497.100 flicker=0.003 noise=0.0001 lr=0.000228 global_step=807571

# %%
import json

for name in [
    "cartpole_reliable_seed0",
    "cartpole_reliable_seed1",
    "cartpole_reliable_seed2",
    "acrobot_reliable_seed0",
    "acrobot_reliable_seed1",
    "acrobot_reliable_seed2",
    "mountaincar_reliable_seed0",
    "mountaincar_reliable_seed1",
    "mountaincar_reliable_seed2",
]:
    path = f"./checkpoints_robust_recurrent_ppo/{name}_meta.json"
    try:
        with open(path, "r", encoding="utf-8") as f:
            meta = json.load(f)
        print(name, "->", meta.get("last_saved_episode"), meta.get("status"))
    except FileNotFoundError:
        print(name, "-> 없음")
# Out:
# cartpole_reliable_seed0 -> 3699 running_or_interrupted
# cartpole_reliable_seed1 -> 3999 finished_or_stopped
# cartpole_reliable_seed2 -> 3999 finished_or_stopped
# acrobot_reliable_seed0 -> 15999 finished_or_stopped
# acrobot_reliable_seed1 -> 15999 finished_or_stopped
# acrobot_reliable_seed2 -> 15999 finished_or_stopped
# mountaincar_reliable_seed0 -> 없음
# mountaincar_reliable_seed1 -> 없음
# mountaincar_reliable_seed2 -> 없음

# %%
# !ls -lh ./checkpoints_robust_recurrent_ppo
# Out:
# total 8.7M
# -rw-r--r-- 1 root root 3.3M Mar 12 17:11 acrobot_reliable_seed0_latest.pt
# -rw-r--r-- 1 root root  202 Mar 12 17:11 acrobot_reliable_seed0_meta.json
# -rw-r--r-- 1 root root 1.9M Mar 12 16:23 cartpole_reliable_seed0_latest.pt
# -rw-r--r-- 1 root root  203 Mar 12 16:23 cartpole_reliable_seed0_meta.json
# -rw-r--r-- 1 root root 1.9M Mar 12 16:29 cartpole_reliable_seed1_latest.pt
# -rw-r--r-- 1 root root  203 Mar 12 16:29 cartpole_reliable_seed1_meta.json
# -rw-r--r-- 1 root root 1.9M Mar 12 16:36 cartpole_reliable_seed2_latest.pt
# -rw-r--r-- 1 root root  203 Mar 12 16:36 cartpole_reliable_seed2_meta.json

# %%
# !python robust_multi_env_recurrent_ppo.py --device cuda:0 --resume
# Out:
# python: can't open file '/workspace/soyoung/pomdp/robust_multi_env_recurrent_ppo.py': [Errno 2] No such file or directory

# %%
# !pwd
# Out:
# /workspace/soyoung/pomdp

# %%
# !ls
# Out:
#  1.ipynb			    reliable_ppo_summary.csv
#  checkpoints			    reliable_ppo_summary.json
#  checkpoints_pomdp		    results_bundle.zip
#  checkpoints_reliable_ppo	    robust_recurrent_ppo_raw.csv
#  checkpoints_robust_recurrent_ppo   robust_recurrent_ppo_raw.json
#  pomdp_results.xlsx		    robust_recurrent_ppo_summary.csv
#  pomdp_results_raw.csv		    robust_recurrent_ppo_summary.json
#  pomdp_results_summary.csv	    test_6.xlsx
#  reliable_ppo_raw.csv		   '저장하기><.ipynb'
#  reliable_ppo_raw.json		   '하이퍼파라미터 실험.ipynb'

# %%
# !ls /workspace/soyoung/pomdp
# Out:
#  1.ipynb			    reliable_ppo_summary.csv
#  checkpoints			    reliable_ppo_summary.json
#  checkpoints_pomdp		    results_bundle.zip
#  checkpoints_reliable_ppo	    robust_recurrent_ppo_raw.csv
#  checkpoints_robust_recurrent_ppo   robust_recurrent_ppo_raw.json
#  pomdp_results.xlsx		    robust_recurrent_ppo_summary.csv
#  pomdp_results_raw.csv		    robust_recurrent_ppo_summary.json
#  pomdp_results_summary.csv	    test_6.xlsx
#  reliable_ppo_raw.csv		   '저장하기><.ipynb'
#  reliable_ppo_raw.json		   '하이퍼파라미터 실험.ipynb'

# %%
import os
import json
import torch
import numpy as np
from pprint import pprint

CKPT_DIR = "./checkpoints_robust_recurrent_ppo"

TARGETS = {
    "cartpole_reliable": 4000,
    "acrobot_reliable": 16000,
    "mountaincar_reliable": 18000,
    # 필요하면 추가
    # "acrobot_reliable_v2": 20000,
    # "cartpole_medium": 6000,
    # "acrobot_medium": 22000,
    # "mountaincar_medium": 24000,
}

SEEDS = [0, 1, 2]


def ckpt_path(preset, seed):
    return os.path.join(CKPT_DIR, f"{preset}_seed{seed}_latest.pt")


def meta_path(preset, seed):
    return os.path.join(CKPT_DIR, f"{preset}_seed{seed}_meta.json")


def summarize_rewards(raw_rewards, solve_score=None):
    if raw_rewards is None or len(raw_rewards) == 0:
        return {
            "episodes_completed": 0,
            "auc_mean": None,
            "last100_mean": None,
            "last100_std": None,
            "best_reward": None,
            "first_solve_ep": -1,
        }

    r = np.asarray(raw_rewards, dtype=np.float32)
    tail = r[-100:] if len(r) >= 100 else r

    first_solve_ep = -1
    if solve_score is not None and len(r) >= 100:
        win = np.convolve(r, np.ones(100, dtype=np.float32) / 100.0, mode="valid")
        idx = np.where(win >= solve_score)[0]
        if len(idx) > 0:
            first_solve_ep = int(idx[0] + 100)

    return {
        "episodes_completed": int(len(r)),
        "auc_mean": float(r.mean()),
        "last100_mean": float(tail.mean()),
        "last100_std": float(tail.std(ddof=0)),
        "best_reward": float(r.max()),
        "first_solve_ep": int(first_solve_ep),
    }


all_rows = []

print("=" * 100)
print("CHECKPOINT STATUS")
print("=" * 100)

for preset, target_ep in TARGETS.items():
    print(f"\n[{preset}] target_episodes={target_ep}")
    for seed in SEEDS:
        cpath = ckpt_path(preset, seed)
        mpath = meta_path(preset, seed)

        exists_ckpt = os.path.exists(cpath)
        exists_meta = os.path.exists(mpath)

        row = {
            "preset": preset,
            "seed": seed,
            "target_episodes": target_ep,
            "ckpt_exists": exists_ckpt,
            "meta_exists": exists_meta,
            "status": "missing",
            "last_saved_episode_meta": None,
            "last_saved_episode_ckpt": None,
            "episodes_completed": 0,
            "done": False,
            "eval_mean": None,
            "eval_std": None,
            "auc_mean": None,
            "last100_mean": None,
            "best_reward": None,
            "first_solve_ep": -1,
        }

        # meta 읽기
        if exists_meta:
            try:
                with open(mpath, "r", encoding="utf-8") as f:
                    meta = json.load(f)
                row["status"] = meta.get("status", "unknown")
                row["last_saved_episode_meta"] = meta.get("last_saved_episode", None)
            except Exception as e:
                row["status"] = f"meta_read_error: {e}"

        # ckpt 읽기
        if exists_ckpt:
            try:
                payload = torch.load(cpath, map_location="cpu")
                episode = int(payload.get("episode", -1))
                raw_train_rewards = payload.get("raw_train_rewards", [])
                eval_history = payload.get("eval_history", [])

                row["last_saved_episode_ckpt"] = episode

                metrics = summarize_rewards(raw_train_rewards)
                row.update(metrics)

                if eval_history:
                    last_eval = eval_history[-1]
                    row["eval_mean"] = float(last_eval.get("eval_mean", 0.0))
                    row["eval_std"] = float(last_eval.get("eval_std", 0.0))

                row["done"] = (row["episodes_completed"] >= target_ep)

            except Exception as e:
                row["status"] = f"ckpt_read_error: {e}"

        print(
            f"seed={seed} | "
            f"status={row['status']} | "
            f"completed={row['episodes_completed']}/{target_ep} | "
            f"done={row['done']} | "
            f"eval_mean={row['eval_mean']}"
        )

        all_rows.append(row)

print("\n" + "=" * 100)
print("DETAIL RESULTS")
print("=" * 100)

for row in all_rows:
    print(
        f"{row['preset']:22s} seed={row['seed']} | "
        f"done={str(row['done']):5s} | "
        f"episodes={row['episodes_completed']:5d}/{row['target_episodes']:5d} | "
        f"status={str(row['status']):22s} | "
        f"last100={str(None if row['last100_mean'] is None else round(row['last100_mean'], 3)):>8s} | "
        f"best={str(None if row['best_reward'] is None else round(row['best_reward'], 3)):>8s} | "
        f"eval={str(None if row['eval_mean'] is None else round(row['eval_mean'], 3)):>8s}"
    )

print("\n" + "=" * 100)
print("SUMMARY BY PRESET")
print("=" * 100)

for preset in TARGETS.keys():
    rows = [r for r in all_rows if r["preset"] == preset]
    if not rows:
        continue

    completed_n = sum(int(r["done"]) for r in rows)
    valid_last100 = [r["last100_mean"] for r in rows if r["last100_mean"] is not None]
    valid_eval = [r["eval_mean"] for r in rows if r["eval_mean"] is not None]

    print(
        f"{preset:22s} | "
        f"finished_seeds={completed_n}/{len(rows)} | "
        f"mean_last100={None if not valid_last100 else round(float(np.mean(valid_last100)), 3)} | "
        f"mean_eval={None if not valid_eval else round(float(np.mean(valid_eval)), 3)}"
    )
# Out:
# ====================================================================================================
# CHECKPOINT STATUS
# ====================================================================================================
#
# [cartpole_reliable] target_episodes=4000
# seed=0 | status=running_or_interrupted | completed=3700/4000 | done=False | eval_mean=500.0
# seed=1 | status=finished_or_stopped | completed=4000/4000 | done=True | eval_mean=500.0
# seed=2 | status=finished_or_stopped | completed=4000/4000 | done=True | eval_mean=476.0
#
# [acrobot_reliable] target_episodes=16000
# seed=0 | status=finished_or_stopped | completed=16000/16000 | done=True | eval_mean=-75.80000305175781
# seed=1 | status=finished_or_stopped | completed=16000/16000 | done=True | eval_mean=-101.0
# seed=2 | status=finished_or_stopped | completed=16000/16000 | done=True | eval_mean=-73.19999694824219
#
# [mountaincar_reliable] target_episodes=18000
# seed=0 | status=finished_or_stopped | completed=18000/18000 | done=True | eval_mean=-122.4000015258789
# seed=1 | status=finished_or_stopped | completed=18000/18000 | done=True | eval_mean=-200.0
# seed=2 | status=finished_or_stopped | completed=18000/18000 | done=True | eval_mean=-118.4000015258789
#
# ====================================================================================================
# DETAIL RESULTS
# ====================================================================================================
# cartpole_reliable      seed=0 | done=False | episodes= 3700/ 4000 | status=running_or_interrupted | last100=   71.87 | best=   500.0 | eval=   500.0
# cartpole_reliable      seed=1 | done=True  | episodes= 4000/ 4000 | status=finished_or_stopped    | last100=   82.91 | best=   500.0 | eval=   500.0
# cartpole_reliable      seed=2 | done=True  | episodes= 4000/ 4000 | status=finished_or_stopped    | last100=   75.58 | best=   500.0 | eval=   476.0
# acrobot_reliable       seed=0 | done=True  | episodes=16000/16000 | status=finished_or_stopped    | last100=  -86.87 | best=   -59.0 | eval=   -75.8
# acrobot_reliable       seed=1 | done=True  | episodes=16000/16000 | status=finished_or_stopped    | last100=   -92.6 | best=   -60.0 | eval=  -101.0
# acrobot_reliable       seed=2 | done=True  | episodes=16000/16000 | status=finished_or_stopped    | last100=  -92.36 | best=   -60.0 | eval=   -73.2
# mountaincar_reliable   seed=0 | done=True  | episodes=18000/18000 | status=finished_or_stopped    | last100= -198.64 | best=  -140.0 | eval=  -122.4
# mountaincar_reliable   seed=1 | done=True  | episodes=18000/18000 | status=finished_or_stopped    | last100=  -200.0 | best=  -200.0 | eval=  -200.0
# mountaincar_reliable   seed=2 | done=True  | episodes=18000/18000 | status=finished_or_stopped    | last100= -115.28 | best=  -104.0 | eval=  -118.4
#
# ====================================================================================================
# SUMMARY BY PRESET
# ====================================================================================================
# cartpole_reliable      | finished_seeds=2/3 | mean_last100=76.787 | mean_eval=492.0
# acrobot_reliable       | finished_seeds=3/3 | mean_last100=-90.61 | mean_eval=-83.333
# mountaincar_reliable   | finished_seeds=3/3 | mean_last100=-171.307 | mean_eval=-146.933

# %%
# ============================================================
# robust_multi_env_recurrent_ppo.py
# ------------------------------------------------------------
# 목표
# - CartPole / Acrobot / MountainCar 에서 안정적으로 학습되는 recurrent PPO
# - sparse reward 환경 대응
# - mild / medium / hard POMDP curriculum 지원
# - notebook / terminal 모두 안전
#
# 주요 개선
# - parse_known_args() : notebook 안전
# - recurrent PPO (LSTM)
# - orthogonal init + LayerNorm
# - observation normalization
# - PPO value clipping / KL early stopping
# - lr annealing / entropy annealing
# - env-specific shaping reward (train only)
# - raw reward / train reward 분리
# - scheduled POMDP severity
# - checkpoint / resume / graceful stop
# - optional notebook kernel safe shutdown
#
# 추가 개선 (Acrobot)
# - AcrobotShaper 강화
# - acrobot_reliable_v2 preset 추가
#
# 권장 실행
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --resume
# ============================================================

import os
import gc
import csv
import json
import math
import time
import signal
import random
import argparse
from dataclasses import dataclass, asdict
from typing import Dict, List, Optional, Tuple, Any

import numpy as np
import gymnasium as gym

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical


# ============================================================
# Global
# ============================================================

USE_AMP_DEFAULT = True
STOP_REQUESTED = False


def _signal_handler(signum, frame):
    global STOP_REQUESTED
    STOP_REQUESTED = True
    print(f"\n[signal] received signal={signum}. stopping at next safe point...")


signal.signal(signal.SIGINT, _signal_handler)
signal.signal(signal.SIGTERM, _signal_handler)


# ============================================================
# Utils
# ============================================================

def set_global_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)


def cleanup_torch(device: torch.device):
    try:
        gc.collect()
        if device.type == "cuda":
            torch.cuda.synchronize(device)
            torch.cuda.empty_cache()
            try:
                torch.cuda.ipc_collect()
            except Exception:
                pass
    except Exception as e:
        print("[warn] cleanup_torch failed:", repr(e))


def unwrap_model(model: nn.Module) -> nn.Module:
    return model._orig_mod if hasattr(model, "_orig_mod") else model


def model_state_dict(model: nn.Module) -> Dict[str, torch.Tensor]:
    return unwrap_model(model).state_dict()


def load_model_state_dict(model: nn.Module, state_dict: Dict[str, torch.Tensor], strict: bool = True):
    unwrap_model(model).load_state_dict(state_dict, strict=strict)


def maybe_compile(model: nn.Module, enabled: bool) -> nn.Module:
    if not enabled:
        return model
    try:
        return torch.compile(model)
    except Exception as e:
        print("[warn] torch.compile failed, fallback:", repr(e))
        return model


def linear_interp(a: float, b: float, t01: float) -> float:
    t01 = max(0.0, min(1.0, float(t01)))
    return a + (b - a) * t01


def safe_float(x, default=0.0):
    try:
        return float(x)
    except Exception:
        return float(default)


def maybe_shutdown_kernel(enabled: bool):
    if not enabled:
        return
    try:
        from IPython import get_ipython
        ip = get_ipython()
        if ip is not None and hasattr(ip, "kernel"):
            print("[shutdown] notebook kernel will be shut down safely.")
            ip.kernel.do_shutdown(restart=False)
    except Exception as e:
        print("[warn] kernel shutdown skipped:", repr(e))


# ============================================================
# Running mean/std
# ============================================================

class RunningMeanStd:
    def __init__(self, shape):
        self.mean = np.zeros(shape, dtype=np.float64)
        self.var = np.ones(shape, dtype=np.float64)
        self.count = 1e-4

    def update(self, x: np.ndarray):
        x = np.asarray(x, dtype=np.float64)
        if x.ndim == 1:
            x = x[None, :]
        batch_mean = np.mean(x, axis=0)
        batch_var = np.var(x, axis=0)
        batch_count = x.shape[0]
        self._update_from_moments(batch_mean, batch_var, batch_count)

    def _update_from_moments(self, batch_mean, batch_var, batch_count):
        delta = batch_mean - self.mean
        total_count = self.count + batch_count

        new_mean = self.mean + delta * batch_count / total_count

        m_a = self.var * self.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + (delta ** 2) * self.count * batch_count / total_count
        new_var = M2 / total_count

        self.mean = new_mean
        self.var = np.maximum(new_var, 1e-12)
        self.count = total_count

    def normalize(self, x: np.ndarray) -> np.ndarray:
        x = np.asarray(x, dtype=np.float32)
        z = (x - self.mean) / np.sqrt(self.var + 1e-8)
        return np.clip(z, -10.0, 10.0).astype(np.float32)

    def state_dict(self) -> Dict[str, Any]:
        return {
            "mean": self.mean.tolist(),
            "var": self.var.tolist(),
            "count": float(self.count),
        }

    def load_state_dict(self, sd: Dict[str, Any]):
        self.mean = np.asarray(sd["mean"], dtype=np.float64)
        self.var = np.asarray(sd["var"], dtype=np.float64)
        self.count = float(sd["count"])


# ============================================================
# POMDP wrapper with curriculum
# ============================================================

class ScheduledPartialObsWrapper(gym.ObservationWrapper):
    """
    partial_indices: 일부 차원만 관측
    flicker/noise는 progress에 따라 start -> end
    """
    def __init__(
        self,
        env: gym.Env,
        partial_indices: Optional[List[int]],
        flicker_prob_start: float,
        flicker_prob_end: float,
        noise_std_start: float,
        noise_std_end: float,
    ):
        super().__init__(env)
        self.partial_indices = partial_indices
        self.flicker_prob_start = float(flicker_prob_start)
        self.flicker_prob_end = float(flicker_prob_end)
        self.noise_std_start = float(noise_std_start)
        self.noise_std_end = float(noise_std_end)
        self.progress = 0.0

        assert isinstance(env.observation_space, gym.spaces.Box), "Only Box observation supported"
        low = env.observation_space.low
        high = env.observation_space.high

        if self.partial_indices is None:
            self.partial_indices = list(range(int(np.prod(low.shape))))

        low2 = low[self.partial_indices].astype(np.float32)
        high2 = high[self.partial_indices].astype(np.float32)

        self.observation_space = gym.spaces.Box(
            low=low2,
            high=high2,
            shape=(len(self.partial_indices),),
            dtype=np.float32,
        )

    def set_progress(self, progress01: float):
        self.progress = max(0.0, min(1.0, float(progress01)))

    def get_current_params(self):
        flicker_prob = linear_interp(self.flicker_prob_start, self.flicker_prob_end, self.progress)
        noise_std = linear_interp(self.noise_std_start, self.noise_std_end, self.progress)
        return flicker_prob, noise_std

    def observation(self, obs):
        obs = np.asarray(obs, dtype=np.float32)
        obs = obs[self.partial_indices].astype(np.float32)

        flicker_prob, noise_std = self.get_current_params()

        if flicker_prob > 0.0 and np.random.rand() < flicker_prob:
            obs = np.zeros_like(obs, dtype=np.float32)

        if noise_std > 0.0:
            obs = obs + np.random.normal(0.0, noise_std, size=obs.shape).astype(np.float32)

        return obs.astype(np.float32)


# ============================================================
# Reward shaping
# ============================================================

class RewardShaper:
    def reset(self, obs: np.ndarray):
        pass

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        return float(raw_reward)


class IdentityShaper(RewardShaper):
    pass


class CartPoleShaper(RewardShaper):
    """
    CartPole은 원래 dense reward라 shaping 거의 안 함.
    너무 과한 shaping은 오히려 망가질 수 있으니 작은 안정화만.
    """
    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        theta = abs(float(next_obs[2])) if len(next_obs) >= 3 else 0.0
        x = abs(float(next_obs[0])) if len(next_obs) >= 1 else 0.0
        bonus = 0.05 * max(0.0, 0.2 - theta) - 0.01 * x
        return float(raw_reward + bonus)


class MountainCarShaper(RewardShaper):
    """
    potential-based shaping:
    높이 + 진행 방향 + 정상 종료 bonus
    """
    def potential(self, obs):
        pos = float(obs[0])
        vel = float(obs[1])
        return 5.0 * pos + 1.0 * vel

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        gamma = 0.99
        shaped = float(raw_reward) + gamma * self.potential(next_obs) - self.potential(obs)
        if terminated and float(next_obs[0]) >= 0.5:
            shaped += 10.0
        return shaped


class AcrobotShaper(RewardShaper):
    """
    Acrobot용 shaping
    - end-effector 높이 잠재함수
    - 과도한 각속도 약한 패널티
    - 성공 시 bonus
    """
    def tip_height(self, obs):
        c1, s1, c2, s2 = float(obs[0]), float(obs[1]), float(obs[2]), float(obs[3])
        theta1 = math.atan2(s1, c1)
        theta2 = math.atan2(s2, c2)
        y = -math.cos(theta1) - math.cos(theta1 + theta2)
        return y

    def potential(self, obs):
        y = self.tip_height(obs)
        d1 = float(obs[4]) if len(obs) > 4 else 0.0
        d2 = float(obs[5]) if len(obs) > 5 else 0.0
        vel_pen = 0.03 * (abs(d1) + abs(d2))
        return 6.0 * y - vel_pen

    def train_reward(self, obs, action, next_obs, raw_reward, terminated, truncated):
        gamma = 0.99
        shaped = float(raw_reward) + gamma * self.potential(next_obs) - self.potential(obs)
        if terminated:
            shaped += 15.0
        return shaped


# ============================================================
# Presets
# ============================================================

@dataclass
class EnvPreset:
    name: str
    env_id: str
    partial_indices: Optional[List[int]]

    flicker_prob_start: float
    flicker_prob_end: float
    noise_std_start: float
    noise_std_end: float

    max_steps: int
    solve_score: Optional[float]
    recommended_episodes: int

    lr: float
    lr_end_scale: float
    gamma: float
    gae_lambda: float
    ppo_clip: float
    value_clip: float
    ppo_epochs: int
    minibatch_tokens: int
    steps_per_update: int
    value_coef: float
    max_grad_norm: float
    target_kl: float

    ent_start: float
    ent_end: float

    mlp_hidden: int
    lstm_hidden: int

    shaper: str


def get_presets() -> Dict[str, EnvPreset]:
    presets = {
        # ----------------------------------------------------
        # RELIABLE
        # ----------------------------------------------------
        "cartpole_reliable": EnvPreset(
            name="cartpole_reliable",
            env_id="CartPole-v1",
            partial_indices=[0, 1, 2, 3],
            flicker_prob_start=0.00,
            flicker_prob_end=0.03,
            noise_std_start=0.0,
            noise_std_end=0.003,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=4000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=4,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.03,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),

        "acrobot_reliable": EnvPreset(
            name="acrobot_reliable",
            env_id="Acrobot-v1",
            partial_indices=[0, 1, 2, 3, 4, 5],
            flicker_prob_start=0.00,
            flicker_prob_end=0.03,
            noise_std_start=0.0,
            noise_std_end=0.001,
            max_steps=500,
            solve_score=-100.0,
            recommended_episodes=16000,
            lr=2.5e-4,
            lr_end_scale=0.15,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=8,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.6,
            max_grad_norm=0.7,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.002,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="acrobot",
        ),

        "acrobot_reliable_v2": EnvPreset(
            name="acrobot_reliable_v2",
            env_id="Acrobot-v1",
            partial_indices=[0, 1, 2, 3, 4, 5],
            flicker_prob_start=0.00,
            flicker_prob_end=0.02,
            noise_std_start=0.0,
            noise_std_end=0.0005,
            max_steps=500,
            solve_score=-100.0,
            recommended_episodes=20000,
            lr=1.5e-4,
            lr_end_scale=0.25,
            gamma=0.995,
            gae_lambda=0.98,
            ppo_clip=0.15,
            value_clip=0.15,
            ppo_epochs=10,
            minibatch_tokens=4096,
            steps_per_update=4096,
            value_coef=0.8,
            max_grad_norm=0.5,
            target_kl=0.015,
            ent_start=0.015,
            ent_end=0.001,
            mlp_hidden=256,
            lstm_hidden=192,
            shaper="acrobot",
        ),

        "mountaincar_reliable": EnvPreset(
            name="mountaincar_reliable",
            env_id="MountainCar-v0",
            partial_indices=[0, 1],
            flicker_prob_start=0.00,
            flicker_prob_end=0.02,
            noise_std_start=0.0,
            noise_std_end=0.0005,
            max_steps=200,
            solve_score=-110.0,
            recommended_episodes=18000,
            lr=2e-4,
            lr_end_scale=0.10,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=10,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.7,
            max_grad_norm=0.7,
            target_kl=0.02,
            ent_start=0.03,
            ent_end=0.003,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="mountaincar",
        ),

        # ----------------------------------------------------
        # MEDIUM POMDP
        # ----------------------------------------------------
        "cartpole_medium": EnvPreset(
            name="cartpole_medium",
            env_id="CartPole-v1",
            partial_indices=[0, 2, 3],
            flicker_prob_start=0.01,
            flicker_prob_end=0.06,
            noise_std_start=0.001,
            noise_std_end=0.01,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=6000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=5,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.03,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),

        "acrobot_medium": EnvPreset(
            name="acrobot_medium",
            env_id="Acrobot-v1",
            partial_indices=[0, 1, 2, 3, 5],
            flicker_prob_start=0.01,
            flicker_prob_end=0.05,
            noise_std_start=0.0,
            noise_std_end=0.003,
            max_steps=500,
            solve_score=-100.0,
            recommended_episodes=22000,
            lr=2.5e-4,
            lr_end_scale=0.15,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=8,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.6,
            max_grad_norm=0.7,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.002,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="acrobot",
        ),

        "mountaincar_medium": EnvPreset(
            name="mountaincar_medium",
            env_id="MountainCar-v0",
            partial_indices=[0, 1],
            flicker_prob_start=0.01,
            flicker_prob_end=0.05,
            noise_std_start=0.0002,
            noise_std_end=0.003,
            max_steps=200,
            solve_score=-110.0,
            recommended_episodes=24000,
            lr=2e-4,
            lr_end_scale=0.10,
            gamma=0.99,
            gae_lambda=0.97,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=10,
            minibatch_tokens=2048,
            steps_per_update=4096,
            value_coef=0.7,
            max_grad_norm=0.7,
            target_kl=0.02,
            ent_start=0.03,
            ent_end=0.003,
            mlp_hidden=256,
            lstm_hidden=128,
            shaper="mountaincar",
        ),

        # ----------------------------------------------------
        # HARD
        # ----------------------------------------------------
        "cartpole_partial_hard": EnvPreset(
            name="cartpole_partial_hard",
            env_id="CartPole-v1",
            partial_indices=[0, 2],
            flicker_prob_start=0.02,
            flicker_prob_end=0.10,
            noise_std_start=0.001,
            noise_std_end=0.02,
            max_steps=500,
            solve_score=475.0,
            recommended_episodes=9000,
            lr=3e-4,
            lr_end_scale=0.20,
            gamma=0.99,
            gae_lambda=0.95,
            ppo_clip=0.2,
            value_clip=0.2,
            ppo_epochs=6,
            minibatch_tokens=1024,
            steps_per_update=1024,
            value_coef=0.5,
            max_grad_norm=0.5,
            target_kl=0.025,
            ent_start=0.02,
            ent_end=0.001,
            mlp_hidden=128,
            lstm_hidden=128,
            shaper="cartpole",
        ),
    }
    return presets


def get_shaper(name: str) -> RewardShaper:
    name = str(name).lower()
    if name == "cartpole":
        return CartPoleShaper()
    if name == "acrobot":
        return AcrobotShaper()
    if name == "mountaincar":
        return MountainCarShaper()
    return IdentityShaper()


def build_env(preset: EnvPreset, seed: Optional[int] = None):
    env = gym.make(preset.env_id)
    env = ScheduledPartialObsWrapper(
        env=env,
        partial_indices=preset.partial_indices,
        flicker_prob_start=preset.flicker_prob_start,
        flicker_prob_end=preset.flicker_prob_end,
        noise_std_start=preset.noise_std_start,
        noise_std_end=preset.noise_std_end,
    )
    if seed is not None:
        env.reset(seed=seed)
        env.action_space.seed(seed)
    return env


# ============================================================
# Model
# ============================================================

class RecurrentActorCritic(nn.Module):
    def __init__(self, obs_dim: int, action_dim: int, mlp_hidden: int, lstm_hidden: int):
        super().__init__()

        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.mlp_hidden = mlp_hidden
        self.lstm_hidden = lstm_hidden

        self.encoder = nn.Sequential(
            nn.Linear(obs_dim, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
            nn.Linear(mlp_hidden, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
        )

        self.lstm = nn.LSTM(
            input_size=mlp_hidden,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
        )

        self.actor = nn.Linear(lstm_hidden, action_dim)
        self.critic = nn.Linear(lstm_hidden, 1)

        self.apply(self._init_weights)

        nn.init.orthogonal_(self.actor.weight, gain=0.01)
        nn.init.zeros_(self.actor.bias)
        nn.init.orthogonal_(self.critic.weight, gain=1.0)
        nn.init.zeros_(self.critic.bias)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.orthogonal_(m.weight, gain=math.sqrt(2))
            nn.init.zeros_(m.bias)

    def initial_state(self, batch_size: int, device: torch.device):
        h = torch.zeros((1, batch_size, self.lstm_hidden), device=device)
        c = torch.zeros((1, batch_size, self.lstm_hidden), device=device)
        return (h, c)

    def forward(self, obs_seq: torch.Tensor, hidden=None):
        x = self.encoder(obs_seq)
        x, hidden = self.lstm(x, hidden)
        logits = self.actor(x)
        values = self.critic(x)
        return logits, values, hidden

    @torch.no_grad()
    def act(self, obs_t: torch.Tensor, hidden):
        logits, value, hidden = self.forward(obs_t, hidden)
        logits = logits[:, -1, :]
        value = value[:, -1, :]
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        entropy = dist.entropy()
        return (
            int(action.item()),
            float(log_prob.item()),
            float(value.item()),
            float(entropy.item()),
            hidden,
        )


# ============================================================
# Rollout buffer
# ============================================================

class RolloutBuffer:
    def __init__(self):
        self.obs = []
        self.actions = []
        self.train_rewards = []
        self.raw_rewards = []
        self.dones = []
        self.log_probs = []
        self.values = []
        self.episode_ids = []
        self.bootstrap_values = []

    def clear(self):
        self.__init__()

    def add(self, obs, action, train_reward, raw_reward, done, log_prob, value, episode_id):
        self.obs.append(np.asarray(obs, dtype=np.float32))
        self.actions.append(int(action))
        self.train_rewards.append(float(train_reward))
        self.raw_rewards.append(float(raw_reward))
        self.dones.append(bool(done))
        self.log_probs.append(float(log_prob))
        self.values.append(float(value))
        self.episode_ids.append(int(episode_id))

    def __len__(self):
        return len(self.obs)


# ============================================================
# Metrics / GAE / segments
# ============================================================

def compute_train_metrics(raw_rewards: List[float], solve_score: Optional[float]):
    r = np.asarray(raw_rewards, dtype=np.float32)
    if len(r) == 0:
        return {
            "auc_mean": 0.0,
            "last100_mean": 0.0,
            "last100_std": 0.0,
            "best_reward": 0.0,
            "first_solve_ep": -1,
        }

    tail = r[-100:] if len(r) >= 100 else r
    last100_mean = float(tail.mean())
    last100_std = float(tail.std(ddof=0))
    best_reward = float(r.max())
    auc_mean = float(r.mean())

    first_solve_ep = -1
    if solve_score is not None and len(r) >= 100:
        win = np.convolve(r, np.ones(100, dtype=np.float32) / 100.0, mode="valid")
        idx = np.where(win >= solve_score)[0]
        if len(idx) > 0:
            first_solve_ep = int(idx[0] + 100)

    return {
        "auc_mean": auc_mean,
        "last100_mean": last100_mean,
        "last100_std": last100_std,
        "best_reward": best_reward,
        "first_solve_ep": int(first_solve_ep),
    }


def compute_gae(
    rewards: np.ndarray,
    values: np.ndarray,
    dones: np.ndarray,
    next_value: float,
    gamma: float,
    gae_lambda: float,
):
    n = len(rewards)
    advantages = np.zeros(n, dtype=np.float32)
    last_gae = 0.0
    for t in reversed(range(n)):
        if t == n - 1:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = next_value
        else:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = values[t + 1]

        delta = rewards[t] + gamma * next_values * next_nonterminal - values[t]
        last_gae = delta + gamma * gae_lambda * next_nonterminal * last_gae
        advantages[t] = last_gae

    returns = advantages + values
    return advantages, returns


def split_into_segments_preview(buffer: RolloutBuffer):
    if len(buffer) == 0:
        return []

    segments = []
    start = 0
    n = len(buffer)

    for i in range(n - 1):
        if buffer.dones[i] or buffer.episode_ids[i + 1] != buffer.episode_ids[i]:
            segments.append(slice(start, i + 1))
            start = i + 1

    if start < n:
        segments.append(slice(start, n))

    return segments


def split_into_segments(buffer: RolloutBuffer):
    previews = split_into_segments_preview(buffer)
    out = []
    for idx, sl in enumerate(previews):
        out.append((sl, buffer.bootstrap_values[idx]))
    return out


def pad_sequences(arrays: List[np.ndarray], pad_value: float = 0.0):
    max_len = max(a.shape[0] for a in arrays)

    padded = []
    masks = []
    for a in arrays:
        T = a.shape[0]
        pad_shape = (max_len - T,) + a.shape[1:]
        if len(pad_shape) == 1:
            pad_arr = np.full((max_len - T,), pad_value, dtype=a.dtype)
        else:
            pad_arr = np.full(pad_shape, pad_value, dtype=a.dtype)

        padded_arr = np.concatenate([a, pad_arr], axis=0)
        mask = np.concatenate(
            [np.ones(T, dtype=np.float32), np.zeros(max_len - T, dtype=np.float32)],
            axis=0,
        )
        padded.append(padded_arr)
        masks.append(mask)

    return np.stack(padded), np.stack(masks)


# ============================================================
# Evaluation
# ============================================================

@torch.no_grad()
def evaluate_policy(
    model: nn.Module,
    preset: EnvPreset,
    device: torch.device,
    obs_rms: RunningMeanStd,
    n_episodes: int = 10,
    greedy: bool = True,
):
    env = build_env(preset, seed=12345)
    env.set_progress(1.0)
    scores = []

    try:
        for ep in range(n_episodes):
            obs, _ = env.reset(seed=12345 + ep)
            hidden = unwrap_model(model).initial_state(batch_size=1, device=device)
            done = False
            ep_reward = 0.0
            steps = 0

            while not done and steps < preset.max_steps:
                obs_n = obs_rms.normalize(obs)
                obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                logits, _, hidden = model(obs_t, hidden)
                logits = logits[:, -1, :]
                dist = Categorical(logits=logits)
                action = torch.argmax(dist.probs, dim=-1) if greedy else dist.sample()

                obs, reward, terminated, truncated, _ = env.step(int(action.item()))
                done = terminated or truncated
                ep_reward += float(reward)
                steps += 1

            scores.append(ep_reward)
    finally:
        env.close()

    arr = np.asarray(scores, dtype=np.float32)
    return {
        "eval_mean": float(arr.mean()) if len(arr) else 0.0,
        "eval_std": float(arr.std(ddof=0)) if len(arr) else 0.0,
        "eval_min": float(arr.min()) if len(arr) else 0.0,
        "eval_max": float(arr.max()) if len(arr) else 0.0,
    }


# ============================================================
# PPO update
# ============================================================

def ppo_update(
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    buffer: RolloutBuffer,
    preset: EnvPreset,
    device: torch.device,
    use_amp: bool,
    progress01: float,
):
    segments = split_into_segments(buffer)
    if not segments:
        return {
            "loss_total": 0.0,
            "loss_policy": 0.0,
            "loss_value": 0.0,
            "entropy": 0.0,
            "approx_kl": 0.0,
            "early_stop_kl": 0,
        }

    obs_list = []
    act_list = []
    old_logp_list = []
    adv_list = []
    ret_list = []
    old_value_list = []

    for sl, bootstrap_value in segments:
        rewards = np.asarray(buffer.train_rewards[sl], dtype=np.float32)
        values = np.asarray(buffer.values[sl], dtype=np.float32)
        dones = np.asarray(buffer.dones[sl], dtype=np.float32)

        adv, ret = compute_gae(
            rewards=rewards,
            values=values,
            dones=dones,
            next_value=float(bootstrap_value),
            gamma=preset.gamma,
            gae_lambda=preset.gae_lambda,
        )

        obs_arr = np.asarray(buffer.obs[sl], dtype=np.float32)
        act_arr = np.asarray(buffer.actions[sl], dtype=np.int64)
        logp_arr = np.asarray(buffer.log_probs[sl], dtype=np.float32)
        val_arr = np.asarray(buffer.values[sl], dtype=np.float32)

        obs_list.append(obs_arr)
        act_list.append(act_arr)
        old_logp_list.append(logp_arr)
        adv_list.append(adv.astype(np.float32))
        ret_list.append(ret.astype(np.float32))
        old_value_list.append(val_arr.astype(np.float32))

    all_adv = np.concatenate(adv_list, axis=0)
    adv_mean = all_adv.mean()
    adv_std = all_adv.std() + 1e-8
    adv_list = [((a - adv_mean) / adv_std).astype(np.float32) for a in adv_list]

    obs_pad, mask = pad_sequences(obs_list, pad_value=0.0)
    act_pad, _ = pad_sequences([a[:, None] for a in act_list], pad_value=0)
    old_logp_pad, _ = pad_sequences([a[:, None] for a in old_logp_list], pad_value=0.0)
    adv_pad, _ = pad_sequences([a[:, None] for a in adv_list], pad_value=0.0)
    ret_pad, _ = pad_sequences([a[:, None] for a in ret_list], pad_value=0.0)
    old_val_pad, _ = pad_sequences([a[:, None] for a in old_value_list], pad_value=0.0)

    obs_t = torch.as_tensor(obs_pad, dtype=torch.float32, device=device)
    act_t = torch.as_tensor(act_pad.squeeze(-1), dtype=torch.long, device=device)
    old_logp_t = torch.as_tensor(old_logp_pad.squeeze(-1), dtype=torch.float32, device=device)
    adv_t = torch.as_tensor(adv_pad.squeeze(-1), dtype=torch.float32, device=device)
    ret_t = torch.as_tensor(ret_pad.squeeze(-1), dtype=torch.float32, device=device)
    old_val_t = torch.as_tensor(old_val_pad.squeeze(-1), dtype=torch.float32, device=device)
    mask_t = torch.as_tensor(mask, dtype=torch.float32, device=device)

    n_seq = obs_t.shape[0]
    idxs = np.arange(n_seq)

    ent_coef = linear_interp(preset.ent_start, preset.ent_end, progress01)

    total_loss_v = []
    policy_loss_v = []
    value_loss_v = []
    entropy_v = []
    approx_kl_v = []
    early_stop_kl = 0

    seqs_per_batch = max(1, preset.minibatch_tokens // max(1, obs_t.shape[1]))

    for _ in range(preset.ppo_epochs):
        np.random.shuffle(idxs)
        stop_this_epoch = False

        for start in range(0, n_seq, seqs_per_batch):
            batch_idx = idxs[start:start + seqs_per_batch]

            b_obs = obs_t[batch_idx]
            b_act = act_t[batch_idx]
            b_old_logp = old_logp_t[batch_idx]
            b_adv = adv_t[batch_idx]
            b_ret = ret_t[batch_idx]
            b_old_val = old_val_t[batch_idx]
            b_mask = mask_t[batch_idx]

            hidden = unwrap_model(model).initial_state(batch_size=b_obs.shape[0], device=device)

            with torch.amp.autocast("cuda", enabled=use_amp):
                logits, values, _ = model(b_obs, hidden)
                values = values.squeeze(-1)

                dist = Categorical(logits=logits)
                new_logp = dist.log_prob(b_act)
                entropy = dist.entropy()

                ratio = torch.exp(new_logp - b_old_logp)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - preset.ppo_clip, 1.0 + preset.ppo_clip) * b_adv
                policy_loss = -torch.sum(torch.min(surr1, surr2) * b_mask) / (torch.sum(b_mask) + 1e-8)

                value_pred_clipped = b_old_val + torch.clamp(values - b_old_val, -preset.value_clip, preset.value_clip)
                value_loss_unclipped = (values - b_ret) ** 2
                value_loss_clipped = (value_pred_clipped - b_ret) ** 2
                value_loss_all = 0.5 * torch.max(value_loss_unclipped, value_loss_clipped)
                value_loss = torch.sum(value_loss_all * b_mask) / (torch.sum(b_mask) + 1e-8)

                entropy_mean = torch.sum(entropy * b_mask) / (torch.sum(b_mask) + 1e-8)
                loss = policy_loss + preset.value_coef * value_loss - ent_coef * entropy_mean

            optimizer.zero_grad(set_to_none=True)
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(unwrap_model(model).parameters(), preset.max_grad_norm)
            scaler.step(optimizer)
            scaler.update()

            with torch.no_grad():
                approx_kl = torch.sum((b_old_logp - new_logp) * b_mask) / (torch.sum(b_mask) + 1e-8)

            total_loss_v.append(float(loss.item()))
            policy_loss_v.append(float(policy_loss.item()))
            value_loss_v.append(float(value_loss.item()))
            entropy_v.append(float(entropy_mean.item()))
            approx_kl_v.append(float(approx_kl.item()))

            if float(approx_kl.item()) > float(preset.target_kl):
                early_stop_kl += 1
                stop_this_epoch = True
                break

        if stop_this_epoch:
            break

    return {
        "loss_total": float(np.mean(total_loss_v)) if total_loss_v else 0.0,
        "loss_policy": float(np.mean(policy_loss_v)) if policy_loss_v else 0.0,
        "loss_value": float(np.mean(value_loss_v)) if value_loss_v else 0.0,
        "entropy": float(np.mean(entropy_v)) if entropy_v else 0.0,
        "approx_kl": float(np.mean(approx_kl_v)) if approx_kl_v else 0.0,
        "early_stop_kl": int(early_stop_kl),
    }


# ============================================================
# Checkpoint
# ============================================================

def ckpt_path(ckpt_dir: str, preset_name: str, seed: int):
    ensure_dir(ckpt_dir)
    return os.path.join(ckpt_dir, f"{preset_name}_seed{seed}_latest.pt")


def meta_path(ckpt_dir: str, preset_name: str, seed: int):
    ensure_dir(ckpt_dir)
    return os.path.join(ckpt_dir, f"{preset_name}_seed{seed}_meta.json")


def save_json(path: str, data: Dict[str, Any]):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)


def save_checkpoint(
    path: str,
    episode: int,
    global_step: int,
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    obs_rms: RunningMeanStd,
    raw_train_rewards: List[float],
    train_reward_history: List[float],
    eval_history: List[Dict[str, Any]],
    config: Dict[str, Any],
):
    payload = {
        "episode": int(episode),
        "global_step": int(global_step),
        "model": model_state_dict(model),
        "optimizer": optimizer.state_dict(),
        "scaler": scaler.state_dict(),
        "obs_rms": obs_rms.state_dict(),
        "raw_train_rewards": list(raw_train_rewards),
        "train_reward_history": list(train_reward_history),
        "eval_history": list(eval_history),
        "config": config,
    }
    torch.save(payload, path)


def load_checkpoint(
    path: str,
    model: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: torch.amp.GradScaler,
    obs_rms: RunningMeanStd,
    device: torch.device,
):
    payload = torch.load(path, map_location=device)

    load_model_state_dict(model, payload["model"], strict=True)
    optimizer.load_state_dict(payload["optimizer"])

    try:
        scaler.load_state_dict(payload["scaler"])
    except Exception:
        pass

    if "obs_rms" in payload:
        obs_rms.load_state_dict(payload["obs_rms"])

    return {
        "episode": int(payload.get("episode", -1)),
        "global_step": int(payload.get("global_step", 0)),
        "raw_train_rewards": list(payload.get("raw_train_rewards", [])),
        "train_reward_history": list(payload.get("train_reward_history", [])),
        "eval_history": list(payload.get("eval_history", [])),
        "config": payload.get("config", {}),
    }


# ============================================================
# One experiment
# ============================================================

def run_experiment(
    preset: EnvPreset,
    seed: int,
    total_episodes_override: Optional[int],
    eval_every: int,
    eval_episodes: int,
    save_every: int,
    log_every: int,
    device: torch.device,
    ckpt_dir: str,
    compile_models: bool,
    resume: bool,
    amp: bool,
):
    set_global_seed(seed)

    env = build_env(preset, seed=seed)
    shaper = get_shaper(preset.shaper)

    obs_dim = int(np.prod(env.observation_space.shape))
    assert isinstance(env.action_space, gym.spaces.Discrete), "Only discrete action spaces supported"
    action_dim = int(env.action_space.n)

    model = RecurrentActorCritic(
        obs_dim=obs_dim,
        action_dim=action_dim,
        mlp_hidden=preset.mlp_hidden,
        lstm_hidden=preset.lstm_hidden,
    ).to(device)

    if compile_models:
        model = maybe_compile(model, True)

    optimizer = torch.optim.Adam(unwrap_model(model).parameters(), lr=preset.lr, eps=1e-5)
    use_amp = bool(amp) and (device.type == "cuda")
    scaler = torch.amp.GradScaler("cuda", enabled=use_amp)

    obs_rms = RunningMeanStd(shape=(obs_dim,))

    episodes_target = int(total_episodes_override) if total_episodes_override is not None else int(preset.recommended_episodes)

    start_episode = 0
    global_step = 0
    raw_train_rewards: List[float] = []
    train_reward_history: List[float] = []
    eval_history: List[Dict[str, Any]] = []

    cpath = ckpt_path(ckpt_dir, preset.name, seed)
    mpath = meta_path(ckpt_dir, preset.name, seed)

    if resume and os.path.exists(cpath):
        print(f"[resume] loading {cpath}")
        state = load_checkpoint(cpath, model, optimizer, scaler, obs_rms, device)
        start_episode = int(state["episode"]) + 1
        global_step = int(state["global_step"])
        raw_train_rewards = state["raw_train_rewards"]
        train_reward_history = state["train_reward_history"]
        eval_history = state["eval_history"]
        print(f"[resume] preset={preset.name} seed={seed} start_episode={start_episode}")

    buffer = RolloutBuffer()

    try:
        if start_episode >= episodes_target:
            print(f"[skip] already finished: {preset.name} seed={seed}")
            result = {
                "preset": preset.name,
                "env_id": preset.env_id,
                "seed": seed,
                "episodes_completed": len(raw_train_rewards),
                **compute_train_metrics(raw_train_rewards, preset.solve_score),
            }
            if eval_history:
                result.update(eval_history[-1])
            return result

        obs, _ = env.reset(seed=seed + 123)
        shaper.reset(obs)
        hidden = unwrap_model(model).initial_state(batch_size=1, device=device)

        episode_idx = start_episode
        ep_raw_reward = 0.0
        ep_train_reward = 0.0
        ep_steps = 0

        while episode_idx < episodes_target:
            progress01 = episode_idx / max(1, episodes_target - 1)
            env.set_progress(progress01)

            lr_now = linear_interp(preset.lr, preset.lr * preset.lr_end_scale, progress01)
            for g in optimizer.param_groups:
                g["lr"] = lr_now

            obs_rms.update(np.asarray(obs, dtype=np.float32)[None, :])
            obs_n = obs_rms.normalize(obs)

            obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
            action, log_prob, value, _entropy, hidden = unwrap_model(model).act(obs_t, hidden)

            next_obs, raw_reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            train_reward = shaper.train_reward(
                obs=obs,
                action=action,
                next_obs=next_obs,
                raw_reward=raw_reward,
                terminated=terminated,
                truncated=truncated,
            )

            buffer.add(
                obs=obs_n,
                action=action,
                train_reward=train_reward,
                raw_reward=raw_reward,
                done=done,
                log_prob=log_prob,
                value=value,
                episode_id=episode_idx,
            )

            obs = next_obs
            ep_raw_reward += float(raw_reward)
            ep_train_reward += float(train_reward)
            ep_steps += 1
            global_step += 1

            if done or ep_steps >= preset.max_steps:
                buffer.bootstrap_values.append(0.0)
                raw_train_rewards.append(float(ep_raw_reward))
                train_reward_history.append(float(ep_train_reward))

                if (episode_idx % log_every) == 0:
                    recent = raw_train_rewards[-20:] if len(raw_train_rewards) >= 20 else raw_train_rewards
                    recent_mean = float(np.mean(recent)) if recent else 0.0
                    flicker_now, noise_now = env.get_current_params()
                    print(
                        f"[{preset.name} seed={seed}] "
                        f"ep={episode_idx:05d} "
                        f"rawR={ep_raw_reward:8.3f} "
                        f"trainR={ep_train_reward:8.3f} "
                        f"recent20={recent_mean:8.3f} "
                        f"flicker={flicker_now:.3f} "
                        f"noise={noise_now:.4f} "
                        f"lr={lr_now:.6f} "
                        f"global_step={global_step}"
                    )

                if ((episode_idx + 1) % eval_every) == 0 or (episode_idx + 1) == episodes_target:
                    eval_result = evaluate_policy(
                        model=model,
                        preset=preset,
                        device=device,
                        obs_rms=obs_rms,
                        n_episodes=eval_episodes,
                        greedy=True,
                    )
                    eval_result["eval_at_episode"] = int(episode_idx + 1)
                    eval_history.append(eval_result)

                    print(
                        f"[eval] {preset.name} seed={seed} "
                        f"ep={episode_idx+1} "
                        f"mean={eval_result['eval_mean']:.3f} "
                        f"std={eval_result['eval_std']:.3f}"
                    )

                if ((episode_idx + 1) % save_every) == 0 or STOP_REQUESTED:
                    save_checkpoint(
                        path=cpath,
                        episode=episode_idx,
                        global_step=global_step,
                        model=model,
                        optimizer=optimizer,
                        scaler=scaler,
                        obs_rms=obs_rms,
                        raw_train_rewards=raw_train_rewards,
                        train_reward_history=train_reward_history,
                        eval_history=eval_history,
                        config={
                            "preset": asdict(preset),
                            "seed": seed,
                            "episodes_target": episodes_target,
                        },
                    )
                    save_json(mpath, {
                        "preset": preset.name,
                        "env_id": preset.env_id,
                        "seed": seed,
                        "last_saved_episode": episode_idx,
                        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
                        "global_step": global_step,
                        "status": "running_or_interrupted",
                    })
                    print(f"[ckpt] saved {cpath}")

                episode_idx += 1

                if STOP_REQUESTED:
                    print("[stop] graceful stop requested.")
                    break

                obs, _ = env.reset(seed=seed * 100000 + episode_idx)
                shaper.reset(obs)
                hidden = unwrap_model(model).initial_state(batch_size=1, device=device)
                ep_raw_reward = 0.0
                ep_train_reward = 0.0
                ep_steps = 0

            if len(buffer) >= preset.steps_per_update or (STOP_REQUESTED and len(buffer) > 0):
                needed_segments = len(split_into_segments_preview(buffer))
                if len(buffer.bootstrap_values) < needed_segments:
                    with torch.no_grad():
                        obs_n = obs_rms.normalize(obs)
                        obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                        _, value_t, _ = model(obs_t, hidden)
                        bootstrap_value = float(value_t[:, -1, :].item()) if not done else 0.0
                    buffer.bootstrap_values.append(bootstrap_value)

                update_stats = ppo_update(
                    model=model,
                    optimizer=optimizer,
                    scaler=scaler,
                    buffer=buffer,
                    preset=preset,
                    device=device,
                    use_amp=use_amp,
                    progress01=progress01,
                )

                print(
                    f"[update] {preset.name} seed={seed} "
                    f"loss={update_stats['loss_total']:.4f} "
                    f"policy={update_stats['loss_policy']:.4f} "
                    f"value={update_stats['loss_value']:.4f} "
                    f"entropy={update_stats['entropy']:.4f} "
                    f"kl={update_stats['approx_kl']:.4f} "
                    f"early_stop_kl={update_stats['early_stop_kl']}"
                )

                buffer.clear()

                if STOP_REQUESTED:
                    break

        final_episode = min(max(start_episode, len(raw_train_rewards)) - 1, episodes_target - 1)
        if final_episode >= 0:
            save_checkpoint(
                path=cpath,
                episode=final_episode,
                global_step=global_step,
                model=model,
                optimizer=optimizer,
                scaler=scaler,
                obs_rms=obs_rms,
                raw_train_rewards=raw_train_rewards,
                train_reward_history=train_reward_history,
                eval_history=eval_history,
                config={
                    "preset": asdict(preset),
                    "seed": seed,
                    "episodes_target": episodes_target,
                },
            )
            save_json(mpath, {
                "preset": preset.name,
                "env_id": preset.env_id,
                "seed": seed,
                "last_saved_episode": final_episode,
                "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
                "global_step": global_step,
                "status": "finished_or_stopped",
            })
            print(f"[ckpt] final saved {cpath}")

        result = {
            "preset": preset.name,
            "env_id": preset.env_id,
            "seed": seed,
            "episodes_completed": len(raw_train_rewards),
            **compute_train_metrics(raw_train_rewards, preset.solve_score),
        }
        if eval_history:
            result.update(eval_history[-1])

        return result

    finally:
        try:
            env.close()
        except Exception:
            pass
        cleanup_torch(device)


# ============================================================
# Aggregation / save
# ============================================================

def aggregate_results(results: List[Dict[str, Any]]):
    grouped: Dict[str, List[Dict[str, Any]]] = {}
    for r in results:
        grouped.setdefault(str(r["preset"]), []).append(r)

    keys = [
        "auc_mean",
        "last100_mean",
        "last100_std",
        "best_reward",
        "first_solve_ep",
        "eval_mean",
        "eval_std",
        "episodes_completed",
    ]

    out = []
    for preset_name, rows in grouped.items():
        item = {
            "preset": preset_name,
            "n_seeds": len(rows),
        }
        for k in keys:
            vals = [float(x[k]) for x in rows if k in x]
            item[k] = float(np.mean(vals)) if vals else 0.0
        out.append(item)

    out.sort(key=lambda x: x["last100_mean"], reverse=True)
    return out


def save_csv(path: str, rows: List[Dict[str, Any]]):
    ensure_dir(os.path.dirname(path) or ".")
    if not rows:
        with open(path, "w", newline="", encoding="utf-8") as f:
            f.write("")
        return

    cols = sorted({k for r in rows for k in r.keys()})
    with open(path, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.DictWriter(f, fieldnames=cols)
        writer.writeheader()
        writer.writerows(rows)


def save_json_rows(path: str, rows: List[Dict[str, Any]]):
    ensure_dir(os.path.dirname(path) or ".")
    with open(path, "w", encoding="utf-8") as f:
        json.dump(rows, f, ensure_ascii=False, indent=2)


# ============================================================
# Args
# ============================================================

def parse_args():
    p = argparse.ArgumentParser(add_help=True)

    p.add_argument("--device", type=str, default=None, help="cuda:0 / cpu / auto(None)")
    p.add_argument("--amp", action="store_true", help="use amp on cuda")
    p.add_argument("--no-amp", dest="amp", action="store_false")
    p.set_defaults(amp=USE_AMP_DEFAULT)

    p.add_argument("--compile", action="store_true")
    p.add_argument("--resume", action="store_true")

    p.add_argument(
        "--presets",
        type=str,
        default="cartpole_reliable,acrobot_reliable,mountaincar_reliable",
        help="comma-separated preset names",
    )
    p.add_argument("--seeds", type=str, default="0,1,2")
    p.add_argument("--total-episodes", type=int, default=None)

    p.add_argument("--eval-every", type=int, default=250)
    p.add_argument("--eval-episodes", type=int, default=10)
    p.add_argument("--save-every", type=int, default=250)
    p.add_argument("--log-every", type=int, default=20)

    p.add_argument("--ckpt-dir", type=str, default="./checkpoints_robust_recurrent_ppo")
    p.add_argument("--raw-csv", type=str, default="./robust_recurrent_ppo_raw.csv")
    p.add_argument("--summary-csv", type=str, default="./robust_recurrent_ppo_summary.csv")
    p.add_argument("--raw-json", type=str, default="./robust_recurrent_ppo_raw.json")
    p.add_argument("--summary-json", type=str, default="./robust_recurrent_ppo_summary.json")

    p.add_argument("--shutdown-kernel-on-finish", action="store_true")

    args, _unknown = p.parse_known_args()
    return args


# ============================================================
# Main
# ============================================================

def main():
    args = parse_args()
    presets_map = get_presets()

    if args.device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    else:
        device = torch.device(args.device)

    if device.type == "cuda":
        torch.backends.cudnn.benchmark = True
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True

    preset_names = [x.strip() for x in args.presets.split(",") if x.strip()]
    seeds = [int(x.strip()) for x in args.seeds.split(",") if x.strip()]

    selected_presets = []
    for name in preset_names:
        if name not in presets_map:
            raise ValueError(f"unknown preset: {name}. available={list(presets_map.keys())}")
        selected_presets.append(presets_map[name])

    print("============================================================")
    print("device       =", device)
    print("amp          =", bool(args.amp and device.type == "cuda"))
    print("compile      =", args.compile)
    print("presets      =", [p.name for p in selected_presets])
    print("seeds        =", seeds)
    print("episodes     =", args.total_episodes, "(None이면 preset recommended_episodes)")
    print("============================================================")

    raw_results = []
    started = time.time()

    try:
        for preset in selected_presets:
            for seed in seeds:
                if STOP_REQUESTED:
                    break

                print(f"\n===== RUN preset={preset.name} seed={seed} =====")
                result = run_experiment(
                    preset=preset,
                    seed=seed,
                    total_episodes_override=args.total_episodes,
                    eval_every=int(args.eval_every),
                    eval_episodes=int(args.eval_episodes),
                    save_every=int(args.save_every),
                    log_every=int(args.log_every),
                    device=device,
                    ckpt_dir=args.ckpt_dir,
                    compile_models=args.compile,
                    resume=args.resume,
                    amp=args.amp,
                )
                raw_results.append(result)

            if STOP_REQUESTED:
                break

    finally:
        summary = aggregate_results(raw_results)

        save_csv(args.raw_csv, raw_results)
        save_csv(args.summary_csv, summary)
        save_json_rows(args.raw_json, raw_results)
        save_json_rows(args.summary_json, summary)

        elapsed = time.time() - started

        print("\n================ FINAL SUMMARY ================")
        if summary:
            cols = [
                "preset", "n_seeds", "episodes_completed",
                "auc_mean", "last100_mean", "best_reward",
                "first_solve_ep", "eval_mean", "eval_std"
            ]
            widths = {c: max(len(c), max(len(str(r.get(c, ""))) for r in summary)) for c in cols}
            header = " | ".join(c.ljust(widths[c]) for c in cols)
            sep = "-+-".join("-" * widths[c] for c in cols)
            print(header)
            print(sep)

            for r in summary:
                pr = dict(r)
                for k in ["episodes_completed", "n_seeds", "first_solve_ep"]:
                    if k in pr:
                        pr[k] = int(float(pr[k]))
                for k in ["auc_mean", "last100_mean", "best_reward", "eval_mean", "eval_std"]:
                    if k in pr:
                        pr[k] = f"{float(pr[k]):.3f}"
                print(" | ".join(str(pr.get(c, "")).ljust(widths[c]) for c in cols))
        else:
            print("(no results)")

        print("\nraw csv     :", args.raw_csv)
        print("summary csv :", args.summary_csv)
        print("raw json    :", args.raw_json)
        print("summary json:", args.summary_json)
        print(f"elapsed_sec : {elapsed:.2f}")

        print("\n[recommended run]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_reliable,acrobot_reliable,mountaincar_reliable "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[more POMDP]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_medium,acrobot_medium,mountaincar_medium "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[hard partial test]")
        print(
            "python robust_multi_env_recurrent_ppo.py "
            "--device cuda:0 "
            "--presets cartpole_partial_hard "
            "--seeds 0,1,2 "
            "--resume"
        )

        print("\n[important note]")
        print(
            "이 코드는 학습 안정성을 위해 reward shaping(train only)과 "
            "POMDP severity curriculum을 사용한다. "
            "평가/summary는 raw reward 기준으로 기록된다."
        )

        cleanup_torch(device)
        maybe_shutdown_kernel(bool(args.shutdown_kernel_on_finish))


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# device       = cuda:0
# amp          = True
# compile      = False
# presets      = ['mountaincar_reliable']
# seeds        = [0, 1, 2]
# episodes     = None (None이면 preset recommended_episodes)
# ============================================================
#
# ===== RUN preset=mountaincar_reliable seed=0 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/mountaincar_reliable_seed0_latest.pt
# [resume] preset=mountaincar_reliable seed=0 start_episode=18000
# [skip] already finished: mountaincar_reliable seed=0
#
# ===== RUN preset=mountaincar_reliable seed=1 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/mountaincar_reliable_seed1_latest.pt
# [resume] preset=mountaincar_reliable seed=1 start_episode=18000
# [skip] already finished: mountaincar_reliable seed=1
#
# ===== RUN preset=mountaincar_reliable seed=2 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/mountaincar_reliable_seed2_latest.pt
# [resume] preset=mountaincar_reliable seed=2 start_episode=18000
# [skip] already finished: mountaincar_reliable seed=2
#
# ================ FINAL SUMMARY ================
# preset               | n_seeds | episodes_completed | auc_mean            | last100_mean       | best_reward | first_solve_ep | eval_mean           | eval_std
# ---------------------+---------+--------------------+---------------------+--------------------+-------------+----------------+---------------------+-------------------
# mountaincar_reliable | 3       | 18000              | -191.862            | -171.307           | -148.000    | -1             | -146.933            | 10.263
#
# raw csv     : ./robust_recurrent_ppo_raw.csv
# summary csv : ./robust_recurrent_ppo_summary.csv
# raw json    : ./robust_recurrent_ppo_raw.json
# summary json: ./robust_recurrent_ppo_summary.json
# elapsed_sec : 0.92
#
# [recommended run]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_reliable,acrobot_reliable,mountaincar_reliable --seeds 0,1,2 --resume
#
# [more POMDP]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_medium,acrobot_medium,mountaincar_medium --seeds 0,1,2 --resume
#
# [hard partial test]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_partial_hard --seeds 0,1,2 --resume
#
# [important note]
# 이 코드는 학습 안정성을 위해 reward shaping(train only)과 POMDP severity curriculum을 사용한다. 평가/summary는 raw reward 기준으로 기록된다.

# %%
import os, torch, json

ckpt_dir = "./checkpoints_robust_recurrent_ppo"

for fn in sorted(os.listdir(ckpt_dir)):
    if fn.endswith("_latest.pt"):
        path = os.path.join(ckpt_dir, fn)
        ckpt = torch.load(path, map_location="cpu")
        print("=" * 80)
        print(fn)
        print("saved episode   :", ckpt.get("episode"))
        print("global_step     :", ckpt.get("global_step"))
        print("num raw rewards :", len(ckpt.get("raw_train_rewards", [])))
        print("num eval hist   :", len(ckpt.get("eval_history", [])))
# Out:
# ================================================================================
# acrobot_reliable_seed0_latest.pt
# saved episode   : 7457
# global_step     : 1957112
# num raw rewards : 7458
# num eval hist   : 29
# ================================================================================
# cartpole_reliable_seed0_latest.pt
# saved episode   : 1249
# global_step     : 72084
# num raw rewards : 1250
# num eval hist   : 5
# ================================================================================
# cartpole_reliable_seed1_latest.pt
# saved episode   : 3999
# global_step     : 264604
# num raw rewards : 4000
# num eval hist   : 16
# ================================================================================
# cartpole_reliable_seed2_latest.pt
# saved episode   : 3999
# global_step     : 252445
# num raw rewards : 4000
# num eval hist   : 16

# %%
STOP_REQUESTED = False

# %%
import sys

sys.argv = [
    "1.ipynb",
    "--device", "cuda:0",
    "--resume",
    "--ckpt-dir", "./checkpoints_robust_recurrent_ppo",
    "--presets", "acrobot_reliable",
    "--seeds", "0,1,2",
    "--save-every", "50",
    "--eval-every", "50",
    "--log-every", "20",
]

main()
# Out:
# ============================================================
# device       = cuda:0
# amp          = True
# compile      = False
# presets      = ['acrobot_reliable']
# seeds        = [0, 1, 2]
# episodes     = None (None이면 preset recommended_episodes)
# ============================================================
#
# ===== RUN preset=acrobot_reliable seed=0 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [resume] preset=acrobot_reliable seed=0 start_episode=7458
# [acrobot_reliable seed=0] ep=07460 rawR=-149.000 trainR=-121.428 recent20=-109.350 flicker=0.014 noise=0.0005 lr=0.000151 global_step=1957453
# [acrobot_reliable seed=0] ep=07480 rawR= -83.000 trainR= -56.891 recent20=-111.750 flicker=0.014 noise=0.0005 lr=0.000151 global_step=1959708
# [update] acrobot_reliable seed=0 loss=22.3470 policy=-0.0537 value=37.3423 entropy=0.3981 kl=0.0002 early_stop_kl=0
# [eval] acrobot_reliable seed=0 ep=7500 mean=-82.400 std=6.726
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [acrobot_reliable seed=0] ep=07500 rawR=-112.000 trainR= -84.687 recent20= -86.750 flicker=0.014 noise=0.0005 lr=0.000150 global_step=1961463
# [acrobot_reliable seed=0] ep=07520 rawR=-101.000 trainR= -72.383 recent20= -94.550 flicker=0.014 noise=0.0005 lr=0.000150 global_step=1963374
# [update] acrobot_reliable seed=0 loss=11.6191 policy=0.0020 value=19.3694 entropy=0.3933 kl=-0.0001 early_stop_kl=0
# [acrobot_reliable seed=0] ep=07540 rawR= -92.000 trainR= -65.929 recent20= -96.600 flicker=0.014 noise=0.0005 lr=0.000150 global_step=1965326
# [eval] acrobot_reliable seed=0 ep=7550 mean=-81.200 std=6.585
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [acrobot_reliable seed=0] ep=07560 rawR= -98.000 trainR= -70.761 recent20= -89.200 flicker=0.014 noise=0.0005 lr=0.000150 global_step=1967130
# [acrobot_reliable seed=0] ep=07580 rawR= -80.000 trainR= -53.153 recent20= -91.650 flicker=0.014 noise=0.0005 lr=0.000149 global_step=1968983
# [update] acrobot_reliable seed=0 loss=9.1922 policy=-0.0128 value=15.3492 entropy=0.3982 kl=0.0004 early_stop_kl=0
# [eval] acrobot_reliable seed=0 ep=7600 mean=-77.700 std=6.589
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [acrobot_reliable seed=0] ep=07600 rawR=-101.000 trainR= -73.233 recent20= -91.950 flicker=0.014 noise=0.0005 lr=0.000149 global_step=1970842

# %%
import sys

sys.argv = [
    "1.ipynb",
    "--device", "cuda:0",
    "--resume",
    "--ckpt-dir", "./checkpoints_robust_recurrent_ppo",
    "--presets", "acrobot_reliable",
    "--seeds", "0,1,2",
    "--save-every", "50",
    "--eval-every", "50",
    "--log-every", "20",
]

main()
# Out:
# ============================================================
# device       = cuda:0
# amp          = True
# compile      = False
# presets      = ['acrobot_reliable']
# seeds        = [0, 1, 2]
# episodes     = None (None이면 preset recommended_episodes)
# ============================================================
#
# ===== RUN preset=acrobot_reliable seed=0 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed0_latest.pt
# [resume] preset=acrobot_reliable seed=0 start_episode=16000
# [skip] already finished: acrobot_reliable seed=0
#
# ===== RUN preset=acrobot_reliable seed=1 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed1_latest.pt
# [resume] preset=acrobot_reliable seed=1 start_episode=16000
# [skip] already finished: acrobot_reliable seed=1
#
# ===== RUN preset=acrobot_reliable seed=2 =====
# [resume] loading ./checkpoints_robust_recurrent_ppo/acrobot_reliable_seed2_latest.pt
# [resume] preset=acrobot_reliable seed=2 start_episode=16000
# [skip] already finished: acrobot_reliable seed=2
#
# ================ FINAL SUMMARY ================
# preset           | n_seeds | episodes_completed | auc_mean            | last100_mean       | best_reward         | first_solve_ep | eval_mean          | eval_std
# -----------------+---------+--------------------+---------------------+--------------------+---------------------+----------------+--------------------+-------------------
# acrobot_reliable | 3       | 16000              | -187.821            | -90.610            | -59.667             | 8897           | -83.333            | 17.210
#
# raw csv     : ./robust_recurrent_ppo_raw.csv
# summary csv : ./robust_recurrent_ppo_summary.csv
# raw json    : ./robust_recurrent_ppo_raw.json
# summary json: ./robust_recurrent_ppo_summary.json
# elapsed_sec : 0.63
#
# [recommended run]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_reliable,acrobot_reliable,mountaincar_reliable --seeds 0,1,2 --resume
#
# [more POMDP]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_medium,acrobot_medium,mountaincar_medium --seeds 0,1,2 --resume
#
# [hard partial test]
# python robust_multi_env_recurrent_ppo.py --device cuda:0 --presets cartpole_partial_hard --seeds 0,1,2 --resume
#
# [important note]
# 이 코드는 학습 안정성을 위해 reward shaping(train only)과 POMDP severity curriculum을 사용한다. 평가/summary는 raw reward 기준으로 기록된다.

# %%
import sys

sys.argv = [
    "1.ipynb",
    "--device", "cuda:0",
    "--resume",
    "--ckpt-dir", "./checkpoints_robust_recurrent_ppo",
    "--presets", "cartpole_reliable,acrobot_reliable,mountaincar_reliable",
    "--seeds", "0,1,2",
    "--save-every", "50",
    "--eval-every", "50",
    "--log-every", "20",
]

main()

# %%
import sys

sys.argv = [
    "1.ipynb",
    "--device", "cuda:0",
    "--resume",
    "--ckpt-dir", "./checkpoints_robust_recurrent_ppo",
    "--presets", "mountaincar_reliable",
    "--seeds", "0,1,2",
    "--save-every", "50",
    "--eval-every", "50",
    "--log-every", "20",
]

main()
# Out:
# ============================================================
# device       = cuda:0
# amp          = True
# compile      = False
# presets      = ['mountaincar_reliable']
# seeds        = [0, 1, 2]
# episodes     = None (None이면 preset recommended_episodes)
# ============================================================
#
# ===== RUN preset=mountaincar_reliable seed=0 =====
# [mountaincar_reliable seed=0] ep=00000 rawR=-200.000 trainR=-195.012 recent20=-200.000 flicker=0.000 noise=0.0000 lr=0.000200 global_step=200
# [update] mountaincar_reliable seed=0 loss=167.9195 policy=-0.0142 value=239.9523 entropy=1.0985 kl=0.0001 early_stop_kl=0
# [mountaincar_reliable seed=0] ep=00020 rawR=-200.000 trainR=-194.240 recent20=-200.000 flicker=0.000 noise=0.0000 lr=0.000200 global_step=4200
# [update] mountaincar_reliable seed=0 loss=163.5428 policy=-0.0138 value=233.6992 entropy=1.0973 kl=-0.0004 early_stop_kl=0
# [mountaincar_reliable seed=0] ep=00040 rawR=-200.000 trainR=-196.160 recent20=-200.000 flicker=0.000 noise=0.0000 lr=0.000200 global_step=8200
# [eval] mountaincar_reliable seed=0 ep=50 mean=-200.000 std=0.000
# [ckpt] saved ./checkpoints_robust_recurrent_ppo/mountaincar_reliable_seed0_latest.pt
# [mountaincar_reliable seed=0] ep=00060 rawR=-200.000 trainR=-194.704 recent20=-200.000 flicker=0.000 noise=0.0000 lr=0.000199 global_step=12200
# [update] mountaincar_reliable seed=0 loss=157.7112 policy=-0.0302 value=225.3915 entropy=1.0925 kl=0.0006 early_stop_kl=0
# [mountaincar_reliable seed=0] ep=00080 rawR=-200.000 trainR=-195.286 recent20=-200.000 flicker=0.000 noise=0.0000 lr=0.000199 global_step=16200
