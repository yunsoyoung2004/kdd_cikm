# %%
# ============================================================
# acrobot_reliable_v3_single.py
# ------------------------------------------------------------
# Acrobot 전용 robust recurrent PPO + SPIKE stabilization
# - notebook-safe argparse
# - GPU info print
# - split_segments preview bug fixed
# ============================================================

import os
import gc
import csv
import json
import math
import signal
import random
import argparse
from copy import deepcopy
from dataclasses import dataclass, asdict
from typing import Any, Dict, List, Optional

import numpy as np
import gymnasium as gym

import torch
import torch.nn as nn
from torch.distributions import Categorical


# ============================================================
# Global
# ============================================================
STOP_REQUESTED = False


def _signal_handler(signum, frame):
    global STOP_REQUESTED
    STOP_REQUESTED = True
    print(f"\n[signal] received {signum}, stop at safe point.")


signal.signal(signal.SIGINT, _signal_handler)
signal.signal(signal.SIGTERM, _signal_handler)


# ============================================================
# Utils
# ============================================================
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)


def cleanup(device: torch.device):
    try:
        gc.collect()
        if device.type == "cuda":
            torch.cuda.synchronize(device)
            torch.cuda.empty_cache()
            try:
                torch.cuda.ipc_collect()
            except Exception:
                pass
    except Exception:
        pass


def linear_interp(a: float, b: float, t01: float) -> float:
    t01 = max(0.0, min(1.0, float(t01)))
    return a + (b - a) * t01


def gpu_mem_str(device: torch.device) -> str:
    if device.type != "cuda":
        return "cpu"
    alloc = torch.cuda.memory_allocated(device) / (1024 ** 2)
    reserved = torch.cuda.memory_reserved(device) / (1024 ** 2)
    return f"alloc={alloc:.1f}MB reserved={reserved:.1f}MB"


# ============================================================
# Config
# ============================================================
@dataclass
class Config:
    name: str = "acrobot_reliable_v3"
    env_id: str = "Acrobot-v1"
    partial_indices: Optional[List[int]] = None

    flicker_prob_start: float = 0.0
    flicker_prob_end: float = 0.015
    noise_std_start: float = 0.0
    noise_std_end: float = 0.0003

    max_steps: int = 500
    recommended_episodes: int = 24000
    solve_score: float = -100.0

    lr: float = 1.2e-4
    lr_end_scale: float = 0.30
    gamma: float = 0.995
    gae_lambda: float = 0.98
    ppo_clip: float = 0.15
    value_clip: float = 0.15
    ppo_epochs: int = 10
    minibatch_tokens: int = 4096
    steps_per_update: int = 4096
    value_coef: float = 0.9
    max_grad_norm: float = 0.5
    target_kl: float = 0.012

    ent_start: float = 0.020
    ent_end: float = 0.002

    mlp_hidden: int = 256
    lstm_hidden: int = 192

    eval_every: int = 250
    eval_episodes: int = 10
    save_every: int = 250
    log_every: int = 20

    ckpt_dir: str = "./checkpoints_acrobot_v3"
    raw_csv: str = "./acrobot_v3_raw.csv"
    summary_json: str = "./acrobot_v3_summary.json"

    # SPIKE / collapse
    spike_threshold: float = 8.0
    collapse_threshold: float = 18.0
    anchor_blend: float = 0.35
    warmup_episodes: int = 1000


CFG = Config(partial_indices=[0, 1, 2, 3, 4, 5])


# ============================================================
# RunningMeanStd
# ============================================================
class RunningMeanStd:
    def __init__(self, shape):
        self.mean = np.zeros(shape, dtype=np.float64)
        self.var = np.ones(shape, dtype=np.float64)
        self.count = 1e-4

    def update(self, x: np.ndarray):
        x = np.asarray(x, dtype=np.float64)
        if x.ndim == 1:
            x = x[None, :]

        batch_mean = np.mean(x, axis=0)
        batch_var = np.var(x, axis=0)
        batch_count = x.shape[0]

        delta = batch_mean - self.mean
        total_count = self.count + batch_count

        new_mean = self.mean + delta * batch_count / total_count
        m_a = self.var * self.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + (delta ** 2) * self.count * batch_count / total_count
        new_var = M2 / total_count

        self.mean = new_mean
        self.var = np.maximum(new_var, 1e-12)
        self.count = total_count

    def normalize(self, x: np.ndarray) -> np.ndarray:
        x = np.asarray(x, dtype=np.float32)
        z = (x - self.mean) / np.sqrt(self.var + 1e-8)
        return np.clip(z, -10.0, 10.0).astype(np.float32)

    def state_dict(self):
        return {
            "mean": self.mean.tolist(),
            "var": self.var.tolist(),
            "count": float(self.count),
        }

    def load_state_dict(self, sd):
        self.mean = np.asarray(sd["mean"], dtype=np.float64)
        self.var = np.asarray(sd["var"], dtype=np.float64)
        self.count = float(sd["count"])


# ============================================================
# POMDP Wrapper
# ============================================================
class ScheduledPartialObsWrapper(gym.ObservationWrapper):
    def __init__(self, env, partial_indices, flicker_prob_start, flicker_prob_end, noise_std_start, noise_std_end):
        super().__init__(env)
        self.partial_indices = partial_indices
        self.flicker_prob_start = float(flicker_prob_start)
        self.flicker_prob_end = float(flicker_prob_end)
        self.noise_std_start = float(noise_std_start)
        self.noise_std_end = float(noise_std_end)
        self.progress = 0.0

        low = env.observation_space.low
        high = env.observation_space.high

        if self.partial_indices is None:
            self.partial_indices = list(range(int(np.prod(low.shape))))

        low2 = low[self.partial_indices].astype(np.float32)
        high2 = high[self.partial_indices].astype(np.float32)

        self.observation_space = gym.spaces.Box(
            low=low2,
            high=high2,
            shape=(len(self.partial_indices),),
            dtype=np.float32,
        )

    def set_progress(self, progress01: float):
        self.progress = max(0.0, min(1.0, float(progress01)))

    def get_current_params(self):
        flicker = linear_interp(self.flicker_prob_start, self.flicker_prob_end, self.progress)
        noise = linear_interp(self.noise_std_start, self.noise_std_end, self.progress)
        return flicker, noise

    def observation(self, obs):
        obs = np.asarray(obs, dtype=np.float32)[self.partial_indices]

        flicker, noise = self.get_current_params()

        if flicker > 0.0 and np.random.rand() < flicker:
            obs = np.zeros_like(obs, dtype=np.float32)

        if noise > 0.0:
            obs = obs + np.random.normal(0.0, noise, size=obs.shape).astype(np.float32)

        return obs.astype(np.float32)


# ============================================================
# Reward shaping
# ============================================================
class AcrobotShaperV3:
    def tip_height(self, obs):
        c1, s1, c2, s2 = float(obs[0]), float(obs[1]), float(obs[2]), float(obs[3])
        theta1 = math.atan2(s1, c1)
        theta2 = math.atan2(s2, c2)
        y = -math.cos(theta1) - math.cos(theta1 + theta2)
        return y

    def potential(self, obs):
        y = self.tip_height(obs)
        d1 = float(obs[4]) if len(obs) > 4 else 0.0
        d2 = float(obs[5]) if len(obs) > 5 else 0.0
        vel_pen = 0.025 * (abs(d1) + abs(d2))
        return 7.0 * y - vel_pen

    def train_reward(self, obs, next_obs, raw_reward, terminated):
        gamma = 0.995
        shaped = float(raw_reward) + gamma * self.potential(next_obs) - self.potential(obs)

        y_gain = self.tip_height(next_obs) - self.tip_height(obs)
        shaped += 2.0 * y_gain

        if terminated:
            shaped += 18.0

        return shaped


# ============================================================
# Model
# ============================================================
class RecurrentActorCritic(nn.Module):
    def __init__(self, obs_dim, action_dim, mlp_hidden, lstm_hidden):
        super().__init__()
        self.lstm_hidden = lstm_hidden

        self.encoder = nn.Sequential(
            nn.Linear(obs_dim, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
            nn.Linear(mlp_hidden, mlp_hidden),
            nn.LayerNorm(mlp_hidden),
            nn.Tanh(),
        )
        self.lstm = nn.LSTM(mlp_hidden, lstm_hidden, batch_first=True)
        self.actor = nn.Linear(lstm_hidden, action_dim)
        self.critic = nn.Linear(lstm_hidden, 1)

        self.apply(self._init)
        nn.init.orthogonal_(self.actor.weight, gain=0.01)
        nn.init.zeros_(self.actor.bias)
        nn.init.orthogonal_(self.critic.weight, gain=1.0)
        nn.init.zeros_(self.critic.bias)

    def _init(self, m):
        if isinstance(m, nn.Linear):
            nn.init.orthogonal_(m.weight, gain=math.sqrt(2))
            nn.init.zeros_(m.bias)

    def initial_state(self, batch_size, device):
        h = torch.zeros(1, batch_size, self.lstm_hidden, device=device)
        c = torch.zeros(1, batch_size, self.lstm_hidden, device=device)
        return (h, c)

    def forward(self, obs_seq, hidden=None):
        x = self.encoder(obs_seq)
        x, hidden = self.lstm(x, hidden)
        logits = self.actor(x)
        values = self.critic(x)
        return logits, values, hidden

    @torch.no_grad()
    def act(self, obs_t, hidden):
        logits, value, hidden = self.forward(obs_t, hidden)
        logits = logits[:, -1, :]
        value = value[:, -1, :]
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        return int(action.item()), float(log_prob.item()), float(value.item()), hidden


# ============================================================
# RolloutBuffer
# ============================================================
class RolloutBuffer:
    def __init__(self):
        self.obs = []
        self.actions = []
        self.rewards = []
        self.raw_rewards = []
        self.dones = []
        self.log_probs = []
        self.values = []
        self.episode_ids = []
        self.bootstrap_values = []

    def add(self, obs, action, reward, raw_reward, done, log_prob, value, episode_id):
        self.obs.append(np.asarray(obs, dtype=np.float32))
        self.actions.append(int(action))
        self.rewards.append(float(reward))
        self.raw_rewards.append(float(raw_reward))
        self.dones.append(bool(done))
        self.log_probs.append(float(log_prob))
        self.values.append(float(value))
        self.episode_ids.append(int(episode_id))

    def clear(self):
        self.__init__()

    def __len__(self):
        return len(self.obs)


# ============================================================
# Helpers
# ============================================================
def build_env(seed=None):
    env = gym.make(CFG.env_id)
    env = ScheduledPartialObsWrapper(
        env,
        CFG.partial_indices,
        CFG.flicker_prob_start,
        CFG.flicker_prob_end,
        CFG.noise_std_start,
        CFG.noise_std_end,
    )
    if seed is not None:
        env.reset(seed=seed)
        env.action_space.seed(seed)
    return env


def compute_gae(rewards, values, dones, next_value, gamma, gae_lambda):
    n = len(rewards)
    adv = np.zeros(n, dtype=np.float32)
    last_gae = 0.0

    for t in reversed(range(n)):
        if t == n - 1:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = next_value
        else:
            next_nonterminal = 1.0 - float(dones[t])
            next_values = values[t + 1]

        delta = rewards[t] + gamma * next_values * next_nonterminal - values[t]
        last_gae = delta + gamma * gae_lambda * next_nonterminal * last_gae
        adv[t] = last_gae

    ret = adv + values
    return adv, ret


def split_segments_preview(buffer: RolloutBuffer):
    if len(buffer) == 0:
        return []

    segments = []
    start = 0

    for i in range(len(buffer.obs) - 1):
        if buffer.dones[i] or buffer.episode_ids[i + 1] != buffer.episode_ids[i]:
            segments.append(slice(start, i + 1))
            start = i + 1

    if start < len(buffer.obs):
        segments.append(slice(start, len(buffer.obs)))

    return segments


def split_segments(buffer: RolloutBuffer):
    previews = split_segments_preview(buffer)
    return [(sl, buffer.bootstrap_values[idx]) for idx, sl in enumerate(previews)]


def pad_sequences(arrays, pad_value=0.0):
    max_len = max(a.shape[0] for a in arrays)
    padded, masks = [], []

    for a in arrays:
        t = a.shape[0]
        pad_shape = (max_len - t,) + a.shape[1:]
        pad = np.full(pad_shape, pad_value, dtype=a.dtype)
        padded.append(np.concatenate([a, pad], axis=0))
        masks.append(np.concatenate([
            np.ones(t, dtype=np.float32),
            np.zeros(max_len - t, dtype=np.float32)
        ]))

    return np.stack(padded), np.stack(masks)


@torch.no_grad()
def evaluate(model, obs_rms, device, n_episodes=10):
    env = build_env(seed=12345)
    env.set_progress(1.0)
    scores = []

    try:
        for ep in range(n_episodes):
            obs, _ = env.reset(seed=12345 + ep)
            hidden = model.initial_state(1, device)
            done = False
            ep_reward = 0.0
            steps = 0

            while not done and steps < CFG.max_steps:
                obs_n = obs_rms.normalize(obs)
                obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                logits, _, hidden = model(obs_t, hidden)
                action = torch.argmax(Categorical(logits=logits[:, -1, :]).probs, dim=-1)

                obs, reward, terminated, truncated, _ = env.step(int(action.item()))
                done = terminated or truncated
                ep_reward += float(reward)
                steps += 1

            scores.append(ep_reward)
    finally:
        env.close()

    arr = np.asarray(scores, dtype=np.float32)
    return {
        "eval_mean": float(arr.mean()),
        "eval_std": float(arr.std(ddof=0)),
        "eval_min": float(arr.min()),
        "eval_max": float(arr.max()),
    }


def maybe_anchor_blend(model, anchor_model, blend):
    with torch.no_grad():
        msd = model.state_dict()
        asd = anchor_model.state_dict()
        for k in msd.keys():
            msd[k].mul_(1.0 - blend).add_(asd[k], alpha=blend)
        model.load_state_dict(msd)


def ppo_update(model, optimizer, scaler, buffer, device, use_amp, progress01):
    segments = split_segments(buffer)
    if not segments:
        return {"loss": 0.0, "policy": 0.0, "value": 0.0, "entropy": 0.0, "kl": 0.0, "early_stop_kl": 0}

    obs_list, act_list, old_logp_list, adv_list, ret_list, old_val_list = [], [], [], [], [], []

    for sl, bootstrap_value in segments:
        rewards = np.asarray(buffer.rewards[sl], dtype=np.float32)
        values = np.asarray(buffer.values[sl], dtype=np.float32)
        dones = np.asarray(buffer.dones[sl], dtype=np.float32)
        adv, ret = compute_gae(rewards, values, dones, bootstrap_value, CFG.gamma, CFG.gae_lambda)

        obs_list.append(np.asarray(buffer.obs[sl], dtype=np.float32))
        act_list.append(np.asarray(buffer.actions[sl], dtype=np.int64))
        old_logp_list.append(np.asarray(buffer.log_probs[sl], dtype=np.float32))
        adv_list.append(adv)
        ret_list.append(ret.astype(np.float32))
        old_val_list.append(np.asarray(buffer.values[sl], dtype=np.float32))

    all_adv = np.concatenate(adv_list, axis=0)
    adv_mean, adv_std = all_adv.mean(), all_adv.std() + 1e-8
    adv_list = [((a - adv_mean) / adv_std).astype(np.float32) for a in adv_list]

    obs_pad, mask = pad_sequences(obs_list, 0.0)
    act_pad, _ = pad_sequences([a[:, None] for a in act_list], 0)
    old_logp_pad, _ = pad_sequences([a[:, None] for a in old_logp_list], 0.0)
    adv_pad, _ = pad_sequences([a[:, None] for a in adv_list], 0.0)
    ret_pad, _ = pad_sequences([a[:, None] for a in ret_list], 0.0)
    old_val_pad, _ = pad_sequences([a[:, None] for a in old_val_list], 0.0)

    obs_t = torch.as_tensor(obs_pad, dtype=torch.float32, device=device)
    act_t = torch.as_tensor(act_pad.squeeze(-1), dtype=torch.long, device=device)
    old_logp_t = torch.as_tensor(old_logp_pad.squeeze(-1), dtype=torch.float32, device=device)
    adv_t = torch.as_tensor(adv_pad.squeeze(-1), dtype=torch.float32, device=device)
    ret_t = torch.as_tensor(ret_pad.squeeze(-1), dtype=torch.float32, device=device)
    old_val_t = torch.as_tensor(old_val_pad.squeeze(-1), dtype=torch.float32, device=device)
    mask_t = torch.as_tensor(mask, dtype=torch.float32, device=device)

    idxs = np.arange(obs_t.shape[0])
    seqs_per_batch = max(1, CFG.minibatch_tokens // max(1, obs_t.shape[1]))
    ent_coef = linear_interp(CFG.ent_start, CFG.ent_end, progress01)

    losses, plosses, vlosses, ents, kls = [], [], [], [], []
    early_stop_kl = 0

    for _ in range(CFG.ppo_epochs):
        np.random.shuffle(idxs)
        stop_epoch = False

        for start in range(0, len(idxs), seqs_per_batch):
            bidx = idxs[start:start + seqs_per_batch]
            b_obs = obs_t[bidx]
            b_act = act_t[bidx]
            b_old_logp = old_logp_t[bidx]
            b_adv = adv_t[bidx]
            b_ret = ret_t[bidx]
            b_old_val = old_val_t[bidx]
            b_mask = mask_t[bidx]

            hidden = model.initial_state(b_obs.shape[0], device)

            with torch.amp.autocast("cuda", enabled=use_amp):
                logits, values, _ = model(b_obs, hidden)
                values = values.squeeze(-1)

                dist = Categorical(logits=logits)
                new_logp = dist.log_prob(b_act)
                entropy = dist.entropy()

                ratio = torch.exp(new_logp - b_old_logp)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - CFG.ppo_clip, 1.0 + CFG.ppo_clip) * b_adv
                policy_loss = -torch.sum(torch.min(surr1, surr2) * b_mask) / (torch.sum(b_mask) + 1e-8)

                value_pred_clipped = b_old_val + torch.clamp(values - b_old_val, -CFG.value_clip, CFG.value_clip)
                value_loss_unclipped = (values - b_ret) ** 2
                value_loss_clipped = (value_pred_clipped - b_ret) ** 2
                value_loss = 0.5 * torch.sum(torch.max(value_loss_unclipped, value_loss_clipped) * b_mask) / (
                    torch.sum(b_mask) + 1e-8
                )

                entropy_mean = torch.sum(entropy * b_mask) / (torch.sum(b_mask) + 1e-8)
                loss = policy_loss + CFG.value_coef * value_loss - ent_coef * entropy_mean

            optimizer.zero_grad(set_to_none=True)
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)
            scaler.step(optimizer)
            scaler.update()

            with torch.no_grad():
                approx_kl = torch.sum((b_old_logp - new_logp) * b_mask) / (torch.sum(b_mask) + 1e-8)

            losses.append(float(loss.item()))
            plosses.append(float(policy_loss.item()))
            vlosses.append(float(value_loss.item()))
            ents.append(float(entropy_mean.item()))
            kls.append(float(approx_kl.item()))

            if float(approx_kl.item()) > CFG.target_kl:
                early_stop_kl += 1
                stop_epoch = True
                break

        if stop_epoch:
            break

    return {
        "loss": float(np.mean(losses)) if losses else 0.0,
        "policy": float(np.mean(plosses)) if plosses else 0.0,
        "value": float(np.mean(vlosses)) if vlosses else 0.0,
        "entropy": float(np.mean(ents)) if ents else 0.0,
        "kl": float(np.mean(kls)) if kls else 0.0,
        "early_stop_kl": early_stop_kl,
    }


def save_checkpoint(path, episode, global_step, model, optimizer, scaler, obs_rms,
                    raw_train_rewards, train_rewards, eval_history, spike_count,
                    collapse_count, anchor_model):
    torch.save({
        "episode": int(episode),
        "global_step": int(global_step),
        "model": model.state_dict(),
        "optimizer": optimizer.state_dict(),
        "scaler": scaler.state_dict(),
        "obs_rms": obs_rms.state_dict(),
        "raw_train_rewards": list(raw_train_rewards),
        "train_rewards": list(train_rewards),
        "eval_history": list(eval_history),
        "spike_count": int(spike_count),
        "collapse_count": int(collapse_count),
        "anchor_model": anchor_model.state_dict() if anchor_model is not None else None,
        "config": asdict(CFG),
    }, path)


def load_checkpoint(path, model, optimizer, scaler, obs_rms, anchor_model, device):
    ckpt = torch.load(path, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    try:
        scaler.load_state_dict(ckpt["scaler"])
    except Exception:
        pass
    obs_rms.load_state_dict(ckpt["obs_rms"])
    if ckpt.get("anchor_model") is not None:
        anchor_model.load_state_dict(ckpt["anchor_model"])
    return ckpt


# ============================================================
# Main
# ============================================================
def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--device", type=str, default=None)
    parser.add_argument("--seed", type=int, default=0)
    parser.add_argument("--episodes", type=int, default=CFG.recommended_episodes)
    parser.add_argument("--resume", action="store_true")
    parser.add_argument("--amp", action="store_true")
    args, _ = parser.parse_known_args()

    set_seed(args.seed)
    device = torch.device(args.device if args.device is not None else ("cuda:0" if torch.cuda.is_available() else "cpu"))
    use_amp = bool(args.amp and device.type == "cuda")

    print("=" * 60)
    print("device       =", device)
    print("use_amp      =", use_amp)
    if device.type == "cuda":
        print("cuda_name    =", torch.cuda.get_device_name(device))
        print("cuda_count   =", torch.cuda.device_count())
        props = torch.cuda.get_device_properties(device)
        print("total_memory =", round(props.total_memory / (1024 ** 3), 2), "GB")
    else:
        print("cuda_name    = CPU mode")
    print("=" * 60)

    env = build_env(seed=args.seed)
    shaper = AcrobotShaperV3()

    obs_dim = int(np.prod(env.observation_space.shape))
    action_dim = int(env.action_space.n)

    model = RecurrentActorCritic(obs_dim, action_dim, CFG.mlp_hidden, CFG.lstm_hidden).to(device)
    anchor_model = RecurrentActorCritic(obs_dim, action_dim, CFG.mlp_hidden, CFG.lstm_hidden).to(device)
    anchor_model.load_state_dict(model.state_dict())
    anchor_model.eval()

    optimizer = torch.optim.Adam(model.parameters(), lr=CFG.lr, eps=1e-5)
    scaler = torch.amp.GradScaler("cuda", enabled=use_amp)
    obs_rms = RunningMeanStd((obs_dim,))
    buffer = RolloutBuffer()

    ensure_dir(CFG.ckpt_dir)
    cpath = os.path.join(CFG.ckpt_dir, f"{CFG.name}_seed{args.seed}_latest.pt")

    raw_train_rewards, train_rewards, eval_history = [], [], []
    episode_idx, global_step = 0, 0
    best_anchor_eval = -1e18
    spike_count, collapse_count = 0, 0

    if args.resume and os.path.exists(cpath):
        ckpt = load_checkpoint(cpath, model, optimizer, scaler, obs_rms, anchor_model, device)
        raw_train_rewards = list(ckpt.get("raw_train_rewards", []))
        train_rewards = list(ckpt.get("train_rewards", []))
        eval_history = list(ckpt.get("eval_history", []))
        spike_count = int(ckpt.get("spike_count", 0))
        collapse_count = int(ckpt.get("collapse_count", 0))
        episode_idx = int(ckpt.get("episode", -1)) + 1
        global_step = int(ckpt.get("global_step", 0))
        if eval_history:
            best_anchor_eval = max(x["eval_mean"] for x in eval_history)
        print(f"[resume] start_episode={episode_idx}")

    try:
        obs, _ = env.reset(seed=args.seed + 123)
        hidden = model.initial_state(1, device)
        ep_raw_reward, ep_train_reward, ep_steps = 0.0, 0.0, 0

        while episode_idx < args.episodes:
            progress01 = episode_idx / max(1, args.episodes - 1)
            env.set_progress(progress01)

            lr_now = linear_interp(CFG.lr, CFG.lr * CFG.lr_end_scale, progress01)
            for g in optimizer.param_groups:
                g["lr"] = lr_now

            obs_rms.update(np.asarray(obs, dtype=np.float32)[None, :])
            obs_n = obs_rms.normalize(obs)
            obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)

            action, log_prob, value, hidden = model.act(obs_t, hidden)
            next_obs, raw_reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            train_reward = shaper.train_reward(obs, next_obs, raw_reward, terminated)
            buffer.add(obs_n, action, train_reward, raw_reward, done, log_prob, value, episode_idx)

            obs = next_obs
            ep_raw_reward += float(raw_reward)
            ep_train_reward += float(train_reward)
            ep_steps += 1
            global_step += 1

            if done or ep_steps >= CFG.max_steps:
                buffer.bootstrap_values.append(0.0)
                raw_train_rewards.append(ep_raw_reward)
                train_rewards.append(ep_train_reward)

                if episode_idx % CFG.log_every == 0:
                    last20 = raw_train_rewards[-20:] if len(raw_train_rewards) >= 20 else raw_train_rewards
                    flicker_now, noise_now = env.get_current_params()
                    print(
                        f"[train] ep={episode_idx:05d} raw={ep_raw_reward:8.3f} "
                        f"train={ep_train_reward:8.3f} recent20={np.mean(last20):8.3f} "
                        f"flicker={flicker_now:.4f} noise={noise_now:.5f} "
                        f"lr={lr_now:.7f} gpu={gpu_mem_str(device)}"
                    )

                if ((episode_idx + 1) % CFG.eval_every) == 0 or (episode_idx + 1) == args.episodes:
                    eval_result = evaluate(model, obs_rms, device, CFG.eval_episodes)
                    eval_result["eval_at_episode"] = episode_idx + 1
                    eval_history.append(eval_result)

                    print(
                        f"[eval] ep={episode_idx+1} mean={eval_result['eval_mean']:.3f} "
                        f"std={eval_result['eval_std']:.3f}"
                    )

                    if episode_idx >= CFG.warmup_episodes and eval_result["eval_mean"] > best_anchor_eval + CFG.spike_threshold:
                        best_anchor_eval = eval_result["eval_mean"]
                        anchor_model.load_state_dict(deepcopy(model.state_dict()))
                        spike_count += 1
                        print(f"[SPIKE] new anchor saved | spike_count={spike_count} | anchor_eval={best_anchor_eval:.3f}")

                    if episode_idx >= CFG.warmup_episodes and best_anchor_eval > -1e17:
                        if eval_result["eval_mean"] < best_anchor_eval - CFG.collapse_threshold:
                            maybe_anchor_blend(model, anchor_model, CFG.anchor_blend)
                            collapse_count += 1
                            print(f"[COLLAPSE] anchor blend applied | collapse_count={collapse_count}")

                if ((episode_idx + 1) % CFG.save_every) == 0 or STOP_REQUESTED:
                    save_checkpoint(
                        cpath, episode_idx, global_step, model, optimizer, scaler, obs_rms,
                        raw_train_rewards, train_rewards, eval_history, spike_count,
                        collapse_count, anchor_model
                    )
                    print(f"[ckpt] saved {cpath}")

                episode_idx += 1
                if STOP_REQUESTED:
                    break

                obs, _ = env.reset(seed=args.seed * 100000 + episode_idx)
                hidden = model.initial_state(1, device)
                ep_raw_reward, ep_train_reward, ep_steps = 0.0, 0.0, 0

            if len(buffer) >= CFG.steps_per_update or (STOP_REQUESTED and len(buffer) > 0):
                needed = len(split_segments_preview(buffer))
                while len(buffer.bootstrap_values) < needed:
                    obs_n = obs_rms.normalize(obs)
                    obs_t = torch.as_tensor(obs_n, dtype=torch.float32, device=device).view(1, 1, -1)
                    with torch.no_grad():
                        _, value_t, _ = model(obs_t, hidden)
                        bootstrap_value = float(value_t[:, -1, :].item()) if not done else 0.0
                    buffer.bootstrap_values.append(bootstrap_value)

                stats = ppo_update(model, optimizer, scaler, buffer, device, use_amp, progress01)
                print(
                    f"[update] loss={stats['loss']:.4f} policy={stats['policy']:.4f} "
                    f"value={stats['value']:.4f} entropy={stats['entropy']:.4f} "
                    f"kl={stats['kl']:.4f} early_stop_kl={stats['early_stop_kl']} "
                    f"gpu={gpu_mem_str(device)}"
                )
                buffer.clear()

                if STOP_REQUESTED:
                    break

        save_checkpoint(
            cpath, max(0, episode_idx - 1), global_step, model, optimizer, scaler, obs_rms,
            raw_train_rewards, train_rewards, eval_history, spike_count,
            collapse_count, anchor_model
        )

        tail100 = raw_train_rewards[-100:] if len(raw_train_rewards) >= 100 else raw_train_rewards
        result = {
            "preset": CFG.name,
            "seed": args.seed,
            "episodes_completed": len(raw_train_rewards),
            "last100_mean": float(np.mean(tail100)) if tail100 else 0.0,
            "best_reward": float(np.max(raw_train_rewards)) if raw_train_rewards else 0.0,
            "eval_mean": float(eval_history[-1]["eval_mean"]) if eval_history else 0.0,
            "eval_std": float(eval_history[-1]["eval_std"]) if eval_history else 0.0,
            "spike_count": spike_count,
            "collapse_count": collapse_count,
        }

        with open(CFG.raw_csv, "w", newline="", encoding="utf-8-sig") as f:
            writer = csv.DictWriter(f, fieldnames=result.keys())
            writer.writeheader()
            writer.writerow(result)

        with open(CFG.summary_json, "w", encoding="utf-8") as f:
            json.dump(result, f, ensure_ascii=False, indent=2)

        print("\n================ FINAL ================")
        print(json.dumps(result, ensure_ascii=False, indent=2))

    finally:
        try:
            env.close()
        except Exception:
            pass
        cleanup(device)


if __name__ == "__main__":
    main()
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# ============================================================
# device       = cuda:0
# use_amp      = False
# cuda_name    = NVIDIA L40S
# cuda_count   = 1
# total_memory = 44.52 GB
# ============================================================
# [train] ep=00000 raw=-500.000 train=-453.372 recent20=-500.000 flicker=0.0000 noise=0.00000 lr=0.0001200 gpu=alloc=11.3MB reserved=42.0MB
# [update] loss=544.1425 policy=0.0207 value=604.6042 entropy=1.0986 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=218.0MB
# [update] loss=539.6809 policy=-0.0283 value=599.7013 entropy=1.0985 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=218.0MB
# [train] ep=00020 raw=-500.000 train=-464.973 recent20=-500.000 flicker=0.0000 noise=0.00000 lr=0.0001199 gpu=alloc=25.2MB reserved=218.0MB
# [update] loss=540.4988 policy=-0.0019 value=600.5807 entropy=1.0984 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=218.0MB
# [update] loss=527.9234 policy=-0.0070 value=586.6137 entropy=1.0982 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=218.0MB
# [update] loss=519.7470 policy=-0.0409 value=577.5666 entropy=1.0980 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=218.0MB
# [train] ep=00040 raw=-500.000 train=-466.592 recent20=-500.000 flicker=0.0000 noise=0.00000 lr=0.0001199 gpu=alloc=25.2MB reserved=218.0MB
# [update] loss=511.7369 policy=-0.0883 value=568.7190 entropy=1.0978 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=519.7104 policy=0.0148 value=577.4639 entropy=1.0953 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00060 raw=-500.000 train=-469.004 recent20=-492.750 flicker=0.0000 noise=0.00000 lr=0.0001198 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=507.1186 policy=-0.0398 value=563.5335 entropy=1.0875 kl=-0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=499.6662 policy=-0.0001 value=555.2088 entropy=1.0863 kl=0.0004 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00080 raw=-500.000 train=-462.184 recent20=-491.100 flicker=0.0001 noise=0.00000 lr=0.0001197 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=494.3416 policy=0.0062 value=549.2856 entropy=1.0873 kl=0.0015 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=486.0253 policy=-0.0730 value=540.1333 entropy=1.0896 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=464.6551 policy=-0.0296 value=516.3403 entropy=1.0825 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00100 raw=-445.000 train=-382.969 recent20=-473.400 flicker=0.0001 noise=0.00000 lr=0.0001196 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=482.1395 policy=-0.0183 value=535.7548 entropy=1.0793 kl=0.0014 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=468.2381 policy=-0.0474 value=520.3406 entropy=1.0560 kl=0.0019 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00120 raw=-500.000 train=-459.627 recent20=-487.000 flicker=0.0001 noise=0.00000 lr=0.0001196 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=475.5162 policy=-0.0065 value=528.3813 entropy=1.0271 kl=0.0018 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=460.6121 policy=-0.0009 value=511.8142 entropy=0.9966 kl=0.0004 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00140 raw=-500.000 train=-456.503 recent20=-465.550 flicker=0.0001 noise=0.00000 lr=0.0001195 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=464.8914 policy=0.0132 value=516.5535 entropy=1.0001 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=451.4655 policy=-0.0272 value=501.6808 entropy=1.0056 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=446.3874 policy=-0.0318 value=496.0441 entropy=1.0287 kl=0.0015 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00160 raw=-500.000 train=-462.190 recent20=-478.800 flicker=0.0001 noise=0.00000 lr=0.0001194 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=456.8402 policy=-0.0026 value=507.6264 entropy=1.0512 kl=-0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=451.1724 policy=0.0003 value=501.3256 entropy=1.0482 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00180 raw=-500.000 train=-461.711 recent20=-482.100 flicker=0.0001 noise=0.00000 lr=0.0001194 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=448.5272 policy=0.0134 value=498.3719 entropy=1.0534 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=449.4922 policy=-0.0443 value=499.5081 entropy=1.0475 kl=0.0006 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00200 raw=-458.000 train=-389.019 recent20=-493.600 flicker=0.0001 noise=0.00000 lr=0.0001193 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=447.1839 policy=-0.0393 value=496.9372 entropy=1.0216 kl=0.0018 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=449.9487 policy=-0.0015 value=499.9667 entropy=1.0000 kl=0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=448.5868 policy=0.0222 value=498.4275 entropy=1.0191 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00220 raw=-500.000 train=-470.110 recent20=-488.800 flicker=0.0001 noise=0.00000 lr=0.0001192 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=438.3611 policy=0.0048 value=487.0852 entropy=1.0252 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=435.2180 policy=-0.0392 value=483.6415 entropy=1.0127 kl=0.0014 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00240 raw=-445.000 train=-377.171 recent20=-492.700 flicker=0.0002 noise=0.00000 lr=0.0001192 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=434.4744 policy=-0.0026 value=482.7754 entropy=1.0564 kl=0.0016 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [eval] ep=250 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_acrobot_v3/acrobot_reliable_v3_seed0_latest.pt
# [update] loss=436.8662 policy=-0.0071 value=485.4383 entropy=1.0672 kl=0.0006 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=436.5947 policy=-0.0089 value=485.1388 entropy=1.0770 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00260 raw=-500.000 train=-470.635 recent20=-488.700 flicker=0.0002 noise=0.00000 lr=0.0001191 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=437.0796 policy=0.0014 value=485.6662 entropy=1.0778 kl=0.0015 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=419.5819 policy=-0.0332 value=466.2628 entropy=1.0817 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00280 raw=-500.000 train=-462.330 recent20=-489.450 flicker=0.0002 noise=0.00000 lr=0.0001190 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=437.5693 policy=-0.0012 value=486.2132 entropy=1.0805 kl=0.0011 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=436.0070 policy=0.0113 value=484.4635 entropy=1.0861 kl=-0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00300 raw=-500.000 train=-465.954 recent20=-491.500 flicker=0.0002 noise=0.00000 lr=0.0001189 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=408.2557 policy=-0.0279 value=453.6725 entropy=1.0885 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=423.6944 policy=-0.0286 value=470.8272 entropy=1.0843 kl=0.0007 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=423.8826 policy=-0.0316 value=471.0394 entropy=1.0770 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00320 raw=-500.000 train=-466.045 recent20=-496.500 flicker=0.0002 noise=0.00000 lr=0.0001189 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=414.3835 policy=-0.0575 value=460.5139 entropy=1.0863 kl=0.0013 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=408.2719 policy=-0.0905 value=453.7600 entropy=1.0937 kl=0.0009 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00340 raw=-500.000 train=-465.737 recent20=-500.000 flicker=0.0002 noise=0.00000 lr=0.0001188 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=409.8506 policy=-0.0394 value=455.4574 entropy=1.0959 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=419.0041 policy=-0.0048 value=465.5893 entropy=1.0872 kl=0.0004 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=420.5533 policy=-0.0140 value=467.3209 entropy=1.0893 kl=0.0011 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00360 raw=-500.000 train=-454.654 recent20=-489.700 flicker=0.0002 noise=0.00000 lr=0.0001187 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=406.6655 policy=-0.0567 value=451.9374 entropy=1.0849 kl=0.0021 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=420.8822 policy=-0.0110 value=467.6829 entropy=1.0860 kl=0.0020 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00380 raw=-500.000 train=-460.639 recent20=-500.000 flicker=0.0002 noise=0.00000 lr=0.0001187 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=417.5896 policy=0.0125 value=463.9985 entropy=1.0926 kl=0.0007 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=412.3325 policy=-0.0342 value=458.2091 entropy=1.0883 kl=0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00400 raw=-500.000 train=-462.948 recent20=-500.000 flicker=0.0003 noise=0.00001 lr=0.0001186 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=413.9280 policy=-0.0002 value=459.9442 entropy=1.0911 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=418.0668 policy=0.0024 value=464.5397 entropy=1.0874 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=412.4703 policy=-0.0145 value=458.3401 entropy=1.0814 kl=-0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00420 raw=-500.000 train=-458.370 recent20=-500.000 flicker=0.0003 noise=0.00001 lr=0.0001185 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=410.7375 policy=-0.0007 value=456.3992 entropy=1.0718 kl=0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=409.3829 policy=-0.0491 value=454.9477 entropy=1.0589 kl=0.0004 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00440 raw=-500.000 train=-460.970 recent20=-499.800 flicker=0.0003 noise=0.00001 lr=0.0001185 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=395.0621 policy=-0.0707 value=439.0593 entropy=1.0451 kl=0.0006 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=409.4330 policy=0.0287 value=454.9165 entropy=1.0437 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=407.9670 policy=0.0184 value=453.2995 entropy=1.0683 kl=0.0022 early_stop_kl=1 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00460 raw=-500.000 train=-463.724 recent20=-485.300 flicker=0.0003 noise=0.00001 lr=0.0001184 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=380.5602 policy=-0.1256 value=423.0077 entropy=1.0774 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=400.8062 policy=-0.0115 value=445.3754 entropy=1.0296 kl=0.0043 early_stop_kl=1 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00480 raw=-500.000 train=-464.028 recent20=-489.800 flicker=0.0003 noise=0.00001 lr=0.0001183 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=399.5048 policy=-0.0393 value=443.9597 entropy=0.9978 kl=-0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=400.9974 policy=0.0027 value=445.5722 entropy=1.0330 kl=0.0022 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [eval] ep=500 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_acrobot_v3/acrobot_reliable_v3_seed0_latest.pt
# [update] loss=396.9302 policy=-0.0350 value=441.0952 entropy=1.0438 kl=0.0013 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00500 raw=-500.000 train=-465.433 recent20=-496.750 flicker=0.0003 noise=0.00001 lr=0.0001182 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=397.3174 policy=-0.0208 value=441.5092 entropy=1.0259 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=387.9572 policy=-0.0238 value=431.1125 entropy=1.0330 kl=0.0006 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00520 raw=-500.000 train=-464.294 recent20=-494.500 flicker=0.0003 noise=0.00001 lr=0.0001182 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=402.7351 policy=0.0067 value=447.4987 entropy=1.0441 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=395.4366 policy=0.0002 value=439.3966 entropy=1.0473 kl=-0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00540 raw=-500.000 train=-465.788 recent20=-499.950 flicker=0.0003 noise=0.00001 lr=0.0001181 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=384.9204 policy=-0.1324 value=427.8594 entropy=1.0554 kl=-0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=387.8771 policy=-0.0444 value=431.0468 entropy=1.0506 kl=0.0014 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=388.0358 policy=-0.0155 value=431.1900 entropy=1.0040 kl=0.0057 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00560 raw=-500.000 train=-466.965 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001180 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=388.6516 policy=-0.0176 value=431.8765 entropy=1.0056 kl=0.0009 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=389.2905 policy=0.0003 value=432.5670 entropy=1.0253 kl=0.0021 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00580 raw=-500.000 train=-455.732 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001180 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=384.3930 policy=-0.0100 value=427.1369 entropy=1.0321 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=392.5714 policy=0.0259 value=436.1846 entropy=1.0521 kl=0.0039 early_stop_kl=1 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=386.4854 policy=0.0029 value=429.4480 entropy=1.0563 kl=-0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00600 raw=-500.000 train=-465.363 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001179 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=382.7872 policy=-0.0250 value=425.3698 entropy=1.0549 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=386.9678 policy=-0.0013 value=429.9880 entropy=1.0286 kl=0.0016 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00620 raw=-500.000 train=-466.031 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001178 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=381.0011 policy=-0.0182 value=423.3773 entropy=1.0361 kl=0.0011 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=380.2792 policy=-0.0139 value=422.5706 entropy=1.0462 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=385.3205 policy=0.0130 value=428.1422 entropy=1.0514 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00640 raw=-500.000 train=-469.518 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001178 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=377.6699 policy=-0.0132 value=419.6707 entropy=1.0561 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=380.1533 policy=-0.0129 value=422.4298 entropy=1.0571 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00660 raw=-500.000 train=-459.835 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001177 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=376.3248 policy=-0.0153 value=418.1786 entropy=1.0595 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=380.7878 policy=0.0106 value=423.1088 entropy=1.0594 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=363.7351 policy=-0.1071 value=404.2921 entropy=1.0639 kl=-0.0009 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00680 raw=-500.000 train=-466.422 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001176 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=373.1310 policy=-0.0064 value=414.6202 entropy=1.0644 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=368.2358 policy=-0.0197 value=409.1959 entropy=1.0663 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00700 raw=-500.000 train=-461.221 recent20=-500.000 flicker=0.0004 noise=0.00001 lr=0.0001175 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=373.2795 policy=-0.0025 value=414.7810 entropy=1.0755 kl=0.0007 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=371.0930 policy=-0.0267 value=412.3785 entropy=1.0774 kl=0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00720 raw=-500.000 train=-457.761 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001175 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=370.6594 policy=-0.0134 value=411.8820 entropy=1.0792 kl=0.0004 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=354.7210 policy=-0.0942 value=394.2623 entropy=1.0681 kl=0.0017 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=365.5026 policy=-0.0301 value=406.1703 entropy=1.0574 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00740 raw=-500.000 train=-455.494 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001174 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=365.5132 policy=-0.0003 value=406.1496 entropy=1.0825 kl=0.0023 early_stop_kl=1 gpu=alloc=25.2MB reserved=224.0MB
# [eval] ep=750 mean=-500.000 std=0.000
# [ckpt] saved ./checkpoints_acrobot_v3/acrobot_reliable_v3_seed0_latest.pt
# [update] loss=369.5333 policy=0.0038 value=410.6120 entropy=1.0928 kl=-0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00760 raw=-500.000 train=-466.636 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001173 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=360.6642 policy=-0.0695 value=400.8389 entropy=1.0943 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=363.6212 policy=-0.0054 value=404.0532 entropy=1.0940 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=339.8477 policy=-0.0925 value=377.7349 entropy=1.0919 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00780 raw=-500.000 train=-468.947 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001173 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=365.8809 policy=-0.0043 value=406.5626 entropy=1.0916 kl=0.0017 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=359.2843 policy=-0.0365 value=399.2688 entropy=1.0929 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00800 raw=-500.000 train=-462.196 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001172 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=362.2699 policy=-0.0181 value=402.5658 entropy=1.0917 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=354.8577 policy=-0.0648 value=394.3818 entropy=1.0926 kl=-0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=356.4974 policy=-0.0185 value=396.1523 entropy=1.0930 kl=0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00820 raw=-500.000 train=-465.343 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001171 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=361.9336 policy=0.0059 value=402.1655 entropy=1.0972 kl=0.0015 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=360.4023 policy=0.0070 value=400.4629 entropy=1.0959 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00840 raw=-500.000 train=-463.893 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001171 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=361.0737 policy=0.0119 value=401.2034 entropy=1.0946 kl=0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=350.5731 policy=-0.0468 value=389.6013 entropy=1.0940 kl=-0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00860 raw=-500.000 train=-465.886 recent20=-500.000 flicker=0.0005 noise=0.00001 lr=0.0001170 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=344.6942 policy=-0.0616 value=383.0856 entropy=1.0951 kl=0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=353.0934 policy=-0.0052 value=392.3554 entropy=1.0944 kl=-0.0002 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=353.8808 policy=-0.0029 value=393.2276 entropy=1.0934 kl=-0.0001 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00880 raw=-500.000 train=-466.134 recent20=-500.000 flicker=0.0006 noise=0.00001 lr=0.0001169 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=353.6181 policy=-0.0069 value=392.9400 entropy=1.0858 kl=0.0017 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=357.5498 policy=0.0210 value=397.2777 entropy=1.0877 kl=0.0003 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00900 raw=-500.000 train=-469.803 recent20=-500.000 flicker=0.0006 noise=0.00001 lr=0.0001168 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=353.1672 policy=0.0060 value=392.4247 entropy=1.0880 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=347.1285 policy=0.0001 value=385.7217 entropy=1.0888 kl=-0.0000 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=352.3463 policy=0.0053 value=391.5129 entropy=1.0655 kl=0.0036 early_stop_kl=1 gpu=alloc=25.2MB reserved=224.0MB
# [train] ep=00920 raw=-500.000 train=-464.201 recent20=-498.000 flicker=0.0006 noise=0.00001 lr=0.0001168 gpu=alloc=25.2MB reserved=224.0MB
# [update] loss=342.9938 policy=-0.0440 value=381.1756 entropy=1.0531 kl=0.0005 early_stop_kl=0 gpu=alloc=25.2MB reserved=224.0MB
